# %% [markdown]
# **Portfolio Investment**

# %%
import numpy as np # work with large multidimensional arrays
import pandas as pd #data manipulation and analysis

# Graphs
import matplotlib.pyplot as plt #Plotting
import matplotlib.dates as mdates #Styling dates

import datetime as dt #For defining dates
import time
import yfinance as yf
import os
from os.path import isfile, join

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# **Constants**

# %%
# Save the stocks data downloaded
PATH = '../raw_data/data_stocks/'
# File with all the tickers to be downloaded
tickers_path = '../raw_data/stocks_ticker/VL_5000_stocks.csv'
# Save stocks data modified
path_folder = '../raw_data/stocks_analysis/'

#Start end date defaults
S_DATE = '2017-02-01'
E_DATE = '2022-12-06'
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# # Get Stocks Data

# %% [markdown]
# ## **Get Column Data from CSV**

# %%
def get_column_from_csv(file, col_name):
    #Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stocks Tickers

# %%
tickers = get_column_from_csv(tickers_path, 'Ticker')
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for :", ticker)
        df = stock.history(period='5y') # Get historical closing price data       
        time.sleep(1) # Wait 2 seconds before download another stock
        
        # Remove the period for saving the file name, 
        # save data to CSV file
        # File to save to
        the_file = folder + ticker.replace(".", ',') + ".csv"
        print(the_file, "Saved")
        df.to_csv(the_file)
    
    except Exception as ex:
        print("Couldn't get data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, len(tickers)):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print('Finished')
# Out:
# Get Data for : A
# ../raw_data/data_stocks/A.csv Saved
# Finished
# Get Data for : AA
# ../raw_data/data_stocks/AA.csv Saved
# Finished
# Get Data for : AAL
# ../raw_data/data_stocks/AAL.csv Saved
# Finished
# Get Data for : AAME
# ../raw_data/data_stocks/AAME.csv Saved
# Finished
# Get Data for : AAN
# ../raw_data/data_stocks/AAN.csv Saved
# Finished
# Get Data for : AAOI
# ../raw_data/data_stocks/AAOI.csv Saved
# Finished
# Get Data for : AAON
# ../raw_data/data_stocks/AAON.csv Saved
# Finished
# Get Data for : AAP
# ../raw_data/data_stocks/AAP.csv Saved
# Finished
# Get Data for : AAPL
# ../raw_data/data_stocks/AAPL.csv Saved
# Finished
# Get Data for : AAT
# ../raw_data/data_stocks/AAT.csv Saved
# Finished
# Get Data for : AAWW
# ../raw_data/data_stocks/AAWW.csv Saved
# Finished
# Get Data for : AAXN
# - AAXN: No data found, symbol may be delisted
# ../raw_data/data_stocks/AAXN.csv Saved
# Finished
# Get Data for : ABBV
# ../raw_data/data_stocks/ABBV.csv Saved
# Finished
# Get Data for : ABC
# ../raw_data/data_stocks/ABC.csv Saved
# Finished
# Get Data for : ABCB
# ../raw_data/data_stocks/ABCB.csv Saved
# Finished
# Get Data for : ABEO
# ../raw_data/data_stocks/ABEO.csv Saved
# Finished
# Get Data for : ABG
# ../raw_data/data_stocks/ABG.csv Saved
# Finished
# Get Data for : ABIO
# ../raw_data/data_stocks/ABIO.csv Saved
# Finished
# Get Data for : ABM
# ../raw_data/data_stocks/ABM.csv Saved
# Finished
# Get Data for : ABMD
# ../raw_data/data_stocks/ABMD.csv Saved
# Finished
# Get Data for : ABR
# ../raw_data/data_stocks/ABR.csv Saved
# Finished
# Get Data for : ABT
# ../raw_data/data_stocks/ABT.csv Saved
# Finished
# Get Data for : ABTX
# ../raw_data/data_stocks/ABTX.csv Saved
# Finished
# Get Data for : AC
# ../raw_data/data_stocks/AC.csv Saved
# Finished
# Get Data for : ACA
# ../raw_data/data_stocks/ACA.csv Saved
# Finished
# Get Data for : ACAD
# ../raw_data/data_stocks/ACAD.csv Saved
# Finished
# Get Data for : ACBI
# ../raw_data/data_stocks/ACBI.csv Saved
# Finished
# Get Data for : ACC
# ../raw_data/data_stocks/ACC.csv Saved
# Finished
# Get Data for : ACCO
# ../raw_data/data_stocks/ACCO.csv Saved
# Finished
# Get Data for : ACER
# ../raw_data/data_stocks/ACER.csv Saved
# Finished
# Get Data for : ACGL
# ../raw_data/data_stocks/ACGL.csv Saved
# Finished
# Get Data for : ACHC
# ../raw_data/data_stocks/ACHC.csv Saved
# Finished
# Get Data for : ACHV
# ../raw_data/data_stocks/ACHV.csv Saved
# Finished
# Get Data for : ACIA
# - ACIA: No data found, symbol may be delisted
# ../raw_data/data_stocks/ACIA.csv Saved
# Finished
# Get Data for : ACIW
# ../raw_data/data_stocks/ACIW.csv Saved
# Finished
# Get Data for : ACLS
# ../raw_data/data_stocks/ACLS.csv Saved
# Finished
# Get Data for : ACM
# ../raw_data/data_stocks/ACM.csv Saved
# Finished
# Get Data for : ACMR
# ../raw_data/data_stocks/ACMR.csv Saved
# Finished
# Get Data for : ACN
# ../raw_data/data_stocks/ACN.csv Saved
# Finished
# Get Data for : ACNB
# ../raw_data/data_stocks/ACNB.csv Saved
# Finished
# Get Data for : ACOR
# ../raw_data/data_stocks/ACOR.csv Saved
# Finished
# Get Data for : ACRE
# ../raw_data/data_stocks/ACRE.csv Saved
# Finished
# Get Data for : ACRS
# ../raw_data/data_stocks/ACRS.csv Saved
# Finished
# Get Data for : ACRX
# ../raw_data/data_stocks/ACRX.csv Saved
# Finished
# Get Data for : ACTG
# ../raw_data/data_stocks/ACTG.csv Saved
# Finished
# Get Data for : ACU
# ../raw_data/data_stocks/ACU.csv Saved
# Finished
# Get Data for : ACY
# ../raw_data/data_stocks/ACY.csv Saved
# Finished
# Get Data for : ADBE
# ../raw_data/data_stocks/ADBE.csv Saved
# Finished
# Get Data for : ADC
# ../raw_data/data_stocks/ADC.csv Saved
# Finished
# Get Data for : ADES
# ../raw_data/data_stocks/ADES.csv Saved
# Finished
# Get Data for : ADI
# ../raw_data/data_stocks/ADI.csv Saved
# Finished
# Get Data for : ADM
# ../raw_data/data_stocks/ADM.csv Saved
# Finished
# Get Data for : ADMA
# ../raw_data/data_stocks/ADMA.csv Saved
# Finished
# Get Data for : ADMP
# ../raw_data/data_stocks/ADMP.csv Saved
# Finished
# Get Data for : ADMS
# - ADMS: No data found, symbol may be delisted
# ../raw_data/data_stocks/ADMS.csv Saved
# Finished
# Get Data for : ADNT
# ../raw_data/data_stocks/ADNT.csv Saved
# Finished
# Get Data for : ADP
# ../raw_data/data_stocks/ADP.csv Saved
# Finished
# Get Data for : ADRO
# - ADRO: No data found, symbol may be delisted
# ../raw_data/data_stocks/ADRO.csv Saved
# Finished
# Get Data for : ADS
# ../raw_data/data_stocks/ADS.csv Saved
# Finished
# Get Data for : ADSK
# ../raw_data/data_stocks/ADSK.csv Saved
# Finished
# Get Data for : ADSW
# - ADSW: No data found, symbol may be delisted
# ../raw_data/data_stocks/ADSW.csv Saved
# Finished
# Get Data for : ADT
# ../raw_data/data_stocks/ADT.csv Saved
# Finished
# Get Data for : ADTN
# ../raw_data/data_stocks/ADTN.csv Saved
# Finished
# Get Data for : ADUS
# ../raw_data/data_stocks/ADUS.csv Saved
# Finished
# Get Data for : ADVM
# ../raw_data/data_stocks/ADVM.csv Saved
# Finished
# Get Data for : ADXS
# ../raw_data/data_stocks/ADXS.csv Saved
# Finished
# Get Data for : AE
# ../raw_data/data_stocks/AE.csv Saved
# Finished
# Get Data for : AEE
# ../raw_data/data_stocks/AEE.csv Saved
# Finished
# Get Data for : AEGN
# - AEGN: No data found, symbol may be delisted
# ../raw_data/data_stocks/AEGN.csv Saved
# Finished
# Get Data for : AEHR
# ../raw_data/data_stocks/AEHR.csv Saved
# Finished
# Get Data for : AEIS
# ../raw_data/data_stocks/AEIS.csv Saved
# Finished
# Get Data for : AEL
# ../raw_data/data_stocks/AEL.csv Saved
# Finished
# Get Data for : AEMD
# ../raw_data/data_stocks/AEMD.csv Saved
# Finished
# Get Data for : AEO
# ../raw_data/data_stocks/AEO.csv Saved
# Finished
# Get Data for : AEP
# ../raw_data/data_stocks/AEP.csv Saved
# Finished
# Get Data for : AERI
# ../raw_data/data_stocks/AERI.csv Saved
# Finished
# Get Data for : AES
# ../raw_data/data_stocks/AES.csv Saved
# Finished
# Get Data for : AEY
# ../raw_data/data_stocks/AEY.csv Saved
# Finished
# Get Data for : AFG
# ../raw_data/data_stocks/AFG.csv Saved
# Finished
# Get Data for : AFH
# - AFH: No data found, symbol may be delisted
# ../raw_data/data_stocks/AFH.csv Saved
# Finished
# Get Data for : AFI
# ../raw_data/data_stocks/AFI.csv Saved
# Finished
# Get Data for : AFIN
# ../raw_data/data_stocks/AFIN.csv Saved
# Finished
# Get Data for : AFL
# ../raw_data/data_stocks/AFL.csv Saved
# Finished
# Get Data for : AGCO
# ../raw_data/data_stocks/AGCO.csv Saved
# Finished
# Get Data for : AGE
# ../raw_data/data_stocks/AGE.csv Saved
# Finished
# Get Data for : AGEN
# ../raw_data/data_stocks/AGEN.csv Saved
# Finished
# Get Data for : AGFS
# ../raw_data/data_stocks/AGFS.csv Saved
# Finished
# Get Data for : AGIO
# ../raw_data/data_stocks/AGIO.csv Saved
# Finished
# Get Data for : AGLE
# ../raw_data/data_stocks/AGLE.csv Saved
# Finished
# Get Data for : AGM
# ../raw_data/data_stocks/AGM.csv Saved
# Finished
# Get Data for : AGNC
# ../raw_data/data_stocks/AGNC.csv Saved
# Finished
# Get Data for : AGO
# ../raw_data/data_stocks/AGO.csv Saved
# Finished
# Get Data for : AGR
# ../raw_data/data_stocks/AGR.csv Saved
# Finished
# Get Data for : AGRX
# ../raw_data/data_stocks/AGRX.csv Saved
# Finished
# Get Data for : AGS
# ../raw_data/data_stocks/AGS.csv Saved
# Finished
# Get Data for : AGTC
# ../raw_data/data_stocks/AGTC.csv Saved
# Finished
# Get Data for : AGX
# ../raw_data/data_stocks/AGX.csv Saved
# Finished
# Get Data for : AGYS
# ../raw_data/data_stocks/AGYS.csv Saved
# Finished
# Get Data for : AHC
# - AHC: No data found, symbol may be delisted
# ../raw_data/data_stocks/AHC.csv Saved
# Finished
# Get Data for : AHH
# ../raw_data/data_stocks/AHH.csv Saved
# Finished
# Get Data for : AHT
# ../raw_data/data_stocks/AHT.csv Saved
# Finished
# Get Data for : AIG
# ../raw_data/data_stocks/AIG.csv Saved
# Finished
# Get Data for : AIMC
# ../raw_data/data_stocks/AIMC.csv Saved
# Finished
# Get Data for : AIMT
# - AIMT: No data found, symbol may be delisted
# ../raw_data/data_stocks/AIMT.csv Saved
# Finished
# Get Data for : AIN
# ../raw_data/data_stocks/AIN.csv Saved
# Finished
# Get Data for : AINC
# ../raw_data/data_stocks/AINC.csv Saved
# Finished
# Get Data for : AIR
# ../raw_data/data_stocks/AIR.csv Saved
# Finished
# Get Data for : AIRG
# ../raw_data/data_stocks/AIRG.csv Saved
# Finished
# Get Data for : AIRI
# ../raw_data/data_stocks/AIRI.csv Saved
# Finished
# Get Data for : AIRT
# ../raw_data/data_stocks/AIRT.csv Saved
# Finished
# Get Data for : AIT
# ../raw_data/data_stocks/AIT.csv Saved
# Finished
# Get Data for : AIV
# ../raw_data/data_stocks/AIV.csv Saved
# Finished
# Get Data for : AIZ
# ../raw_data/data_stocks/AIZ.csv Saved
# Finished
# Get Data for : AJG
# ../raw_data/data_stocks/AJG.csv Saved
# Finished
# Get Data for : AJRD
# ../raw_data/data_stocks/AJRD.csv Saved
# Finished
# Get Data for : AJX
# ../raw_data/data_stocks/AJX.csv Saved
# Finished
# Get Data for : AKAM
# ../raw_data/data_stocks/AKAM.csv Saved
# Finished
# Get Data for : AKBA
# ../raw_data/data_stocks/AKBA.csv Saved
# Finished
# Get Data for : AKCA
# - AKCA: No data found, symbol may be delisted
# ../raw_data/data_stocks/AKCA.csv Saved
# Finished
# Get Data for : AKER
# - AKER: No data found, symbol may be delisted
# ../raw_data/data_stocks/AKER.csv Saved
# Finished
# Get Data for : AKR
# ../raw_data/data_stocks/AKR.csv Saved
# Finished
# Get Data for : AKTS
# ../raw_data/data_stocks/AKTS.csv Saved
# Finished
# Get Data for : AL
# ../raw_data/data_stocks/AL.csv Saved
# Finished
# Get Data for : ALB
# ../raw_data/data_stocks/ALB.csv Saved
# Finished
# Get Data for : ALBO
# ../raw_data/data_stocks/ALBO.csv Saved
# Finished
# Get Data for : ALCO
# ../raw_data/data_stocks/ALCO.csv Saved
# Finished
# Get Data for : ALDX
# ../raw_data/data_stocks/ALDX.csv Saved
# Finished
# Get Data for : ALE
# ../raw_data/data_stocks/ALE.csv Saved
# Finished
# Get Data for : ALEC
# ../raw_data/data_stocks/ALEC.csv Saved
# Finished
# Get Data for : ALEX
# ../raw_data/data_stocks/ALEX.csv Saved
# Finished
# Get Data for : ALG
# ../raw_data/data_stocks/ALG.csv Saved
# Finished
# Get Data for : ALGN
# ../raw_data/data_stocks/ALGN.csv Saved
# Finished
# Get Data for : ALGT
# ../raw_data/data_stocks/ALGT.csv Saved
# Finished
# Get Data for : ALIM
# ../raw_data/data_stocks/ALIM.csv Saved
# Finished
# Get Data for : ALJJ
# ../raw_data/data_stocks/ALJJ.csv Saved
# Finished
# Get Data for : ALK
# ../raw_data/data_stocks/ALK.csv Saved
# Finished
# Get Data for : ALKS
# ../raw_data/data_stocks/ALKS.csv Saved
# Finished
# Get Data for : ALL
# ../raw_data/data_stocks/ALL.csv Saved
# Finished
# Get Data for : ALLE
# ../raw_data/data_stocks/ALLE.csv Saved
# Finished
# Get Data for : ALLK
# ../raw_data/data_stocks/ALLK.csv Saved
# Finished
# Get Data for : ALLO
# ../raw_data/data_stocks/ALLO.csv Saved
# Finished
# Get Data for : ALLY
# ../raw_data/data_stocks/ALLY.csv Saved
# Finished
# Get Data for : ALNA
# ../raw_data/data_stocks/ALNA.csv Saved
# Finished
# Get Data for : ALNY
# ../raw_data/data_stocks/ALNY.csv Saved
# Finished
# Get Data for : ALOT
# ../raw_data/data_stocks/ALOT.csv Saved
# Finished
# Get Data for : ALPN
# ../raw_data/data_stocks/ALPN.csv Saved
# Finished
# Get Data for : ALRM
# ../raw_data/data_stocks/ALRM.csv Saved
# Finished
# Get Data for : ALSK
# - ALSK: No data found, symbol may be delisted
# ../raw_data/data_stocks/ALSK.csv Saved
# Finished
# Get Data for : ALSN
# ../raw_data/data_stocks/ALSN.csv Saved
# Finished
# Get Data for : ALT
# ../raw_data/data_stocks/ALT.csv Saved
# Finished
# Get Data for : ALTM
# ../raw_data/data_stocks/ALTM.csv Saved
# Finished
# Get Data for : ALTR
# ../raw_data/data_stocks/ALTR.csv Saved
# Finished
# Get Data for : ALV
# ../raw_data/data_stocks/ALV.csv Saved
# Finished
# Get Data for : ALX
# ../raw_data/data_stocks/ALX.csv Saved
# Finished
# Get Data for : ALXN
# - ALXN: No data found, symbol may be delisted
# ../raw_data/data_stocks/ALXN.csv Saved
# Finished
# Get Data for : AM
# ../raw_data/data_stocks/AM.csv Saved
# Finished
# Get Data for : AMAG
# - AMAG: No data found, symbol may be delisted
# ../raw_data/data_stocks/AMAG.csv Saved
# Finished
# Get Data for : AMAL
# ../raw_data/data_stocks/AMAL.csv Saved
# Finished
# Get Data for : AMAT
# ../raw_data/data_stocks/AMAT.csv Saved
# Finished
# Get Data for : AMBC
# ../raw_data/data_stocks/AMBC.csv Saved
# Finished
# Get Data for : AMC
# ../raw_data/data_stocks/AMC.csv Saved
# Finished
# Get Data for : AMCX
# ../raw_data/data_stocks/AMCX.csv Saved
# Finished
# Get Data for : AMD
# ../raw_data/data_stocks/AMD.csv Saved
# Finished
# Get Data for : AME
# ../raw_data/data_stocks/AME.csv Saved
# Finished
# Get Data for : AMED
# ../raw_data/data_stocks/AMED.csv Saved
# Finished
# Get Data for : AMG
# ../raw_data/data_stocks/AMG.csv Saved
# Finished
# Get Data for : AMGN
# ../raw_data/data_stocks/AMGN.csv Saved
# Finished
# Get Data for : AMH
# ../raw_data/data_stocks/AMH.csv Saved
# Finished
# Get Data for : AMKR
# ../raw_data/data_stocks/AMKR.csv Saved
# Finished
# Get Data for : AMN
# ../raw_data/data_stocks/AMN.csv Saved
# Finished
# Get Data for : AMNB
# ../raw_data/data_stocks/AMNB.csv Saved
# Finished
# Get Data for : AMOT
# ../raw_data/data_stocks/AMOT.csv Saved
# Finished
# Get Data for : AMP
# ../raw_data/data_stocks/AMP.csv Saved
# Finished
# Get Data for : AMPE
# ../raw_data/data_stocks/AMPE.csv Saved
# Finished
# Get Data for : AMPH
# ../raw_data/data_stocks/AMPH.csv Saved
# Finished
# Get Data for : AMRB
# - AMRB: No data found, symbol may be delisted
# ../raw_data/data_stocks/AMRB.csv Saved
# Finished
# Get Data for : AMRC
# ../raw_data/data_stocks/AMRC.csv Saved
# Finished
# Get Data for : AMRK
# ../raw_data/data_stocks/AMRK.csv Saved
# Finished
# Get Data for : AMRS
# ../raw_data/data_stocks/AMRS.csv Saved
# Finished
# Get Data for : AMRX
# ../raw_data/data_stocks/AMRX.csv Saved
# Finished
# Get Data for : AMS
# ../raw_data/data_stocks/AMS.csv Saved
# Finished
# Get Data for : AMSC
# ../raw_data/data_stocks/AMSC.csv Saved
# Finished
# Get Data for : AMSF
# ../raw_data/data_stocks/AMSF.csv Saved
# Finished
# Get Data for : AMSWA
# ../raw_data/data_stocks/AMSWA.csv Saved
# Finished
# Get Data for : AMT
# ../raw_data/data_stocks/AMT.csv Saved
# Finished
# Get Data for : AMTD
# ../raw_data/data_stocks/AMTD.csv Saved
# Finished
# Get Data for : AMTX
# ../raw_data/data_stocks/AMTX.csv Saved
# Finished
# Get Data for : AMWD
# ../raw_data/data_stocks/AMWD.csv Saved
# Finished
# Get Data for : AMZN
# ../raw_data/data_stocks/AMZN.csv Saved
# Finished
# Get Data for : AN
# ../raw_data/data_stocks/AN.csv Saved
# Finished
# Get Data for : ANAB
# ../raw_data/data_stocks/ANAB.csv Saved
# Finished
# Get Data for : ANAT
# ../raw_data/data_stocks/ANAT.csv Saved
# Finished
# Get Data for : ANDE
# ../raw_data/data_stocks/ANDE.csv Saved
# Finished
# Get Data for : ANET
# ../raw_data/data_stocks/ANET.csv Saved
# Finished
# Get Data for : ANF
# ../raw_data/data_stocks/ANF.csv Saved
# Finished
# Get Data for : ANGI
# ../raw_data/data_stocks/ANGI.csv Saved
# Finished
# Get Data for : ANGO
# ../raw_data/data_stocks/ANGO.csv Saved
# Finished
# Get Data for : ANH
# - ANH: No data found, symbol may be delisted
# ../raw_data/data_stocks/ANH.csv Saved
# Finished
# Get Data for : ANIK
# ../raw_data/data_stocks/ANIK.csv Saved
# Finished
# Get Data for : ANIP
# ../raw_data/data_stocks/ANIP.csv Saved
# Finished
# Get Data for : ANIX
# ../raw_data/data_stocks/ANIX.csv Saved
# Finished
# Get Data for : ANSS
# ../raw_data/data_stocks/ANSS.csv Saved
# Finished
# Get Data for : ANTM
# ../raw_data/data_stocks/ANTM.csv Saved
# Finished
# Get Data for : AON
# ../raw_data/data_stocks/AON.csv Saved
# Finished
# Get Data for : AOS
# ../raw_data/data_stocks/AOS.csv Saved
# Finished
# Get Data for : AOSL
# ../raw_data/data_stocks/AOSL.csv Saved
# Finished
# Get Data for : AP
# ../raw_data/data_stocks/AP.csv Saved
# Finished
# Get Data for : APA
# ../raw_data/data_stocks/APA.csv Saved
# Finished
# Get Data for : APAM
# ../raw_data/data_stocks/APAM.csv Saved
# Finished
# Get Data for : APD
# ../raw_data/data_stocks/APD.csv Saved
# Finished
# Get Data for : APDN
# ../raw_data/data_stocks/APDN.csv Saved
# Finished
# Get Data for : APEI
# ../raw_data/data_stocks/APEI.csv Saved
# Finished
# Get Data for : APEN
# ../raw_data/data_stocks/APEN.csv Saved
# Finished
# Get Data for : APH
# ../raw_data/data_stocks/APH.csv Saved
# Finished
# Get Data for : APLE
# ../raw_data/data_stocks/APLE.csv Saved
# Finished
# Get Data for : APLS
# ../raw_data/data_stocks/APLS.csv Saved
# Finished
# Get Data for : APOG
# ../raw_data/data_stocks/APOG.csv Saved
# Finished
# Get Data for : APPF
# ../raw_data/data_stocks/APPF.csv Saved
# Finished
# Get Data for : APPN
# ../raw_data/data_stocks/APPN.csv Saved
# Finished
# Get Data for : APPS
# ../raw_data/data_stocks/APPS.csv Saved
# Finished
# Get Data for : APRN
# ../raw_data/data_stocks/APRN.csv Saved
# Finished
# Get Data for : APT
# ../raw_data/data_stocks/APT.csv Saved
# Finished
# Get Data for : APTS
# ../raw_data/data_stocks/APTS.csv Saved
# Finished
# Get Data for : APTV
# ../raw_data/data_stocks/APTV.csv Saved
# Finished
# Get Data for : APVO
# ../raw_data/data_stocks/APVO.csv Saved
# Finished
# Get Data for : APYX
# ../raw_data/data_stocks/APYX.csv Saved
# Finished
# Get Data for : AQB
# ../raw_data/data_stocks/AQB.csv Saved
# Finished
# Get Data for : AQMS
# ../raw_data/data_stocks/AQMS.csv Saved
# Finished
# Get Data for : AQUA
# ../raw_data/data_stocks/AQUA.csv Saved
# Finished
# Get Data for : AR
# ../raw_data/data_stocks/AR.csv Saved
# Finished
# Get Data for : ARA
# - ARA: No data found, symbol may be delisted
# ../raw_data/data_stocks/ARA.csv Saved
# Finished
# Get Data for : ARAV
# ../raw_data/data_stocks/ARAV.csv Saved
# Finished
# Get Data for : ARAY
# ../raw_data/data_stocks/ARAY.csv Saved
# Finished
# Get Data for : ARC
# ../raw_data/data_stocks/ARC.csv Saved
# Finished
# Get Data for : ARCB
# ../raw_data/data_stocks/ARCB.csv Saved
# Finished
# Get Data for : ARCH
# ../raw_data/data_stocks/ARCH.csv Saved
# Finished
# Get Data for : ARDX
# ../raw_data/data_stocks/ARDX.csv Saved
# Finished
# Get Data for : ARE
# ../raw_data/data_stocks/ARE.csv Saved
# Finished
# Get Data for : ARES
# ../raw_data/data_stocks/ARES.csv Saved
# Finished
# Get Data for : ARGO
# ../raw_data/data_stocks/ARGO.csv Saved
# Finished
# Get Data for : ARI
# ../raw_data/data_stocks/ARI.csv Saved
# Finished
# Get Data for : ARKR
# ../raw_data/data_stocks/ARKR.csv Saved
# Finished
# Get Data for : ARL
# ../raw_data/data_stocks/ARL.csv Saved
# Finished
# Get Data for : ARLO
# ../raw_data/data_stocks/ARLO.csv Saved
# Finished
# Get Data for : ARMK
# ../raw_data/data_stocks/ARMK.csv Saved
# Finished
# Get Data for : ARNA
# ../raw_data/data_stocks/ARNA.csv Saved
# Finished
# Get Data for : ARNC
# ../raw_data/data_stocks/ARNC.csv Saved
# Finished
# Get Data for : AROC
# ../raw_data/data_stocks/AROC.csv Saved
# Finished
# Get Data for : AROW
# ../raw_data/data_stocks/AROW.csv Saved
# Finished
# Get Data for : ARPO
# - ARPO: No data found, symbol may be delisted
# ../raw_data/data_stocks/ARPO.csv Saved
# Finished
# Get Data for : ARR
# ../raw_data/data_stocks/ARR.csv Saved
# Finished
# Get Data for : ARTNA
# ../raw_data/data_stocks/ARTNA.csv Saved
# Finished
# Get Data for : ARTW
# ../raw_data/data_stocks/ARTW.csv Saved
# Finished
# Get Data for : ARVN
# ../raw_data/data_stocks/ARVN.csv Saved
# Finished
# Get Data for : ARW
# ../raw_data/data_stocks/ARW.csv Saved
# Finished
# Get Data for : ARWR
# ../raw_data/data_stocks/ARWR.csv Saved
# Finished
# Get Data for : ASB
# ../raw_data/data_stocks/ASB.csv Saved
# Finished
# Get Data for : ASFI
# - ASFI: No data found, symbol may be delisted
# ../raw_data/data_stocks/ASFI.csv Saved
# Finished
# Get Data for : ASGN
# ../raw_data/data_stocks/ASGN.csv Saved
# Finished
# Get Data for : ASH
# ../raw_data/data_stocks/ASH.csv Saved
# Finished
# Get Data for : ASIX
# ../raw_data/data_stocks/ASIX.csv Saved
# Finished
# Get Data for : ASMB
# ../raw_data/data_stocks/ASMB.csv Saved
# Finished
# Get Data for : ASNA
# - ASNA: No data found, symbol may be delisted
# ../raw_data/data_stocks/ASNA.csv Saved
# Finished
# Get Data for : ASPN
# ../raw_data/data_stocks/ASPN.csv Saved
# Finished
# Get Data for : ASPS
# ../raw_data/data_stocks/ASPS.csv Saved
# Finished
# Get Data for : ASRT
# ../raw_data/data_stocks/ASRT.csv Saved
# Finished
# Get Data for : ASRV
# ../raw_data/data_stocks/ASRV.csv Saved
# Finished
# Get Data for : ASTC
# ../raw_data/data_stocks/ASTC.csv Saved
# Finished
# Get Data for : ASTE
# ../raw_data/data_stocks/ASTE.csv Saved
# Finished
# Get Data for : ASUR
# ../raw_data/data_stocks/ASUR.csv Saved
# Finished
# Get Data for : ASYS
# ../raw_data/data_stocks/ASYS.csv Saved
# Finished
# Get Data for : ATEC
# ../raw_data/data_stocks/ATEC.csv Saved
# Finished
# Get Data for : ATEN
# ../raw_data/data_stocks/ATEN.csv Saved
# Finished
# Get Data for : ATGE
# ../raw_data/data_stocks/ATGE.csv Saved
# Finished
# Get Data for : ATH
# - ATH: No data found, symbol may be delisted
# ../raw_data/data_stocks/ATH.csv Saved
# Finished
# Get Data for : ATHX
# ../raw_data/data_stocks/ATHX.csv Saved
# Finished
# Get Data for : ATI
# ../raw_data/data_stocks/ATI.csv Saved
# Finished
# Get Data for : ATKR
# ../raw_data/data_stocks/ATKR.csv Saved
# Finished
# Get Data for : ATLC
# ../raw_data/data_stocks/ATLC.csv Saved
# Finished
# Get Data for : ATLO
# ../raw_data/data_stocks/ATLO.csv Saved
# Finished
# Get Data for : ATNI
# ../raw_data/data_stocks/ATNI.csv Saved
# Finished
# Get Data for : ATNM
# ../raw_data/data_stocks/ATNM.csv Saved
# Finished
# Get Data for : ATNX
# ../raw_data/data_stocks/ATNX.csv Saved
# Finished
# Get Data for : ATO
# ../raw_data/data_stocks/ATO.csv Saved
# Finished
# Get Data for : ATOS
# ../raw_data/data_stocks/ATOS.csv Saved
# Finished
# Get Data for : ATR
# ../raw_data/data_stocks/ATR.csv Saved
# Finished
# Get Data for : ATRA
# ../raw_data/data_stocks/ATRA.csv Saved
# Finished
# Get Data for : ATRC
# ../raw_data/data_stocks/ATRC.csv Saved
# Finished
# Get Data for : ATRI
# ../raw_data/data_stocks/ATRI.csv Saved
# Finished
# Get Data for : ATRO
# ../raw_data/data_stocks/ATRO.csv Saved
# Finished
# Get Data for : ATRS
# ../raw_data/data_stocks/ATRS.csv Saved
# Finished
# Get Data for : ATSG
# ../raw_data/data_stocks/ATSG.csv Saved
# Finished
# Get Data for : ATUS
# ../raw_data/data_stocks/ATUS.csv Saved
# Finished
# Get Data for : ATVI
# ../raw_data/data_stocks/ATVI.csv Saved
# Finished
# Get Data for : AUBN
# ../raw_data/data_stocks/AUBN.csv Saved
# Finished
# Get Data for : AUMN
# ../raw_data/data_stocks/AUMN.csv Saved
# Finished
# Get Data for : AUTO
# ../raw_data/data_stocks/AUTO.csv Saved
# Finished
# Get Data for : AVA
# ../raw_data/data_stocks/AVA.csv Saved
# Finished
# Get Data for : AVAV
# ../raw_data/data_stocks/AVAV.csv Saved
# Finished
# Get Data for : AVB
# ../raw_data/data_stocks/AVB.csv Saved
# Finished
# Get Data for : AVD
# ../raw_data/data_stocks/AVD.csv Saved
# Finished
# Get Data for : AVEO
# ../raw_data/data_stocks/AVEO.csv Saved
# Finished
# Get Data for : AVGO
# ../raw_data/data_stocks/AVGO.csv Saved
# Finished
# Get Data for : AVGR
# ../raw_data/data_stocks/AVGR.csv Saved
# Finished
# Get Data for : AVID
# ../raw_data/data_stocks/AVID.csv Saved
# Finished
# Get Data for : AVLR
# ../raw_data/data_stocks/AVLR.csv Saved
# Finished
# Get Data for : AVNS
# ../raw_data/data_stocks/AVNS.csv Saved
# Finished
# Get Data for : AVNW
# ../raw_data/data_stocks/AVNW.csv Saved
# Finished
# Get Data for : AVRO
# ../raw_data/data_stocks/AVRO.csv Saved
# Finished
# Get Data for : AVT
# ../raw_data/data_stocks/AVT.csv Saved
# Finished
# Get Data for : AVTR
# ../raw_data/data_stocks/AVTR.csv Saved
# Finished
# Get Data for : AVXL
# ../raw_data/data_stocks/AVXL.csv Saved
# Finished
# Get Data for : AVY
# ../raw_data/data_stocks/AVY.csv Saved
# Finished
# Get Data for : AVYA
# ../raw_data/data_stocks/AVYA.csv Saved
# Finished
# Get Data for : AWI
# ../raw_data/data_stocks/AWI.csv Saved
# Finished
# Get Data for : AWK
# ../raw_data/data_stocks/AWK.csv Saved
# Finished
# Get Data for : AWR
# ../raw_data/data_stocks/AWR.csv Saved
# Finished
# Get Data for : AWRE
# ../raw_data/data_stocks/AWRE.csv Saved
# Finished
# Get Data for : AWSM
# - AWSM: No data found, symbol may be delisted
# ../raw_data/data_stocks/AWSM.csv Saved
# Finished
# Get Data for : AX
# ../raw_data/data_stocks/AX.csv Saved
# Finished
# Get Data for : AXAS
# ../raw_data/data_stocks/AXAS.csv Saved
# Finished
# Get Data for : AXDX
# ../raw_data/data_stocks/AXDX.csv Saved
# Finished
# Get Data for : AXE
# - AXE: No data found, symbol may be delisted
# ../raw_data/data_stocks/AXE.csv Saved
# Finished
# Get Data for : AXGN
# ../raw_data/data_stocks/AXGN.csv Saved
# Finished
# Get Data for : AXL
# ../raw_data/data_stocks/AXL.csv Saved
# Finished
# Get Data for : AXNX
# ../raw_data/data_stocks/AXNX.csv Saved
# Finished
# Get Data for : AXP
# ../raw_data/data_stocks/AXP.csv Saved
# Finished
# Get Data for : AXR
# ../raw_data/data_stocks/AXR.csv Saved
# Finished
# Get Data for : AXS
# ../raw_data/data_stocks/AXS.csv Saved
# Finished
# Get Data for : AXSM
# ../raw_data/data_stocks/AXSM.csv Saved
# Finished
# Get Data for : AXTA
# ../raw_data/data_stocks/AXTA.csv Saved
# Finished
# Get Data for : AXTI
# ../raw_data/data_stocks/AXTI.csv Saved
# Finished
# Get Data for : AYI
# ../raw_data/data_stocks/AYI.csv Saved
# Finished
# Get Data for : AYX
# ../raw_data/data_stocks/AYX.csv Saved
# Finished
# Get Data for : AZO
# ../raw_data/data_stocks/AZO.csv Saved
# Finished
# Get Data for : AZPN
# ../raw_data/data_stocks/AZPN.csv Saved
# Finished
# Get Data for : AZZ
# ../raw_data/data_stocks/AZZ.csv Saved
# Finished
# Get Data for : B
# ../raw_data/data_stocks/B.csv Saved
# Finished
# Get Data for : BA
# ../raw_data/data_stocks/BA.csv Saved
# Finished
# Get Data for : BAC
# ../raw_data/data_stocks/BAC.csv Saved
# Finished
# Get Data for : BAH
# ../raw_data/data_stocks/BAH.csv Saved
# Finished
# Get Data for : BANC
# ../raw_data/data_stocks/BANC.csv Saved
# Finished
# Get Data for : BAND
# ../raw_data/data_stocks/BAND.csv Saved
# Finished
# Get Data for : BANF
# ../raw_data/data_stocks/BANF.csv Saved
# Finished
# Get Data for : BANR
# ../raw_data/data_stocks/BANR.csv Saved
# Finished
# Get Data for : BASI
# - BASI: No data found, symbol may be delisted
# ../raw_data/data_stocks/BASI.csv Saved
# Finished
# Get Data for : BATRA
# ../raw_data/data_stocks/BATRA.csv Saved
# Finished
# Get Data for : BATRK
# ../raw_data/data_stocks/BATRK.csv Saved
# Finished
# Get Data for : BAX
# ../raw_data/data_stocks/BAX.csv Saved
# Finished
# Get Data for : BBBY
# ../raw_data/data_stocks/BBBY.csv Saved
# Finished
# Get Data for : BBCP
# ../raw_data/data_stocks/BBCP.csv Saved
# Finished
# Get Data for : BBGI
# ../raw_data/data_stocks/BBGI.csv Saved
# Finished
# Get Data for : BBSI
# ../raw_data/data_stocks/BBSI.csv Saved
# Finished
# Get Data for : BBW
# ../raw_data/data_stocks/BBW.csv Saved
# Finished
# Get Data for : BBY
# ../raw_data/data_stocks/BBY.csv Saved
# Finished
# Get Data for : BC
# ../raw_data/data_stocks/BC.csv Saved
# Finished
# Get Data for : BCBP
# ../raw_data/data_stocks/BCBP.csv Saved
# Finished
# Get Data for : BCC
# ../raw_data/data_stocks/BCC.csv Saved
# Finished
# Get Data for : BCEI
# - BCEI: No data found, symbol may be delisted
# ../raw_data/data_stocks/BCEI.csv Saved
# Finished
# Get Data for : BCLI
# ../raw_data/data_stocks/BCLI.csv Saved
# Finished
# Get Data for : BCO
# ../raw_data/data_stocks/BCO.csv Saved
# Finished
# Get Data for : BCOR
# ../raw_data/data_stocks/BCOR.csv Saved
# Finished
# Get Data for : BCOV
# ../raw_data/data_stocks/BCOV.csv Saved
# Finished
# Get Data for : BCPC
# ../raw_data/data_stocks/BCPC.csv Saved
# Finished
# Get Data for : BCRX
# ../raw_data/data_stocks/BCRX.csv Saved
# Finished
# Get Data for : BDC
# ../raw_data/data_stocks/BDC.csv Saved
# Finished
# Get Data for : BDGE
# - BDGE: No data found, symbol may be delisted
# ../raw_data/data_stocks/BDGE.csv Saved
# Finished
# Get Data for : BDL
# ../raw_data/data_stocks/BDL.csv Saved
# Finished
# Get Data for : BDN
# ../raw_data/data_stocks/BDN.csv Saved
# Finished
# Get Data for : BDSI
# ../raw_data/data_stocks/BDSI.csv Saved
# Finished
# Get Data for : BDX
# ../raw_data/data_stocks/BDX.csv Saved
# Finished
# Get Data for : BE
# ../raw_data/data_stocks/BE.csv Saved
# Finished
# Get Data for : BEAT
# ../raw_data/data_stocks/BEAT.csv Saved
# Finished
# Get Data for : BECN
# ../raw_data/data_stocks/BECN.csv Saved
# Finished
# Get Data for : BELFA
# ../raw_data/data_stocks/BELFA.csv Saved
# Finished
# Get Data for : BELFB
# ../raw_data/data_stocks/BELFB.csv Saved
# Finished
# Get Data for : BEN
# ../raw_data/data_stocks/BEN.csv Saved
# Finished
# Get Data for : BERY
# ../raw_data/data_stocks/BERY.csv Saved
# Finished
# Get Data for : BFAM
# ../raw_data/data_stocks/BFAM.csv Saved
# Finished
# Get Data for : BFIN
# ../raw_data/data_stocks/BFIN.csv Saved
# Finished
# Get Data for : BFS
# ../raw_data/data_stocks/BFS.csv Saved
# Finished
# Get Data for : BFST
# ../raw_data/data_stocks/BFST.csv Saved
# Finished
# Get Data for : BG
# ../raw_data/data_stocks/BG.csv Saved
# Finished
# Get Data for : BGCP
# ../raw_data/data_stocks/BGCP.csv Saved
# Finished
# Get Data for : BGFV
# ../raw_data/data_stocks/BGFV.csv Saved
# Finished
# Get Data for : BGS
# ../raw_data/data_stocks/BGS.csv Saved
# Finished
# Get Data for : BGSF
# ../raw_data/data_stocks/BGSF.csv Saved
# Finished
# Get Data for : BH
# ../raw_data/data_stocks/BH.csv Saved
# Finished
# Get Data for : BHB
# ../raw_data/data_stocks/BHB.csv Saved
# Finished
# Get Data for : BHE
# ../raw_data/data_stocks/BHE.csv Saved
# Finished
# Get Data for : BHF
# ../raw_data/data_stocks/BHF.csv Saved
# Finished
# Get Data for : BHLB
# ../raw_data/data_stocks/BHLB.csv Saved
# Finished
# Get Data for : BHR
# ../raw_data/data_stocks/BHR.csv Saved
# Finished
# Get Data for : BHVN
# ../raw_data/data_stocks/BHVN.csv Saved
# Finished
# Get Data for : BIG
# ../raw_data/data_stocks/BIG.csv Saved
# Finished
# Get Data for : BIIB
# ../raw_data/data_stocks/BIIB.csv Saved
# Finished
# Get Data for : BIO
# ../raw_data/data_stocks/BIO.csv Saved
# Finished
# Get Data for : BIOC
# ../raw_data/data_stocks/BIOC.csv Saved
# Finished
# Get Data for : BIOL
# ../raw_data/data_stocks/BIOL.csv Saved
# Finished
# Get Data for : BJ
# ../raw_data/data_stocks/BJ.csv Saved
# Finished
# Get Data for : BJRI
# ../raw_data/data_stocks/BJRI.csv Saved
# Finished
# Get Data for : BK
# ../raw_data/data_stocks/BK.csv Saved
# Finished
# Get Data for : BKD
# ../raw_data/data_stocks/BKD.csv Saved
# Finished
# Get Data for : BKE
# ../raw_data/data_stocks/BKE.csv Saved
# Finished
# Get Data for : BKH
# ../raw_data/data_stocks/BKH.csv Saved
# Finished
# Get Data for : BKI
# ../raw_data/data_stocks/BKI.csv Saved
# Finished
# Get Data for : BKNG
# ../raw_data/data_stocks/BKNG.csv Saved
# Finished
# Get Data for : BKSC
# ../raw_data/data_stocks/BKSC.csv Saved
# Finished
# Get Data for : BKTI
# ../raw_data/data_stocks/BKTI.csv Saved
# Finished
# Get Data for : BKU
# ../raw_data/data_stocks/BKU.csv Saved
# Finished
# Get Data for : BL
# ../raw_data/data_stocks/BL.csv Saved
# Finished
# Get Data for : BLBD
# ../raw_data/data_stocks/BLBD.csv Saved
# Finished
# Get Data for : BLCM
# ../raw_data/data_stocks/BLCM.csv Saved
# Finished
# Get Data for : BLD
# ../raw_data/data_stocks/BLD.csv Saved
# Finished
# Get Data for : BLDR
# ../raw_data/data_stocks/BLDR.csv Saved
# Finished
# Get Data for : BLFS
# ../raw_data/data_stocks/BLFS.csv Saved
# Finished
# Get Data for : BLK
# ../raw_data/data_stocks/BLK.csv Saved
# Finished
# Get Data for : BLKB
# ../raw_data/data_stocks/BLKB.csv Saved
# Finished
# Get Data for : BLL
# ../raw_data/data_stocks/BLL.csv Saved
# Finished
# Get Data for : BLMN
# ../raw_data/data_stocks/BLMN.csv Saved
# Finished
# Get Data for : BLUE
# ../raw_data/data_stocks/BLUE.csv Saved
# Finished
# Get Data for : BMCH
# - BMCH: No data found, symbol may be delisted
# ../raw_data/data_stocks/BMCH.csv Saved
# Finished
# Get Data for : BMI
# ../raw_data/data_stocks/BMI.csv Saved
# Finished
# Get Data for : BMRC
# ../raw_data/data_stocks/BMRC.csv Saved
# Finished
# Get Data for : BMRN
# ../raw_data/data_stocks/BMRN.csv Saved
# Finished
# Get Data for : BMTC
# - BMTC: No data found, symbol may be delisted
# ../raw_data/data_stocks/BMTC.csv Saved
# Finished
# Get Data for : BMY
# ../raw_data/data_stocks/BMY.csv Saved
# Finished
# Get Data for : BNED
# ../raw_data/data_stocks/BNED.csv Saved
# Finished
# Get Data for : BNFT
# ../raw_data/data_stocks/BNFT.csv Saved
# Finished
# Get Data for : BOCH
# - BOCH: No data found, symbol may be delisted
# ../raw_data/data_stocks/BOCH.csv Saved
# Finished
# Get Data for : BOH
# ../raw_data/data_stocks/BOH.csv Saved
# Finished
# Get Data for : BOKF
# ../raw_data/data_stocks/BOKF.csv Saved
# Finished
# Get Data for : BOMN
# ../raw_data/data_stocks/BOMN.csv Saved
# Finished
# Get Data for : BOOM
# ../raw_data/data_stocks/BOOM.csv Saved
# Finished
# Get Data for : BOOT
# ../raw_data/data_stocks/BOOT.csv Saved
# Finished
# Get Data for : BOTJ
# ../raw_data/data_stocks/BOTJ.csv Saved
# Finished
# Get Data for : BOX
# ../raw_data/data_stocks/BOX.csv Saved
# Finished
# Get Data for : BPFH
# - BPFH: No data found, symbol may be delisted
# ../raw_data/data_stocks/BPFH.csv Saved
# Finished
# Get Data for : BPMC
# ../raw_data/data_stocks/BPMC.csv Saved
# Finished
# Get Data for : BPOP
# ../raw_data/data_stocks/BPOP.csv Saved
# Finished
# Get Data for : BPRN
# ../raw_data/data_stocks/BPRN.csv Saved
# Finished
# Get Data for : BPTH
# ../raw_data/data_stocks/BPTH.csv Saved
# Finished
# Get Data for : BR
# ../raw_data/data_stocks/BR.csv Saved
# Finished
# Get Data for : BRC
# ../raw_data/data_stocks/BRC.csv Saved
# Finished
# Get Data for : BREW
# - BREW: No data found, symbol may be delisted
# ../raw_data/data_stocks/BREW.csv Saved
# Finished
# Get Data for : BRG
# ../raw_data/data_stocks/BRG.csv Saved
# Finished
# Get Data for : BRID
# ../raw_data/data_stocks/BRID.csv Saved
# Finished
# Get Data for : BRKL
# ../raw_data/data_stocks/BRKL.csv Saved
# Finished
# Get Data for : BRKR
# ../raw_data/data_stocks/BRKR.csv Saved
# Finished
# Get Data for : BRKS
# - BRKS: No data found, symbol may be delisted
# ../raw_data/data_stocks/BRKS.csv Saved
# Finished
# Get Data for : BRN
# ../raw_data/data_stocks/BRN.csv Saved
# Finished
# Get Data for : BRO
# ../raw_data/data_stocks/BRO.csv Saved
# Finished
# Get Data for : BRT
# ../raw_data/data_stocks/BRT.csv Saved
# Finished
# Get Data for : BRX
# ../raw_data/data_stocks/BRX.csv Saved
# Finished
# Get Data for : BRY
# ../raw_data/data_stocks/BRY.csv Saved
# Finished
# Get Data for : BSET
# ../raw_data/data_stocks/BSET.csv Saved
# Finished
# Get Data for : BSGM
# ../raw_data/data_stocks/BSGM.csv Saved
# Finished
# Get Data for : BSQR
# ../raw_data/data_stocks/BSQR.csv Saved
# Finished
# Get Data for : BSRR
# ../raw_data/data_stocks/BSRR.csv Saved
# Finished
# Get Data for : BSTC
# - BSTC: No data found, symbol may be delisted
# ../raw_data/data_stocks/BSTC.csv Saved
# Finished
# Get Data for : BSX
# ../raw_data/data_stocks/BSX.csv Saved
# Finished
# Get Data for : BTN
# ../raw_data/data_stocks/BTN.csv Saved
# Finished
# Get Data for : BTU
# ../raw_data/data_stocks/BTU.csv Saved
# Finished
# Get Data for : BURL
# ../raw_data/data_stocks/BURL.csv Saved
# Finished
# Get Data for : BUSE
# ../raw_data/data_stocks/BUSE.csv Saved
# Finished
# Get Data for : BV
# ../raw_data/data_stocks/BV.csv Saved
# Finished
# Get Data for : BW
# ../raw_data/data_stocks/BW.csv Saved
# Finished
# Get Data for : BWA
# ../raw_data/data_stocks/BWA.csv Saved
# Finished
# Get Data for : BWEN
# ../raw_data/data_stocks/BWEN.csv Saved
# Finished
# Get Data for : BWFG
# ../raw_data/data_stocks/BWFG.csv Saved
# Finished
# Get Data for : BWXT
# ../raw_data/data_stocks/BWXT.csv Saved
# Finished
# Get Data for : BXC
# ../raw_data/data_stocks/BXC.csv Saved
# Finished
# Get Data for : BXMT
# ../raw_data/data_stocks/BXMT.csv Saved
# Finished
# Get Data for : BXP
# ../raw_data/data_stocks/BXP.csv Saved
# Finished
# Get Data for : BXS
# - BXS: No data found, symbol may be delisted
# ../raw_data/data_stocks/BXS.csv Saved
# Finished
# Get Data for : BY
# ../raw_data/data_stocks/BY.csv Saved
# Finished
# Get Data for : BYD
# ../raw_data/data_stocks/BYD.csv Saved
# Finished
# Get Data for : BYFC
# ../raw_data/data_stocks/BYFC.csv Saved
# Finished
# Get Data for : BYND
# ../raw_data/data_stocks/BYND.csv Saved
# Finished
# Get Data for : BZH
# ../raw_data/data_stocks/BZH.csv Saved
# Finished
# Get Data for : C
# ../raw_data/data_stocks/C.csv Saved
# Finished
# Get Data for : CABO
# ../raw_data/data_stocks/CABO.csv Saved
# Finished
# Get Data for : CAC
# ../raw_data/data_stocks/CAC.csv Saved
# Finished
# Get Data for : CACC
# ../raw_data/data_stocks/CACC.csv Saved
# Finished
# Get Data for : CACI
# ../raw_data/data_stocks/CACI.csv Saved
# Finished
# Get Data for : CADE
# ../raw_data/data_stocks/CADE.csv Saved
# Finished
# Get Data for : CAG
# ../raw_data/data_stocks/CAG.csv Saved
# Finished
# Get Data for : CAH
# ../raw_data/data_stocks/CAH.csv Saved
# Finished
# Get Data for : CAI
# - CAI: No data found, symbol may be delisted
# ../raw_data/data_stocks/CAI.csv Saved
# Finished
# Get Data for : CAKE
# ../raw_data/data_stocks/CAKE.csv Saved
# Finished
# Get Data for : CAL
# ../raw_data/data_stocks/CAL.csv Saved
# Finished
# Get Data for : CALA
# ../raw_data/data_stocks/CALA.csv Saved
# Finished
# Get Data for : CALM
# ../raw_data/data_stocks/CALM.csv Saved
# Finished
# Get Data for : CALX
# ../raw_data/data_stocks/CALX.csv Saved
# Finished
# Get Data for : CAMP
# ../raw_data/data_stocks/CAMP.csv Saved
# Finished
# Get Data for : CAPR
# ../raw_data/data_stocks/CAPR.csv Saved
# Finished
# Get Data for : CAR
# ../raw_data/data_stocks/CAR.csv Saved
# Finished
# Get Data for : CARA
# ../raw_data/data_stocks/CARA.csv Saved
# Finished
# Get Data for : CARG
# ../raw_data/data_stocks/CARG.csv Saved
# Finished
# Get Data for : CARS
# ../raw_data/data_stocks/CARS.csv Saved
# Finished
# Get Data for : CASA
# ../raw_data/data_stocks/CASA.csv Saved
# Finished
# Get Data for : CASH
# ../raw_data/data_stocks/CASH.csv Saved
# Finished
# Get Data for : CASI
# ../raw_data/data_stocks/CASI.csv Saved
# Finished
# Get Data for : CASS
# ../raw_data/data_stocks/CASS.csv Saved
# Finished
# Get Data for : CASY
# ../raw_data/data_stocks/CASY.csv Saved
# Finished
# Get Data for : CAT
# ../raw_data/data_stocks/CAT.csv Saved
# Finished
# Get Data for : CATB
# - CATB: No data found, symbol may be delisted
# ../raw_data/data_stocks/CATB.csv Saved
# Finished
# Get Data for : CATC
# ../raw_data/data_stocks/CATC.csv Saved
# Finished
# Get Data for : CATM
# - CATM: No data found, symbol may be delisted
# ../raw_data/data_stocks/CATM.csv Saved
# Finished
# Get Data for : CATO
# ../raw_data/data_stocks/CATO.csv Saved
# Finished
# Get Data for : CATS
# - CATS: No data found, symbol may be delisted
# ../raw_data/data_stocks/CATS.csv Saved
# Finished
# Get Data for : CATY
# ../raw_data/data_stocks/CATY.csv Saved
# Finished
# Get Data for : CB
# ../raw_data/data_stocks/CB.csv Saved
# Finished
# Get Data for : CBAN
# ../raw_data/data_stocks/CBAN.csv Saved
# Finished
# Get Data for : CBAY
# ../raw_data/data_stocks/CBAY.csv Saved
# Finished
# Get Data for : CBB
# - CBB: No data found, symbol may be delisted
# ../raw_data/data_stocks/CBB.csv Saved
# Finished
# Get Data for : CBFV
# ../raw_data/data_stocks/CBFV.csv Saved
# Finished
# Get Data for : CBIO
# ../raw_data/data_stocks/CBIO.csv Saved
# Finished
# Get Data for : CBLI
# - CBLI: No data found, symbol may be delisted
# ../raw_data/data_stocks/CBLI.csv Saved
# Finished
# Get Data for : CBMG
# - CBMG: No data found, symbol may be delisted
# ../raw_data/data_stocks/CBMG.csv Saved
# Finished
# Get Data for : CBOE
# ../raw_data/data_stocks/CBOE.csv Saved
# Finished
# Get Data for : CBRE
# ../raw_data/data_stocks/CBRE.csv Saved
# Finished
# Get Data for : CBRL
# ../raw_data/data_stocks/CBRL.csv Saved
# Finished
# Get Data for : CBSH
# ../raw_data/data_stocks/CBSH.csv Saved
# Finished
# Get Data for : CBT
# ../raw_data/data_stocks/CBT.csv Saved
# Finished
# Get Data for : CBTX
# ../raw_data/data_stocks/CBTX.csv Saved
# Finished
# Get Data for : CBU
# ../raw_data/data_stocks/CBU.csv Saved
# Finished
# Get Data for : CBZ
# ../raw_data/data_stocks/CBZ.csv Saved
# Finished
# Get Data for : CC
# ../raw_data/data_stocks/CC.csv Saved
# Finished
# Get Data for : CCBG
# ../raw_data/data_stocks/CCBG.csv Saved
# Finished
# Get Data for : CCF
# ../raw_data/data_stocks/CCF.csv Saved
# Finished
# Get Data for : CCI
# ../raw_data/data_stocks/CCI.csv Saved
# Finished
# Get Data for : CCK
# ../raw_data/data_stocks/CCK.csv Saved
# Finished
# Get Data for : CCL
# ../raw_data/data_stocks/CCL.csv Saved
# Finished
# Get Data for : CCMP
# ../raw_data/data_stocks/CCMP.csv Saved
# Finished
# Get Data for : CCNE
# ../raw_data/data_stocks/CCNE.csv Saved
# Finished
# Get Data for : CCO
# ../raw_data/data_stocks/CCO.csv Saved
# Finished
# Get Data for : CCOI
# ../raw_data/data_stocks/CCOI.csv Saved
# Finished
# Get Data for : CCRN
# ../raw_data/data_stocks/CCRN.csv Saved
# Finished
# Get Data for : CCS
# ../raw_data/data_stocks/CCS.csv Saved
# Finished
# Get Data for : CCXI
# ../raw_data/data_stocks/CCXI.csv Saved
# Finished
# Get Data for : CDAY
# ../raw_data/data_stocks/CDAY.csv Saved
# Finished
# Get Data for : CDE
# ../raw_data/data_stocks/CDE.csv Saved
# Finished
# Get Data for : CDEV
# ../raw_data/data_stocks/CDEV.csv Saved
# Finished
# Get Data for : CDK
# ../raw_data/data_stocks/CDK.csv Saved
# Finished
# Get Data for : CDLX
# ../raw_data/data_stocks/CDLX.csv Saved
# Finished
# Get Data for : CDMO
# ../raw_data/data_stocks/CDMO.csv Saved
# Finished
# Get Data for : CDNA
# ../raw_data/data_stocks/CDNA.csv Saved
# Finished
# Get Data for : CDNS
# ../raw_data/data_stocks/CDNS.csv Saved
# Finished
# Get Data for : CDR
# ../raw_data/data_stocks/CDR.csv Saved
# Finished
# Get Data for : CDTX
# ../raw_data/data_stocks/CDTX.csv Saved
# Finished
# Get Data for : CDW
# ../raw_data/data_stocks/CDW.csv Saved
# Finished
# Get Data for : CDXC
# ../raw_data/data_stocks/CDXC.csv Saved
# Finished
# Get Data for : CDXS
# ../raw_data/data_stocks/CDXS.csv Saved
# Finished
# Get Data for : CDZI
# ../raw_data/data_stocks/CDZI.csv Saved
# Finished
# Get Data for : CE
# ../raw_data/data_stocks/CE.csv Saved
# Finished
# Get Data for : CECE
# ../raw_data/data_stocks/CECE.csv Saved
# Finished
# Get Data for : CEI
# ../raw_data/data_stocks/CEI.csv Saved
# Finished
# Get Data for : CEIX
# ../raw_data/data_stocks/CEIX.csv Saved
# Finished
# Get Data for : CELC
# ../raw_data/data_stocks/CELC.csv Saved
# Finished
# Get Data for : CELH
# ../raw_data/data_stocks/CELH.csv Saved
# Finished
# Get Data for : CEMI
# ../raw_data/data_stocks/CEMI.csv Saved
# Finished
# Get Data for : CENT
# ../raw_data/data_stocks/CENT.csv Saved
# Finished
# Get Data for : CENTA
# ../raw_data/data_stocks/CENTA.csv Saved
# Finished
# Get Data for : CENX
# ../raw_data/data_stocks/CENX.csv Saved
# Finished
# Get Data for : CERC
# - CERC: No data found, symbol may be delisted
# ../raw_data/data_stocks/CERC.csv Saved
# Finished
# Get Data for : CERN
# ../raw_data/data_stocks/CERN.csv Saved
# Finished
# Get Data for : CERS
# ../raw_data/data_stocks/CERS.csv Saved
# Finished
# Get Data for : CETV
# - CETV: No data found, symbol may be delisted
# ../raw_data/data_stocks/CETV.csv Saved
# Finished
# Get Data for : CETX
# ../raw_data/data_stocks/CETX.csv Saved
# Finished
# Get Data for : CEVA
# ../raw_data/data_stocks/CEVA.csv Saved
# Finished
# Get Data for : CF
# ../raw_data/data_stocks/CF.csv Saved
# Finished
# Get Data for : CFBK
# ../raw_data/data_stocks/CFBK.csv Saved
# Finished
# Get Data for : CFFI
# ../raw_data/data_stocks/CFFI.csv Saved
# Finished
# Get Data for : CFFN
# ../raw_data/data_stocks/CFFN.csv Saved
# Finished
# Get Data for : CFG
# ../raw_data/data_stocks/CFG.csv Saved
# Finished
# Get Data for : CFMS
# ../raw_data/data_stocks/CFMS.csv Saved
# Finished
# Get Data for : CFR
# ../raw_data/data_stocks/CFR.csv Saved
# Finished
# Get Data for : CFX
# ../raw_data/data_stocks/CFX.csv Saved
# Finished
# Get Data for : CGIX
# - CGIX: No data found, symbol may be delisted
# ../raw_data/data_stocks/CGIX.csv Saved
# Finished
# Get Data for : CGNX
# ../raw_data/data_stocks/CGNX.csv Saved
# Finished
# Get Data for : CHAP
# - CHAP: No data found, symbol may be delisted
# ../raw_data/data_stocks/CHAP.csv Saved
# Finished
# Get Data for : CHCI
# ../raw_data/data_stocks/CHCI.csv Saved
# Finished
# Get Data for : CHCO
# ../raw_data/data_stocks/CHCO.csv Saved
# Finished
# Get Data for : CHCT
# ../raw_data/data_stocks/CHCT.csv Saved
# Finished
# Get Data for : CHD
# ../raw_data/data_stocks/CHD.csv Saved
# Finished
# Get Data for : CHDN
# ../raw_data/data_stocks/CHDN.csv Saved
# Finished
# Get Data for : CHE
# ../raw_data/data_stocks/CHE.csv Saved
# Finished
# Get Data for : CHEF
# ../raw_data/data_stocks/CHEF.csv Saved
# Finished
# Get Data for : CHGG
# ../raw_data/data_stocks/CHGG.csv Saved
# Finished
# Get Data for : CHH
# ../raw_data/data_stocks/CHH.csv Saved
# Finished
# Get Data for : CHK
# ../raw_data/data_stocks/CHK.csv Saved
# Finished
# Get Data for : CHMA
# ../raw_data/data_stocks/CHMA.csv Saved
# Finished
# Get Data for : CHMG
# ../raw_data/data_stocks/CHMG.csv Saved
# Finished
# Get Data for : CHMI
# ../raw_data/data_stocks/CHMI.csv Saved
# Finished
# Get Data for : CHRS
# ../raw_data/data_stocks/CHRS.csv Saved
# Finished
# Get Data for : CHRW
# ../raw_data/data_stocks/CHRW.csv Saved
# Finished
# Get Data for : CHS
# ../raw_data/data_stocks/CHS.csv Saved
# Finished
# Get Data for : CHTR
# ../raw_data/data_stocks/CHTR.csv Saved
# Finished
# Get Data for : CHUY
# ../raw_data/data_stocks/CHUY.csv Saved
# Finished
# Get Data for : CI
# ../raw_data/data_stocks/CI.csv Saved
# Finished
# Get Data for : CIA
# ../raw_data/data_stocks/CIA.csv Saved
# Finished
# Get Data for : CIDM
# ../raw_data/data_stocks/CIDM.csv Saved
# Finished
# Get Data for : CIEN
# ../raw_data/data_stocks/CIEN.csv Saved
# Finished
# Get Data for : CIM
# ../raw_data/data_stocks/CIM.csv Saved
# Finished
# Get Data for : CINF
# ../raw_data/data_stocks/CINF.csv Saved
# Finished
# Get Data for : CIO
# ../raw_data/data_stocks/CIO.csv Saved
# Finished
# Get Data for : CIR
# ../raw_data/data_stocks/CIR.csv Saved
# Finished
# Get Data for : CIT
# - CIT: No data found, symbol may be delisted
# ../raw_data/data_stocks/CIT.csv Saved
# Finished
# Get Data for : CIVB
# ../raw_data/data_stocks/CIVB.csv Saved
# Finished
# Get Data for : CIX
# ../raw_data/data_stocks/CIX.csv Saved
# Finished
# Get Data for : CIZN
# ../raw_data/data_stocks/CIZN.csv Saved
# Finished
# Get Data for : CKH
# - CKH: No data found, symbol may be delisted
# ../raw_data/data_stocks/CKH.csv Saved
# Finished
# Get Data for : CKX
# ../raw_data/data_stocks/CKX.csv Saved
# Finished
# Get Data for : CL
# ../raw_data/data_stocks/CL.csv Saved
# Finished
# Get Data for : CLAR
# ../raw_data/data_stocks/CLAR.csv Saved
# Finished
# Get Data for : CLB
# ../raw_data/data_stocks/CLB.csv Saved
# Finished
# Get Data for : CLBS
# ../raw_data/data_stocks/CLBS.csv Saved
# Finished
# Get Data for : CLCT
# - CLCT: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLCT.csv Saved
# Finished
# Get Data for : CLDR
# - CLDR: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLDR.csv Saved
# Finished
# Get Data for : CLDT
# ../raw_data/data_stocks/CLDT.csv Saved
# Finished
# Get Data for : CLDX
# ../raw_data/data_stocks/CLDX.csv Saved
# Finished
# Get Data for : CLF
# ../raw_data/data_stocks/CLF.csv Saved
# Finished
# Get Data for : CLFD
# ../raw_data/data_stocks/CLFD.csv Saved
# Finished
# Get Data for : CLGX
# - CLGX: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLGX.csv Saved
# Finished
# Get Data for : CLH
# ../raw_data/data_stocks/CLH.csv Saved
# Finished
# Get Data for : CLI
# - CLI: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLI.csv Saved
# Finished
# Get Data for : CLIR
# ../raw_data/data_stocks/CLIR.csv Saved
# Finished
# Get Data for : CLNC
# - CLNC: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLNC.csv Saved
# Finished
# Get Data for : CLNE
# ../raw_data/data_stocks/CLNE.csv Saved
# Finished
# Get Data for : CLNY
# - CLNY: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLNY.csv Saved
# Finished
# Get Data for : CLPR
# ../raw_data/data_stocks/CLPR.csv Saved
# Finished
# Get Data for : CLR
# ../raw_data/data_stocks/CLR.csv Saved
# Finished
# Get Data for : CLRB
# ../raw_data/data_stocks/CLRB.csv Saved
# Finished
# Get Data for : CLRO
# ../raw_data/data_stocks/CLRO.csv Saved
# Finished
# Get Data for : CLSN
# ../raw_data/data_stocks/CLSN.csv Saved
# Finished
# Get Data for : CLUB
# - CLUB: No data found, symbol may be delisted
# ../raw_data/data_stocks/CLUB.csv Saved
# Finished
# Get Data for : CLVS
# ../raw_data/data_stocks/CLVS.csv Saved
# Finished
# Get Data for : CLW
# ../raw_data/data_stocks/CLW.csv Saved
# Finished
# Get Data for : CLX
# ../raw_data/data_stocks/CLX.csv Saved
# Finished
# Get Data for : CLXT
# ../raw_data/data_stocks/CLXT.csv Saved
# Finished
# Get Data for : CMA
# ../raw_data/data_stocks/CMA.csv Saved
# Finished
# Get Data for : CMC
# ../raw_data/data_stocks/CMC.csv Saved
# Finished
# Get Data for : CMCO
# ../raw_data/data_stocks/CMCO.csv Saved
# Finished
# Get Data for : CMCSA
# ../raw_data/data_stocks/CMCSA.csv Saved
# Finished
# Get Data for : CMCT
# ../raw_data/data_stocks/CMCT.csv Saved
# Finished
# Get Data for : CMD
# - CMD: No data found, symbol may be delisted
# ../raw_data/data_stocks/CMD.csv Saved
# Finished
# Get Data for : CME
# ../raw_data/data_stocks/CME.csv Saved
# Finished
# Get Data for : CMG
# ../raw_data/data_stocks/CMG.csv Saved
# Finished
# Get Data for : CMI
# ../raw_data/data_stocks/CMI.csv Saved
# Finished
# Get Data for : CMO
# - CMO: No data found, symbol may be delisted
# ../raw_data/data_stocks/CMO.csv Saved
# Finished
# Get Data for : CMP
# ../raw_data/data_stocks/CMP.csv Saved
# Finished
# Get Data for : CMRX
# ../raw_data/data_stocks/CMRX.csv Saved
# Finished
# Get Data for : CMS
# ../raw_data/data_stocks/CMS.csv Saved
# Finished
# Get Data for : CMT
# ../raw_data/data_stocks/CMT.csv Saved
# Finished
# Get Data for : CMTL
# ../raw_data/data_stocks/CMTL.csv Saved
# Finished
# Get Data for : CNA
# ../raw_data/data_stocks/CNA.csv Saved
# Finished
# Get Data for : CNBKA
# - CNBKA: No data found, symbol may be delisted
# ../raw_data/data_stocks/CNBKA.csv Saved
# Finished
# Get Data for : CNC
# ../raw_data/data_stocks/CNC.csv Saved
# Finished
# Get Data for : CNCE
# ../raw_data/data_stocks/CNCE.csv Saved
# Finished
# Get Data for : CNDT
# ../raw_data/data_stocks/CNDT.csv Saved
# Finished
# Get Data for : CNFR
# ../raw_data/data_stocks/CNFR.csv Saved
# Finished
# Get Data for : CNK
# ../raw_data/data_stocks/CNK.csv Saved
# Finished
# Get Data for : CNMD
# ../raw_data/data_stocks/CNMD.csv Saved
# Finished
# Get Data for : CNNE
# ../raw_data/data_stocks/CNNE.csv Saved
# Finished
# Get Data for : CNO
# ../raw_data/data_stocks/CNO.csv Saved
# Finished
# Get Data for : CNOB
# ../raw_data/data_stocks/CNOB.csv Saved
# Finished
# Get Data for : CNP
# ../raw_data/data_stocks/CNP.csv Saved
# Finished
# Get Data for : CNS
# ../raw_data/data_stocks/CNS.csv Saved
# Finished
# Get Data for : CNSL
# ../raw_data/data_stocks/CNSL.csv Saved
# Finished
# Get Data for : CNTY
# ../raw_data/data_stocks/CNTY.csv Saved
# Finished
# Get Data for : CNX
# ../raw_data/data_stocks/CNX.csv Saved
# Finished
# Get Data for : CNXN
# ../raw_data/data_stocks/CNXN.csv Saved
# Finished
# Get Data for : CODA
# ../raw_data/data_stocks/CODA.csv Saved
# Finished
# Get Data for : COF
# ../raw_data/data_stocks/COF.csv Saved
# Finished
# Get Data for : COG
# ...
# Finished
# Get Data for : VAPO
# ../raw_data/data_stocks/VAPO.csv Saved
# Finished
# Get Data for : VREX
# ../raw_data/data_stocks/VREX.csv Saved
# Finished
# Get Data for : VAR
# - VAR: No data found, symbol may be delisted
# ../raw_data/data_stocks/VAR.csv Saved
# Finished
# Get Data for : VRNS
# ../raw_data/data_stocks/VRNS.csv Saved
# Finished
# Get Data for : VXRT
# ../raw_data/data_stocks/VXRT.csv Saved
# Finished
# Get Data for : VBIV
# ../raw_data/data_stocks/VBIV.csv Saved
# Finished
# Get Data for : VGR
# ../raw_data/data_stocks/VGR.csv Saved
# Finished
# Get Data for : VEC
# ../raw_data/data_stocks/VEC.csv Saved
# Finished
# Get Data for : VECO
# ../raw_data/data_stocks/VECO.csv Saved
# Finished
# Get Data for : VEEV
# ../raw_data/data_stocks/VEEV.csv Saved
# Finished
# Get Data for : VNTR
# ../raw_data/data_stocks/VNTR.csv Saved
# Finished
# Get Data for : VTR
# ../raw_data/data_stocks/VTR.csv Saved
# Finished
# Get Data for : VNE
# ../raw_data/data_stocks/VNE.csv Saved
# Finished
# Get Data for : VRA
# ../raw_data/data_stocks/VRA.csv Saved
# Finished
# Get Data for : VCYT
# ../raw_data/data_stocks/VCYT.csv Saved
# Finished
# Get Data for : VSTM
# ../raw_data/data_stocks/VSTM.csv Saved
# Finished
# Get Data for : VER
# - VER: No data found, symbol may be delisted
# ../raw_data/data_stocks/VER.csv Saved
# Finished
# Get Data for : VCEL
# ../raw_data/data_stocks/VCEL.csv Saved
# Finished
# Get Data for : VRNT
# ../raw_data/data_stocks/VRNT.csv Saved
# Finished
# Get Data for : VRSN
# ../raw_data/data_stocks/VRSN.csv Saved
# Finished
# Get Data for : VRSK
# ../raw_data/data_stocks/VRSK.csv Saved
# Finished
# Get Data for : VBTX
# ../raw_data/data_stocks/VBTX.csv Saved
# Finished
# Get Data for : VRTV
# ../raw_data/data_stocks/VRTV.csv Saved
# Finished
# Get Data for : VERI
# ../raw_data/data_stocks/VERI.csv Saved
# Finished
# Get Data for : VZ
# ../raw_data/data_stocks/VZ.csv Saved
# Finished
# Get Data for : VRML
# - VRML: No data found, symbol may be delisted
# ../raw_data/data_stocks/VRML.csv Saved
# Finished
# Get Data for : VRRM
# ../raw_data/data_stocks/VRRM.csv Saved
# Finished
# Get Data for : VRS
# ../raw_data/data_stocks/VRS.csv Saved
# Finished
# Get Data for : VTNR
# ../raw_data/data_stocks/VTNR.csv Saved
# Finished
# Get Data for : VRTX
# ../raw_data/data_stocks/VRTX.csv Saved
# Finished
# Get Data for : VERU
# ../raw_data/data_stocks/VERU.csv Saved
# Finished
# Get Data for : VFC
# ../raw_data/data_stocks/VFC.csv Saved
# Finished
# Get Data for : CBS
# - CBS: No data found, symbol may be delisted
# ../raw_data/data_stocks/CBS.csv Saved
# Finished
# Get Data for : VVI
# ../raw_data/data_stocks/VVI.csv Saved
# Finished
# Get Data for : VSAT
# ../raw_data/data_stocks/VSAT.csv Saved
# Finished
# Get Data for : VIAV
# ../raw_data/data_stocks/VIAV.csv Saved
# Finished
# Get Data for : VICL
# - VICL: No data found, symbol may be delisted
# ../raw_data/data_stocks/VICL.csv Saved
# Finished
# Get Data for : VICI
# ../raw_data/data_stocks/VICI.csv Saved
# Finished
# Get Data for : VICR
# ../raw_data/data_stocks/VICR.csv Saved
# Finished
# Get Data for : VCTR
# ../raw_data/data_stocks/VCTR.csv Saved
# Finished
# Get Data for : VRAY
# ../raw_data/data_stocks/VRAY.csv Saved
# Finished
# Get Data for : VKTX
# ../raw_data/data_stocks/VKTX.csv Saved
# Finished
# Get Data for : VBFC
# ../raw_data/data_stocks/VBFC.csv Saved
# Finished
# Get Data for : VLGEA
# ../raw_data/data_stocks/VLGEA.csv Saved
# Finished
# Get Data for : VNCE
# ../raw_data/data_stocks/VNCE.csv Saved
# Finished
# Get Data for : VIRC
# ../raw_data/data_stocks/VIRC.csv Saved
# Finished
# Get Data for : VHC
# ../raw_data/data_stocks/VHC.csv Saved
# Finished
# Get Data for : VIRT
# ../raw_data/data_stocks/VIRT.csv Saved
# Finished
# Get Data for : VRTS
# ../raw_data/data_stocks/VRTS.csv Saved
# Finished
# Get Data for : VRTU
# - VRTU: No data found, symbol may be delisted
# ../raw_data/data_stocks/VRTU.csv Saved
# Finished
# Get Data for : V
# ../raw_data/data_stocks/V.csv Saved
# Finished
# Get Data for : VSH
# ../raw_data/data_stocks/VSH.csv Saved
# Finished
# Get Data for : VPG
# ../raw_data/data_stocks/VPG.csv Saved
# Finished
# Get Data for : VISL
# ../raw_data/data_stocks/VISL.csv Saved
# Finished
# Get Data for : VSTO
# ../raw_data/data_stocks/VSTO.csv Saved
# Finished
# Get Data for : VC
# ../raw_data/data_stocks/VC.csv Saved
# Finished
# Get Data for : VST
# ../raw_data/data_stocks/VST.csv Saved
# Finished
# Get Data for : VSI
# - VSI: No data found, symbol may be delisted
# ../raw_data/data_stocks/VSI.csv Saved
# Finished
# Get Data for : VSLR
# - VSLR: No data found, symbol may be delisted
# ../raw_data/data_stocks/VSLR.csv Saved
# Finished
# Get Data for : VVUS
# - VVUS: No data found, symbol may be delisted
# ../raw_data/data_stocks/VVUS.csv Saved
# Finished
# Get Data for : VMW
# ../raw_data/data_stocks/VMW.csv Saved
# Finished
# Get Data for : VCRA
# ../raw_data/data_stocks/VCRA.csv Saved
# Finished
# Get Data for : VNRX
# ../raw_data/data_stocks/VNRX.csv Saved
# Finished
# Get Data for : VISI
# - VISI: No data found, symbol may be delisted
# ../raw_data/data_stocks/VISI.csv Saved
# Finished
# Get Data for : VG
# ../raw_data/data_stocks/VG.csv Saved
# Finished
# Get Data for : VNO
# ../raw_data/data_stocks/VNO.csv Saved
# Finished
# Get Data for : VOXX
# ../raw_data/data_stocks/VOXX.csv Saved
# Finished
# Get Data for : VOYA
# ../raw_data/data_stocks/VOYA.csv Saved
# Finished
# Get Data for : VYGR
# ../raw_data/data_stocks/VYGR.csv Saved
# Finished
# Get Data for : VSEC
# ../raw_data/data_stocks/VSEC.csv Saved
# Finished
# Get Data for : VTVT
# ../raw_data/data_stocks/VTVT.csv Saved
# Finished
# Get Data for : VMC
# ../raw_data/data_stocks/VMC.csv Saved
# Finished
# Get Data for : VUZI
# ../raw_data/data_stocks/VUZI.csv Saved
# Finished
# Get Data for : WTI
# ../raw_data/data_stocks/WTI.csv Saved
# Finished
# Get Data for : WPC
# ../raw_data/data_stocks/WPC.csv Saved
# Finished
# Get Data for : WRB
# ../raw_data/data_stocks/WRB.csv Saved
# Finished
# Get Data for : GRA
# - GRA: No data found, symbol may be delisted
# ../raw_data/data_stocks/GRA.csv Saved
# Finished
# Get Data for : GWW
# ../raw_data/data_stocks/GWW.csv Saved
# Finished
# Get Data for : WNC
# ../raw_data/data_stocks/WNC.csv Saved
# Finished
# Get Data for : WBC
# - WBC: No data found, symbol may be delisted
# ../raw_data/data_stocks/WBC.csv Saved
# Finished
# Get Data for : WDR
# - WDR: No data found, symbol may be delisted
# ../raw_data/data_stocks/WDR.csv Saved
# Finished
# Get Data for : WTRH
# ../raw_data/data_stocks/WTRH.csv Saved
# Finished
# Get Data for : WBA
# ../raw_data/data_stocks/WBA.csv Saved
# Finished
# Get Data for : WD
# ../raw_data/data_stocks/WD.csv Saved
# Finished
# Get Data for : WMT
# ../raw_data/data_stocks/WMT.csv Saved
# Finished
# Get Data for : HCC
# ../raw_data/data_stocks/HCC.csv Saved
# Finished
# Get Data for : WAFD
# ../raw_data/data_stocks/WAFD.csv Saved
# Finished
# Get Data for : WPG
# - WPG: No data found, symbol may be delisted
# ../raw_data/data_stocks/WPG.csv Saved
# Finished
# Get Data for : WRE
# ../raw_data/data_stocks/WRE.csv Saved
# Finished
# Get Data for : WASH
# ../raw_data/data_stocks/WASH.csv Saved
# Finished
# Get Data for : WM
# ../raw_data/data_stocks/WM.csv Saved
# Finished
# Get Data for : WAT
# ../raw_data/data_stocks/WAT.csv Saved
# Finished
# Get Data for : WSBF
# ../raw_data/data_stocks/WSBF.csv Saved
# Finished
# Get Data for : WSO
# ../raw_data/data_stocks/WSO.csv Saved
# Finished
# Get Data for : WTS
# ../raw_data/data_stocks/WTS.csv Saved
# Finished
# Get Data for : WVE
# ../raw_data/data_stocks/WVE.csv Saved
# Finished
# Get Data for : W
# ../raw_data/data_stocks/W.csv Saved
# Finished
# Get Data for : WSTG
# ../raw_data/data_stocks/WSTG.csv Saved
# Finished
# Get Data for : WDFC
# ../raw_data/data_stocks/WDFC.csv Saved
# Finished
# Get Data for : WBS
# ../raw_data/data_stocks/WBS.csv Saved
# Finished
# Get Data for : WEC
# ../raw_data/data_stocks/WEC.csv Saved
# Finished
# Get Data for : WRI
# - WRI: No data found, symbol may be delisted
# ../raw_data/data_stocks/WRI.csv Saved
# Finished
# Get Data for : WMK
# ../raw_data/data_stocks/WMK.csv Saved
# Finished
# Get Data for : WBT
# ../raw_data/data_stocks/WBT.csv Saved
# Finished
# Get Data for : WCG
# - WCG: No data found, symbol may be delisted
# ../raw_data/data_stocks/WCG.csv Saved
# Finished
# Get Data for : WEBK
# - WEBK: No data found, symbol may be delisted
# ../raw_data/data_stocks/WEBK.csv Saved
# Finished
# Get Data for : WFC
# ../raw_data/data_stocks/WFC.csv Saved
# Finished
# Get Data for : WELL
# ../raw_data/data_stocks/WELL.csv Saved
# Finished
# Get Data for : WERN
# ../raw_data/data_stocks/WERN.csv Saved
# Finished
# Get Data for : WSBC
# ../raw_data/data_stocks/WSBC.csv Saved
# Finished
# Get Data for : WAIR
# - WAIR: No data found, symbol may be delisted
# ../raw_data/data_stocks/WAIR.csv Saved
# Finished
# Get Data for : WCC
# ../raw_data/data_stocks/WCC.csv Saved
# Finished
# Get Data for : WTBA
# ../raw_data/data_stocks/WTBA.csv Saved
# Finished
# Get Data for : WST
# ../raw_data/data_stocks/WST.csv Saved
# Finished
# Get Data for : WABC
# ../raw_data/data_stocks/WABC.csv Saved
# Finished
# Get Data for : WSTL
# ../raw_data/data_stocks/WSTL.csv Saved
# Finished
# Get Data for : WAL
# ../raw_data/data_stocks/WAL.csv Saved
# Finished
# Get Data for : WMC
# ../raw_data/data_stocks/WMC.csv Saved
# Finished
# Get Data for : WDC
# ../raw_data/data_stocks/WDC.csv Saved
# Finished
# Get Data for : WNEB
# ../raw_data/data_stocks/WNEB.csv Saved
# Finished
# Get Data for : WAB
# ../raw_data/data_stocks/WAB.csv Saved
# Finished
# Get Data for : WLK
# ../raw_data/data_stocks/WLK.csv Saved
# Finished
# Get Data for : WRK
# ../raw_data/data_stocks/WRK.csv Saved
# Finished
# Get Data for : WWR
# ../raw_data/data_stocks/WWR.csv Saved
# Finished
# Get Data for : WHG
# ../raw_data/data_stocks/WHG.csv Saved
# Finished
# Get Data for : WEX
# ../raw_data/data_stocks/WEX.csv Saved
# Finished
# Get Data for : WEYS
# ../raw_data/data_stocks/WEYS.csv Saved
# Finished
# Get Data for : WY
# ../raw_data/data_stocks/WY.csv Saved
# Finished
# Get Data for : WHLR
# ../raw_data/data_stocks/WHLR.csv Saved
# Finished
# Get Data for : WHR
# ../raw_data/data_stocks/WHR.csv Saved
# Finished
# Get Data for : WTM
# ../raw_data/data_stocks/WTM.csv Saved
# Finished
# Get Data for : WSR
# ../raw_data/data_stocks/WSR.csv Saved
# Finished
# Get Data for : WLL
# ../raw_data/data_stocks/WLL.csv Saved
# Finished
# Get Data for : WOW
# ../raw_data/data_stocks/WOW.csv Saved
# Finished
# Get Data for : WYY
# ../raw_data/data_stocks/WYY.csv Saved
# Finished
# Get Data for : WHLM
# ../raw_data/data_stocks/WHLM.csv Saved
# Finished
# Get Data for : WVVI
# ../raw_data/data_stocks/WVVI.csv Saved
# Finished
# Get Data for : WLDN
# ../raw_data/data_stocks/WLDN.csv Saved
# Finished
# Get Data for : WLH
# - WLH: No data found, symbol may be delisted
# ../raw_data/data_stocks/WLH.csv Saved
# Finished
# Get Data for : WSM
# ../raw_data/data_stocks/WSM.csv Saved
# Finished
# Get Data for : WLFC
# ../raw_data/data_stocks/WLFC.csv Saved
# Finished
# Get Data for : WLTW
# - WLTW: No data found, symbol may be delisted
# ../raw_data/data_stocks/WLTW.csv Saved
# Finished
# Get Data for : WSC
# ../raw_data/data_stocks/WSC.csv Saved
# Finished
# Get Data for : WING
# ../raw_data/data_stocks/WING.csv Saved
# Finished
# Get Data for : WINA
# ../raw_data/data_stocks/WINA.csv Saved
# Finished
# Get Data for : WGO
# ../raw_data/data_stocks/WGO.csv Saved
# Finished
# Get Data for : WTFC
# ../raw_data/data_stocks/WTFC.csv Saved
# Finished
# Get Data for : WTT
# ../raw_data/data_stocks/WTT.csv Saved
# Finished
# Get Data for : WETF
# ../raw_data/data_stocks/WETF.csv Saved
# Finished
# Get Data for : WWW
# ../raw_data/data_stocks/WWW.csv Saved
# Finished
# Get Data for : WWD
# ../raw_data/data_stocks/WWD.csv Saved
# Finished
# Get Data for : WDAY
# ../raw_data/data_stocks/WDAY.csv Saved
# Finished
# Get Data for : WKHS
# ../raw_data/data_stocks/WKHS.csv Saved
# Finished
# Get Data for : WK
# ../raw_data/data_stocks/WK.csv Saved
# Finished
# Get Data for : WRLD
# ../raw_data/data_stocks/WRLD.csv Saved
# Finished
# Get Data for : INT
# ../raw_data/data_stocks/INT.csv Saved
# Finished
# Get Data for : WWE
# ../raw_data/data_stocks/WWE.csv Saved
# Finished
# Get Data for : WOR
# ../raw_data/data_stocks/WOR.csv Saved
# Finished
# Get Data for : WPX
# - WPX: No data found, symbol may be delisted
# ../raw_data/data_stocks/WPX.csv Saved
# Finished
# Get Data for : WRTC
# - WRTC: No data found, symbol may be delisted
# ../raw_data/data_stocks/WRTC.csv Saved
# Finished
# Get Data for : WMGI
# - WMGI: No data found, symbol may be delisted
# ../raw_data/data_stocks/WMGI.csv Saved
# Finished
# Get Data for : WSFS
# ../raw_data/data_stocks/WSFS.csv Saved
# Finished
# Get Data for : WVFC
# ../raw_data/data_stocks/WVFC.csv Saved
# Finished
# Get Data for : WW
# ../raw_data/data_stocks/WW.csv Saved
# Finished
# Get Data for : WYND
# - WYND: No data found, symbol may be delisted
# ../raw_data/data_stocks/WYND.csv Saved
# Finished
# Get Data for : WH
# ../raw_data/data_stocks/WH.csv Saved
# Finished
# Get Data for : WYNN
# ../raw_data/data_stocks/WYNN.csv Saved
# Finished
# Get Data for : XFOR
# ../raw_data/data_stocks/XFOR.csv Saved
# Finished
# Get Data for : XBIT
# ../raw_data/data_stocks/XBIT.csv Saved
# Finished
# Get Data for : XELB
# ../raw_data/data_stocks/XELB.csv Saved
# Finished
# Get Data for : XEL
# ../raw_data/data_stocks/XEL.csv Saved
# Finished
# Get Data for : XNCR
# ../raw_data/data_stocks/XNCR.csv Saved
# Finished
# Get Data for : XHR
# ../raw_data/data_stocks/XHR.csv Saved
# Finished
# Get Data for : XERS
# ../raw_data/data_stocks/XERS.csv Saved
# Finished
# Get Data for : XRX
# ../raw_data/data_stocks/XRX.csv Saved
# Finished
# Get Data for : XLNX
# - XLNX: No data found, symbol may be delisted
# ../raw_data/data_stocks/XLNX.csv Saved
# Finished
# Get Data for : XOMA
# ../raw_data/data_stocks/XOMA.csv Saved
# Finished
# Get Data for : XPER
# ../raw_data/data_stocks/XPER.csv Saved
# Finished
# Get Data for : XPO
# ../raw_data/data_stocks/XPO.csv Saved
# Finished
# Get Data for : XSPA
# ../raw_data/data_stocks/XSPA.csv Saved
# Finished
# Get Data for : XTNT
# ../raw_data/data_stocks/XTNT.csv Saved
# Finished
# Get Data for : XYL
# ../raw_data/data_stocks/XYL.csv Saved
# Finished
# Get Data for : YELP
# ../raw_data/data_stocks/YELP.csv Saved
# Finished
# Get Data for : YETI
# ../raw_data/data_stocks/YETI.csv Saved
# Finished
# Get Data for : YEXT
# ../raw_data/data_stocks/YEXT.csv Saved
# Finished
# Get Data for : YTEN
# ../raw_data/data_stocks/YTEN.csv Saved
# Finished
# Get Data for : YMAB
# ../raw_data/data_stocks/YMAB.csv Saved
# Finished
# Get Data for : YORW
# ../raw_data/data_stocks/YORW.csv Saved
# Finished
# Get Data for : YRCW
# - YRCW: No data found, symbol may be delisted
# ../raw_data/data_stocks/YRCW.csv Saved
# Finished
# Get Data for : YUM
# ../raw_data/data_stocks/YUM.csv Saved
# Finished
# Get Data for : YUMA
# - YUMA: No data found, symbol may be delisted
# ../raw_data/data_stocks/YUMA.csv Saved
# Finished
# Get Data for : CTIB
# ../raw_data/data_stocks/CTIB.csv Saved
# Finished
# Get Data for : ZFGN
# - ZFGN: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZFGN.csv Saved
# Finished
# Get Data for : ZAGG
# - ZAGG: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZAGG.csv Saved
# Finished
# Get Data for : ZAYO
# - ZAYO: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZAYO.csv Saved
# Finished
# Get Data for : ZBRA
# ../raw_data/data_stocks/ZBRA.csv Saved
# Finished
# Get Data for : ZDGE
# ../raw_data/data_stocks/ZDGE.csv Saved
# Finished
# Get Data for : ZEN
# ../raw_data/data_stocks/ZEN.csv Saved
# Finished
# Get Data for : Z
# ../raw_data/data_stocks/Z.csv Saved
# Finished
# Get Data for : ZG
# ../raw_data/data_stocks/ZG.csv Saved
# Finished
# Get Data for : ZBH
# ../raw_data/data_stocks/ZBH.csv Saved
# Finished
# Get Data for : ZN
# - ZN: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZN.csv Saved
# Finished
# Get Data for : ZION
# ../raw_data/data_stocks/ZION.csv Saved
# Finished
# Get Data for : ZIOP
# - ZIOP: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZIOP.csv Saved
# Finished
# Get Data for : ZIXI
# - ZIXI: No data found, symbol may be delisted
# ../raw_data/data_stocks/ZIXI.csv Saved
# Finished
# Get Data for : ZTS
# ../raw_data/data_stocks/ZTS.csv Saved
# Finished
# Get Data for : ZGNX
# ../raw_data/data_stocks/ZGNX.csv Saved
# Finished
# Get Data for : ZM
# ../raw_data/data_stocks/ZM.csv Saved
# Finished
# Get Data for : ZSAN
# ../raw_data/data_stocks/ZSAN.csv Saved
# Finished
# Get Data for : ZVO
# ../raw_data/data_stocks/ZVO.csv Saved
# Finished
# Get Data for : ZS
# ../raw_data/data_stocks/ZS.csv Saved
# Finished
# Get Data for : ZUMZ
# ../raw_data/data_stocks/ZUMZ.csv Saved
# Finished
# Get Data for : ZUO
# ../raw_data/data_stocks/ZUO.csv Saved
# Finished
# Get Data for : ZYNE
# ../raw_data/data_stocks/ZYNE.csv Saved
# Finished
# Get Data for : ZYXI
# ../raw_data/data_stocks/ZYXI.csv Saved
# Finished
# Get Data for : ZNGA
# ../raw_data/data_stocks/ZNGA.csv Saved
# Finished

# %% [markdown]
# 🚀 **Ready to launch!**
