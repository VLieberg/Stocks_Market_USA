# %% [markdown]
# Finance Portfolio

# %% [markdown]
#  Imports

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data as web #Reads stock data
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import datetime as dt #defining dates
import mplfinance as mpf # Matplotlib finance

import time

#Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

# %%
# Variables:

file = "../raw_data/stocks_ticker/VL_5000_stocks.csv"
folder = "../raw_data/data_stocks/"
col_name = "Ticker"
PATH = "../raw_data/data_stocks/"

# Dates
syear = 2019
smonth = 1
sday = 1
eyear = 2022
emonth = 4
eday = 1

# %% [markdown]
# **Holds Stocks Not Downloaded**

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# **Save Stock Data to CSV**

# %%
def save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    try:
        print("Get Data from: ", ticker)
        df = web.DataReader(ticker, 'yahoo', start, end)['Adj Close']
        time.sleep(10) # pause after 10 seg and cut the download
        df.to_csv(folder + ticker + '.csv') # saving in a csv file
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't get data for :", ticker)

# %% [markdown]
# **Returns a Stock DataFrame from a CSV**

# %%
def get_stock_df_from_csv(folder, ticker):
    try:
        df = pd.read_csv(folder + ticker + '.csv')
    except FileNotFoundError:
        print("File doesn't exist")
    else:
        return df

# %% [markdown]
# **Returns a Named Columns Data from CSV**

# %%
def get_column_from_csv(file, col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File doesn't exist")
    else:
        return df[col_name]

# %% [markdown]
# **Test Receiving the Stock Tickers**

# %%
tickers = get_column_from_csv(file, col_name)
tickers
# Out:
# 0          A
# 1         AA
# 2        AAL
# 3       AAME
# 4        AAN
#         ...
# 3476    ZUMZ
# 3477     ZUO
# 3478    ZYNE
# 3479    ZYXI
# 3480    ZNGA
# Name: Ticker, Length: 3481, dtype: object

# %% [markdown]
# **Get 4 Years of Data for the 1st 20 Stocks to test**

# %%
for x in range(20):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
# Out:
# Get Data from:  A
# Get Data from:  AA
# Get Data from:  AAL
# Get Data from:  AAME
# Get Data from:  AAN
# Get Data from:  AAOI
# Get Data from:  AAON
# Get Data from:  AAP
# Get Data from:  AAPL
# Get Data from:  AAT
# Get Data from:  AAWW
# Get Data from:  AAXN
# Couldn't get data for : AAXN
# Get Data from:  ABBV
# Get Data from:  ABC
# Get Data from:  ABCB
# Get Data from:  ABEO
# Get Data from:  ABG
# Get Data from:  ABIO
# Get Data from:  ABM
# Get Data from:  ABMD
# Finished

# %% [markdown]
# **Download Stocks in Blocks**

# %%
for x in range (20,500):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  ABR
# Get Data from:  ABT
# Get Data from:  ABTX
# Get Data from:  AC
# Get Data from:  ACA
# Get Data from:  ACAD
# Get Data from:  ACBI
# Get Data from:  ACC
# Get Data from:  ACCO
# Get Data from:  ACER
# Get Data from:  ACGL
# Get Data from:  ACHC
# Get Data from:  ACHV
# Get Data from:  ACIA
# Couldn't get data for : ACIA
# Get Data from:  ACIW
# Get Data from:  ACLS
# Get Data from:  ACM
# Get Data from:  ACMR
# Get Data from:  ACN
# Get Data from:  ACNB
# Get Data from:  ACOR
# Get Data from:  ACRE
# Get Data from:  ACRS
# Get Data from:  ACRX
# Get Data from:  ACTG
# Get Data from:  ACU
# Get Data from:  ACY
# Couldn't get data for : ACY
# Get Data from:  ADBE
# Get Data from:  ADC
# Get Data from:  ADES
# Get Data from:  ADI
# Get Data from:  ADM
# Get Data from:  ADMA
# Get Data from:  ADMP
# Get Data from:  ADMS
# Couldn't get data for : ADMS
# Get Data from:  ADNT
# Get Data from:  ADP
# Get Data from:  ADRO
# Couldn't get data for : ADRO
# Get Data from:  ADS
# Get Data from:  ADSK
# Get Data from:  ADSW
# Couldn't get data for : ADSW
# Get Data from:  ADT
# Get Data from:  ADTN
# Get Data from:  ADUS
# Get Data from:  ADVM
# Get Data from:  ADXS
# Get Data from:  AE
# Get Data from:  AEE
# Get Data from:  AEGN
# Couldn't get data for : AEGN
# Get Data from:  AEHR
# Get Data from:  AEIS
# Get Data from:  AEL
# Get Data from:  AEMD
# Get Data from:  AEO
# Get Data from:  AEP
# Get Data from:  AERI
# Get Data from:  AES
# Get Data from:  AEY
# Get Data from:  AFG
# Get Data from:  AFH
# Couldn't get data for : AFH
# Get Data from:  AFI
# Get Data from:  AFIN
# Couldn't get data for : AFIN
# Get Data from:  AFL
# Get Data from:  AGCO
# Get Data from:  AGE
# Get Data from:  AGEN
# Get Data from:  AGFS
# Get Data from:  AGIO
# Get Data from:  AGLE
# Get Data from:  AGM
# Get Data from:  AGNC
# Get Data from:  AGO
# Get Data from:  AGR
# Get Data from:  AGRX
# Get Data from:  AGS
# Get Data from:  AGTC
# Get Data from:  AGX
# Get Data from:  AGYS
# Get Data from:  AHC
# Couldn't get data for : AHC
# Get Data from:  AHH
# Get Data from:  AHT
# Get Data from:  AIG
# Get Data from:  AIMC
# Get Data from:  AIMT
# Couldn't get data for : AIMT
# Get Data from:  AIN
# Get Data from:  AINC
# Get Data from:  AIR
# Get Data from:  AIRG
# Get Data from:  AIRI
# Get Data from:  AIRT
# Get Data from:  AIT
# Get Data from:  AIV
# Get Data from:  AIZ
# Get Data from:  AJG
# Get Data from:  AJRD
# Get Data from:  AJX
# Get Data from:  AKAM
# Get Data from:  AKBA
# Get Data from:  AKCA
# Couldn't get data for : AKCA
# Get Data from:  AKER
# Couldn't get data for : AKER
# Get Data from:  AKR
# Get Data from:  AKTS
# Get Data from:  AL
# Get Data from:  ALB
# Get Data from:  ALBO
# Get Data from:  ALCO
# Get Data from:  ALDX
# Get Data from:  ALE
# Get Data from:  ALEC
# Get Data from:  ALEX
# Get Data from:  ALG
# Get Data from:  ALGN
# Get Data from:  ALGT
# Get Data from:  ALIM
# Get Data from:  ALJJ
# Get Data from:  ALK
# Get Data from:  ALKS
# Get Data from:  ALL
# Get Data from:  ALLE
# Get Data from:  ALLK
# Get Data from:  ALLO
# Get Data from:  ALLY
# Get Data from:  ALNA
# Get Data from:  ALNY
# Get Data from:  ALOT
# Get Data from:  ALPN
# Get Data from:  ALRM
# Get Data from:  ALSK
# Couldn't get data for : ALSK
# Get Data from:  ALSN
# Get Data from:  ALT
# Get Data from:  ALTM
# Couldn't get data for : ALTM
# Get Data from:  ALTR
# Get Data from:  ALV
# Get Data from:  ALX
# Get Data from:  ALXN
# Couldn't get data for : ALXN
# Get Data from:  AM
# Get Data from:  AMAG
# Couldn't get data for : AMAG
# Get Data from:  AMAL
# Get Data from:  AMAT
# Get Data from:  AMBC
# Get Data from:  AMC
# Get Data from:  AMCX
# Get Data from:  AMD
# Get Data from:  AME
# Get Data from:  AMED
# Get Data from:  AMG
# Get Data from:  AMGN
# Get Data from:  AMH
# Get Data from:  AMKR
# Get Data from:  AMN
# Get Data from:  AMNB
# Get Data from:  AMOT
# Get Data from:  AMP
# Get Data from:  AMPE
# Get Data from:  AMPH
# Get Data from:  AMRB
# Couldn't get data for : AMRB
# Get Data from:  AMRC
# Get Data from:  AMRK
# Get Data from:  AMRS
# Get Data from:  AMRX
# Get Data from:  AMS
# Get Data from:  AMSC
# Get Data from:  AMSF
# Get Data from:  AMSWA
# Get Data from:  AMT
# Get Data from:  AMTD
# Get Data from:  AMTX
# Get Data from:  AMWD
# Get Data from:  AMZN
# Get Data from:  AN
# Get Data from:  ANAB
# Get Data from:  ANAT
# Get Data from:  ANDE
# Get Data from:  ANET
# Get Data from:  ANF
# Get Data from:  ANGI
# Get Data from:  ANGO
# Get Data from:  ANH
# Couldn't get data for : ANH
# Get Data from:  ANIK
# Get Data from:  ANIP
# Get Data from:  ANIX
# Get Data from:  ANSS
# Get Data from:  ANTM
# Get Data from:  AON
# Get Data from:  AOS
# Get Data from:  AOSL
# Get Data from:  AP
# Get Data from:  APA
# Get Data from:  APAM
# Get Data from:  APD
# Get Data from:  APDN
# Get Data from:  APEI
# Get Data from:  APEN
# Get Data from:  APH
# Get Data from:  APLE
# Get Data from:  APLS
# Get Data from:  APOG
# Get Data from:  APPF
# Get Data from:  APPN
# Get Data from:  APPS
# Get Data from:  APRN
# Get Data from:  APT
# Get Data from:  APTS
# Get Data from:  APTV
# Get Data from:  APVO
# Get Data from:  APYX
# Get Data from:  AQB
# Get Data from:  AQMS
# Get Data from:  AQUA
# Get Data from:  AR
# Get Data from:  ARA
# Couldn't get data for : ARA
# Get Data from:  ARAV
# Get Data from:  ARAY
# Get Data from:  ARC
# Get Data from:  ARCB
# Get Data from:  ARCH
# Get Data from:  ARDX
# Get Data from:  ARE
# Get Data from:  ARES
# Get Data from:  ARGO
# Get Data from:  ARI
# Get Data from:  ARKR
# Get Data from:  ARL
# Get Data from:  ARLO
# Get Data from:  ARMK
# Get Data from:  ARNA
# Get Data from:  ARNC
# Get Data from:  AROC
# Get Data from:  AROW
# Get Data from:  ARPO
# Couldn't get data for : ARPO
# Get Data from:  ARR
# Get Data from:  ARTNA
# Get Data from:  ARTW
# Get Data from:  ARVN
# Get Data from:  ARW
# Get Data from:  ARWR
# Get Data from:  ASB
# Get Data from:  ASFI
# Couldn't get data for : ASFI
# Get Data from:  ASGN
# Get Data from:  ASH
# Get Data from:  ASIX
# Get Data from:  ASMB
# Get Data from:  ASNA
# Couldn't get data for : ASNA
# Get Data from:  ASPN
# Get Data from:  ASPS
# Get Data from:  ASRT
# Get Data from:  ASRV
# Get Data from:  ASTC
# Get Data from:  ASTE
# Get Data from:  ASUR
# Get Data from:  ASYS
# Get Data from:  ATEC
# Get Data from:  ATEN
# Get Data from:  ATGE
# Get Data from:  ATH
# Couldn't get data for : ATH
# Get Data from:  ATHX
# Get Data from:  ATI
# Get Data from:  ATKR
# Get Data from:  ATLC
# Get Data from:  ATLO
# Get Data from:  ATNI
# Get Data from:  ATNM
# Get Data from:  ATNX
# Get Data from:  ATO
# Get Data from:  ATOS
# Get Data from:  ATR
# Get Data from:  ATRA
# Get Data from:  ATRC
# Get Data from:  ATRI
# Get Data from:  ATRO
# Get Data from:  ATRS
# Get Data from:  ATSG
# Get Data from:  ATUS
# Get Data from:  ATVI
# Get Data from:  AUBN
# Get Data from:  AUMN
# Get Data from:  AUTO
# Get Data from:  AVA
# Get Data from:  AVAV
# Get Data from:  AVB
# Get Data from:  AVD
# Get Data from:  AVEO
# Get Data from:  AVGO
# Get Data from:  AVGR
# Get Data from:  AVID
# Get Data from:  AVLR
# Get Data from:  AVNS
# Get Data from:  AVNW
# Get Data from:  AVRO
# Get Data from:  AVT
# Get Data from:  AVTR
# Get Data from:  AVXL
# Get Data from:  AVY
# Get Data from:  AVYA
# Get Data from:  AWI
# Get Data from:  AWK
# Get Data from:  AWR
# Get Data from:  AWRE
# Get Data from:  AWSM
# Couldn't get data for : AWSM
# Get Data from:  AX
# Get Data from:  AXAS
# Get Data from:  AXDX
# Get Data from:  AXE
# Couldn't get data for : AXE
# Get Data from:  AXGN
# Get Data from:  AXL
# Get Data from:  AXNX
# Get Data from:  AXP
# Get Data from:  AXR
# Get Data from:  AXS
# Get Data from:  AXSM
# Get Data from:  AXTA
# Get Data from:  AXTI
# Get Data from:  AYI
# Get Data from:  AYX
# Get Data from:  AZO
# Get Data from:  AZPN
# Get Data from:  AZZ
# Get Data from:  B
# Get Data from:  BA
# Get Data from:  BAC
# Get Data from:  BAH
# Get Data from:  BANC
# Get Data from:  BAND
# Get Data from:  BANF
# Get Data from:  BANR
# Get Data from:  BASI
# Couldn't get data for : BASI
# Get Data from:  BATRA
# Get Data from:  BATRK
# Get Data from:  BAX
# Get Data from:  BBBY
# Get Data from:  BBCP
# Get Data from:  BBGI
# Get Data from:  BBSI
# Get Data from:  BBW
# Get Data from:  BBY
# Get Data from:  BC
# Get Data from:  BCBP
# Get Data from:  BCC
# Get Data from:  BCEI
# Couldn't get data for : BCEI
# Get Data from:  BCLI
# Get Data from:  BCO
# Get Data from:  BCOR
# Get Data from:  BCOV
# Get Data from:  BCPC
# Get Data from:  BCRX
# Get Data from:  BDC
# Get Data from:  BDGE
# Couldn't get data for : BDGE
# Get Data from:  BDL
# Get Data from:  BDN
# Get Data from:  BDSI
# Get Data from:  BDX
# Get Data from:  BE
# Get Data from:  BEAT
# Get Data from:  BECN
# Get Data from:  BELFA
# Get Data from:  BELFB
# Get Data from:  BEN
# Get Data from:  BERY
# Get Data from:  BFAM
# Get Data from:  BFIN
# Get Data from:  BFS
# Get Data from:  BFST
# Get Data from:  BG
# Get Data from:  BGCP
# Get Data from:  BGFV
# Get Data from:  BGS
# Get Data from:  BGSF
# Get Data from:  BH
# Get Data from:  BHB
# Get Data from:  BHE
# Get Data from:  BHF
# Get Data from:  BHLB
# Get Data from:  BHR
# Get Data from:  BHVN
# Get Data from:  BIG
# Get Data from:  BIIB
# Get Data from:  BIO
# Get Data from:  BIOC
# Get Data from:  BIOL
# Get Data from:  BJ
# Get Data from:  BJRI
# Get Data from:  BK
# Get Data from:  BKD
# Get Data from:  BKE
# Get Data from:  BKH
# Get Data from:  BKI
# Get Data from:  BKNG
# Get Data from:  BKSC
# Get Data from:  BKTI
# Get Data from:  BKU
# Get Data from:  BL
# Get Data from:  BLBD
# Get Data from:  BLCM
# Get Data from:  BLD
# Get Data from:  BLDR
# Get Data from:  BLFS
# Get Data from:  BLK
# Get Data from:  BLKB
# Get Data from:  BLL
# Get Data from:  BLMN
# Get Data from:  BLUE
# Get Data from:  BMCH
# Couldn't get data for : BMCH
# Get Data from:  BMI
# Get Data from:  BMRC
# Get Data from:  BMRN
# Get Data from:  BMTC
# Couldn't get data for : BMTC
# Get Data from:  BMY
# Get Data from:  BNED
# Get Data from:  BNFT
# Get Data from:  BOCH
# Couldn't get data for : BOCH
# Get Data from:  BOH
# Get Data from:  BOKF
# Get Data from:  BOMN
# Couldn't get data for : BOMN
# Get Data from:  BOOM
# Get Data from:  BOOT
# Get Data from:  BOTJ
# Get Data from:  BOX
# Get Data from:  BPFH
# Couldn't get data for : BPFH
# Get Data from:  BPMC
# Get Data from:  BPOP
# Get Data from:  BPRN
# Get Data from:  BPTH
# Get Data from:  BR
# Get Data from:  BRC
# Get Data from:  BREW
# Couldn't get data for : BREW
# Get Data from:  BRG
# Get Data from:  BRID
# Get Data from:  BRKL
# Get Data from:  BRKR
# Get Data from:  BRKS
# Couldn't get data for : BRKS
# Get Data from:  BRN
# Get Data from:  BRO
# Get Data from:  BRT
# Get Data from:  BRX
# Get Data from:  BRY
# Get Data from:  BSET
# Get Data from:  BSGM
# Get Data from:  BSQR
# Get Data from:  BSRR
# Get Data from:  BSTC
# Couldn't get data for : BSTC
# Get Data from:  BSX
# Get Data from:  BTN
# Get Data from:  BTU
# Get Data from:  BURL
# Get Data from:  BUSE
# Get Data from:  BV
# Get Data from:  BW
# Get Data from:  BWA
# Get Data from:  BWEN
# Get Data from:  BWFG
# Get Data from:  BWXT
# Get Data from:  BXC
# Get Data from:  BXMT
# Get Data from:  BXP
# Get Data from:  BXS
# Couldn't get data for : BXS
# Get Data from:  BY
# Get Data from:  BYD
# Get Data from:  BYFC
# Get Data from:  BYND
# Get Data from:  BZH
# Get Data from:  C
# Get Data from:  CABO
# Get Data from:  CAC
# Get Data from:  CACC
# Get Data from:  CACI
# Get Data from:  CADE
# Get Data from:  CAG
# Get Data from:  CAH
# Get Data from:  CAI
# Couldn't get data for : CAI
# Get Data from:  CAKE
# Get Data from:  CAL
# Get Data from:  CALA
# Get Data from:  CALM
# Get Data from:  CALX
# Get Data from:  CAMP
# Get Data from:  CAPR
# Get Data from:  CAR
# Get Data from:  CARA
# Get Data from:  CARG
# Get Data from:  CARS
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI']

# %%
for x in range (500,1000):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  CASA
# Get Data from:  CASH
# Get Data from:  CASI
# Get Data from:  CASS
# Get Data from:  CASY
# Get Data from:  CAT
# Get Data from:  CATB
# Couldn't get data for : CATB
# Get Data from:  CATC
# Get Data from:  CATM
# Couldn't get data for : CATM
# Get Data from:  CATO
# Get Data from:  CATS
# Couldn't get data for : CATS
# Get Data from:  CATY
# Get Data from:  CB
# Get Data from:  CBAN
# Get Data from:  CBAY
# Get Data from:  CBB
# Couldn't get data for : CBB
# Get Data from:  CBFV
# Get Data from:  CBIO
# Get Data from:  CBLI
# Couldn't get data for : CBLI
# Get Data from:  CBMG
# Couldn't get data for : CBMG
# Get Data from:  CBOE
# Get Data from:  CBRE
# Get Data from:  CBRL
# Get Data from:  CBSH
# Get Data from:  CBT
# Get Data from:  CBTX
# Get Data from:  CBU
# Get Data from:  CBZ
# Get Data from:  CC
# Get Data from:  CCBG
# Get Data from:  CCF
# Get Data from:  CCI
# Get Data from:  CCK
# Get Data from:  CCL
# Get Data from:  CCMP
# Get Data from:  CCNE
# Get Data from:  CCO
# Get Data from:  CCOI
# Get Data from:  CCRN
# Get Data from:  CCS
# Get Data from:  CCXI
# Get Data from:  CDAY
# Get Data from:  CDE
# Get Data from:  CDEV
# Get Data from:  CDK
# Get Data from:  CDLX
# Get Data from:  CDMO
# Get Data from:  CDNA
# Get Data from:  CDNS
# Get Data from:  CDR
# Get Data from:  CDTX
# Get Data from:  CDW
# Get Data from:  CDXC
# Get Data from:  CDXS
# Get Data from:  CDZI
# Get Data from:  CE
# Get Data from:  CECE
# Get Data from:  CEI
# Get Data from:  CEIX
# Get Data from:  CELC
# Get Data from:  CELH
# Get Data from:  CEMI
# Get Data from:  CENT
# Get Data from:  CENTA
# Get Data from:  CENX
# Get Data from:  CERC
# Couldn't get data for : CERC
# Get Data from:  CERN
# Get Data from:  CERS
# Get Data from:  CETV
# Couldn't get data for : CETV
# Get Data from:  CETX
# Get Data from:  CEVA
# Get Data from:  CF
# Get Data from:  CFBK
# Get Data from:  CFFI
# Get Data from:  CFFN
# Get Data from:  CFG
# Get Data from:  CFMS
# Get Data from:  CFR
# Get Data from:  CFX
# Get Data from:  CGIX
# Couldn't get data for : CGIX
# Get Data from:  CGNX
# Get Data from:  CHAP
# Couldn't get data for : CHAP
# Get Data from:  CHCI
# Get Data from:  CHCO
# Get Data from:  CHCT
# Get Data from:  CHD
# Get Data from:  CHDN
# Get Data from:  CHE
# Get Data from:  CHEF
# Get Data from:  CHGG
# Get Data from:  CHH
# Get Data from:  CHK
# Get Data from:  CHMA
# Get Data from:  CHMG
# Get Data from:  CHMI
# Get Data from:  CHRS
# Get Data from:  CHRW
# Get Data from:  CHS
# Get Data from:  CHTR
# Get Data from:  CHUY
# Get Data from:  CI
# Get Data from:  CIA
# Get Data from:  CIDM
# Get Data from:  CIEN
# Get Data from:  CIM
# Get Data from:  CINF
# Get Data from:  CIO
# Get Data from:  CIR
# Get Data from:  CIT
# Couldn't get data for : CIT
# Get Data from:  CIVB
# Get Data from:  CIX
# Get Data from:  CIZN
# Get Data from:  CKH
# Couldn't get data for : CKH
# Get Data from:  CKX
# Get Data from:  CL
# Get Data from:  CLAR
# Get Data from:  CLB
# Get Data from:  CLBS
# Get Data from:  CLCT
# Couldn't get data for : CLCT
# Get Data from:  CLDR
# Couldn't get data for : CLDR
# Get Data from:  CLDT
# Get Data from:  CLDX
# Get Data from:  CLF
# Get Data from:  CLFD
# Get Data from:  CLGX
# Couldn't get data for : CLGX
# Get Data from:  CLH
# Get Data from:  CLI
# Couldn't get data for : CLI
# Get Data from:  CLIR
# Get Data from:  CLNC
# Couldn't get data for : CLNC
# Get Data from:  CLNE
# Get Data from:  CLNY
# Couldn't get data for : CLNY
# Get Data from:  CLPR
# Get Data from:  CLR
# Get Data from:  CLRB
# Get Data from:  CLRO
# Get Data from:  CLSN
# Get Data from:  CLUB
# Couldn't get data for : CLUB
# Get Data from:  CLVS
# Get Data from:  CLW
# Get Data from:  CLX
# Get Data from:  CLXT
# Get Data from:  CMA
# Get Data from:  CMC
# Get Data from:  CMCO
# Get Data from:  CMCSA
# Get Data from:  CMCT
# Get Data from:  CMD
# Couldn't get data for : CMD
# Get Data from:  CME
# Get Data from:  CMG
# Get Data from:  CMI
# Get Data from:  CMO
# Couldn't get data for : CMO
# Get Data from:  CMP
# Get Data from:  CMRX
# Get Data from:  CMS
# Get Data from:  CMT
# Get Data from:  CMTL
# Get Data from:  CNA
# Get Data from:  CNBKA
# Couldn't get data for : CNBKA
# Get Data from:  CNC
# Get Data from:  CNCE
# Get Data from:  CNDT
# Get Data from:  CNFR
# Get Data from:  CNK
# Get Data from:  CNMD
# Get Data from:  CNNE
# Get Data from:  CNO
# Get Data from:  CNOB
# Get Data from:  CNP
# Get Data from:  CNS
# Get Data from:  CNSL
# Get Data from:  CNTY
# Get Data from:  CNX
# Get Data from:  CNXN
# Get Data from:  CODA
# Get Data from:  COF
# Get Data from:  COG
# Couldn't get data for : COG
# Get Data from:  COHN
# Get Data from:  COHR
# Get Data from:  COHU
# Get Data from:  COKE
# Get Data from:  COLB
# Get Data from:  COLD
# Get Data from:  COLL
# Get Data from:  COLM
# Get Data from:  COMM
# Get Data from:  CONE
# Couldn't get data for : CONE
# Get Data from:  CONN
# Get Data from:  COO
# Get Data from:  COOP
# Get Data from:  COP
# Get Data from:  COR
# Couldn't get data for : COR
# Get Data from:  CORE
# Couldn't get data for : CORE
# Get Data from:  CORR
# Get Data from:  CORT
# Get Data from:  COST
# Get Data from:  COTY
# Get Data from:  COUP
# Get Data from:  COWN
# Get Data from:  CPB
# Get Data from:  CPE
# Get Data from:  CPF
# Get Data from:  CPHC
# Get Data from:  CPIX
# Get Data from:  CPK
# Get Data from:  CPLG
# Couldn't get data for : CPLG
# Get Data from:  CPRI
# Get Data from:  CPRT
# Get Data from:  CPRX
# Get Data from:  CPS
# Get Data from:  CPSH
# Get Data from:  CPSI
# Get Data from:  CPSS
# Get Data from:  CPST
# Couldn't get data for : CPST
# Get Data from:  CPT
# Get Data from:  CR
# Get Data from:  CRAI
# Get Data from:  CRBP
# Get Data from:  CRC
# Get Data from:  CREE
# Couldn't get data for : CREE
# Get Data from:  CRI
# Get Data from:  CRIS
# Get Data from:  CRK
# Get Data from:  CRL
# Get Data from:  CRM
# Get Data from:  CRMD
# Get Data from:  CRMT
# Get Data from:  CRNX
# Get Data from:  CROX
# Get Data from:  CRS
# Get Data from:  CRTX
# Get Data from:  CRUS
# Get Data from:  CRVL
# Get Data from:  CRVS
# Get Data from:  CRWS
# Get Data from:  CRY
# Couldn't get data for : CRY
# Get Data from:  CSCO
# Get Data from:  CSGP
# Get Data from:  CSGS
# Get Data from:  CSII
# Get Data from:  CSL
# Get Data from:  CSLT
# Couldn't get data for : CSLT
# Get Data from:  CSOD
# Couldn't get data for : CSOD
# Get Data from:  CSPI
# Get Data from:  CSTR
# Get Data from:  CSU
# Couldn't get data for : CSU
# Get Data from:  CSV
# Get Data from:  CSWI
# Get Data from:  CSX
# Get Data from:  CTAS
# Get Data from:  CTB
# Couldn't get data for : CTB
# Get Data from:  CTBI
# Get Data from:  CTG
# Get Data from:  CTHR
# Get Data from:  CTIB
# Get Data from:  CTIC
# Get Data from:  CTL
# Couldn't get data for : CTL
# Get Data from:  CTLT
# Get Data from:  CTMX
# Get Data from:  CTO
# Get Data from:  CTRE
# Get Data from:  CTRN
# Get Data from:  CTS
# Get Data from:  CTSH
# Get Data from:  CTSO
# Get Data from:  CTT
# Get Data from:  CTXS
# Get Data from:  CUB
# Couldn't get data for : CUB
# Get Data from:  CUBE
# Get Data from:  CUBI
# Get Data from:  CUE
# Get Data from:  CULP
# Get Data from:  CURO
# Get Data from:  CUTR
# Get Data from:  CUZ
# Get Data from:  CVA
# Couldn't get data for : CVA
# Get Data from:  CVBF
# Get Data from:  CVCO
# Get Data from:  CVCY
# Get Data from:  CVGI
# Get Data from:  CVGW
# Get Data from:  CVI
# Get Data from:  CVIA
# Couldn't get data for : CVIA
# Get Data from:  CVLT
# Get Data from:  CVLY
# Get Data from:  CVM
# Get Data from:  CVNA
# Get Data from:  CVR
# Get Data from:  CVS
# Get Data from:  CVTI
# Couldn't get data for : CVTI
# Get Data from:  CVU
# Get Data from:  CVV
# Get Data from:  CVX
# Get Data from:  CW
# Get Data from:  CWBC
# Get Data from:  CWBR
# Get Data from:  CWEN
# Get Data from:  CWH
# Get Data from:  CWST
# Get Data from:  CWT
# Get Data from:  CXO
# Couldn't get data for : CXO
# Get Data from:  CXP
# Couldn't get data for : CXP
# Get Data from:  CXW
# Get Data from:  CYAN
# Get Data from:  CYBE
# Get Data from:  CYCC
# Get Data from:  CYH
# Get Data from:  CYRX
# Get Data from:  CYTK
# Get Data from:  CYTR
# Get Data from:  CZNC
# Get Data from:  CZR
# Get Data from:  CZWI
# Get Data from:  D
# Get Data from:  DAIO
# Get Data from:  DAKT
# Get Data from:  DAL
# Get Data from:  DAN
# Get Data from:  DAR
# Get Data from:  DARE
# Get Data from:  DBD
# Get Data from:  DBI
# Get Data from:  DBX
# Get Data from:  DCI
# Get Data from:  DCO
# Get Data from:  DCOM
# Get Data from:  DCPH
# Get Data from:  DD
# Get Data from:  DDD
# Get Data from:  DDS
# Get Data from:  DE
# Get Data from:  DEA
# Get Data from:  DECK
# Get Data from:  DEI
# Get Data from:  DELL
# Get Data from:  DENN
# Get Data from:  DFIN
# Get Data from:  DFS
# Get Data from:  DG
# Get Data from:  DGICA
# Get Data from:  DGII
# Get Data from:  DGLY
# Get Data from:  DGX
# Get Data from:  DHI
# Get Data from:  DHIL
# Get Data from:  DHR
# Get Data from:  DHX
# Get Data from:  DIN
# Get Data from:  DIOD
# Get Data from:  DIS
# Get Data from:  DISCA
# Get Data from:  DISCK
# Get Data from:  DISH
# Get Data from:  DIT
# Get Data from:  DJCO
# Get Data from:  DK
# Get Data from:  DKS
# Get Data from:  DLA
# Get Data from:  DLB
# Get Data from:  DLHC
# Get Data from:  DLPH
# Couldn't get data for : DLPH
# Get Data from:  DLR
# Get Data from:  DLTH
# Get Data from:  DLTR
# Get Data from:  DLX
# Get Data from:  DMRC
# Get Data from:  DNKN
# Couldn't get data for : DNKN
# Get Data from:  DNLI
# Get Data from:  DNOW
# Get Data from:  DNR
# Couldn't get data for : DNR
# Get Data from:  DOC
# Get Data from:  DOCU
# Get Data from:  DOMO
# Get Data from:  DOOR
# Get Data from:  DORM
# Get Data from:  DOV
# Get Data from:  DOW
# Get Data from:  DPZ
# Get Data from:  DRAD
# Couldn't get data for : DRAD
# Get Data from:  DRE
# Get Data from:  DRH
# Get Data from:  DRI
# Get Data from:  DRNA
# Couldn't get data for : DRNA
# Get Data from:  DRQ
# Get Data from:  DRRX
# Get Data from:  DS
# Get Data from:  DSKE
# Get Data from:  DSPG
# Couldn't get data for : DSPG
# Get Data from:  DSS
# Get Data from:  DTE
# Get Data from:  DUK
# Get Data from:  DVA
# Get Data from:  DVAX
# Get Data from:  DVD
# Couldn't get data for : DVD
# Get Data from:  DVN
# Get Data from:  DWSN
# Get Data from:  DX
# Get Data from:  DXC
# Get Data from:  DXCM
# Get Data from:  DXLG
# Get Data from:  DXPE
# Get Data from:  DXYN
# Get Data from:  DY
# Get Data from:  DZSI
# Get Data from:  EA
# Get Data from:  EAF
# Get Data from:  EARN
# Get Data from:  EAT
# Get Data from:  EB
# Get Data from:  EBAY
# Get Data from:  EBF
# Get Data from:  EBIX
# Get Data from:  EBMT
# Get Data from:  EBS
# Get Data from:  EBSB
# Couldn't get data for : EBSB
# Get Data from:  EBTC
# Get Data from:  ECHO
# Couldn't get data for : ECHO
# Get Data from:  ECL
# Get Data from:  ECOL
# Get Data from:  ECOM
# Get Data from:  ECPG
# Get Data from:  ED
# Get Data from:  EDIT
# Get Data from:  EDUC
# Get Data from:  EE
# Couldn't get data for : EE
# Get Data from:  EEFT
# Get Data from:  EEX
# Get Data from:  EFC
# Get Data from:  EFOI
# Get Data from:  EFSC
# Get Data from:  EFX
# Get Data from:  EGAN
# Get Data from:  EGBN
# Get Data from:  EGHT
# Get Data from:  EGLE
# Get Data from:  EGOV
# Couldn't get data for : EGOV
# Get Data from:  EGP
# Get Data from:  EGRX
# Get Data from:  EGY
# Get Data from:  EHC
# Get Data from:  EHTH
# Get Data from:  EIDX
# Couldn't get data for : EIDX
# Get Data from:  EIG
# Get Data from:  EIGI
# Couldn't get data for : EIGI
# Get Data from:  EIGR
# Get Data from:  EIX
# Get Data from:  EKSO
# Get Data from:  EL
# Get Data from:  ELAN
# Get Data from:  ELF
# Get Data from:  ELGX
# Couldn't get data for : ELGX
# Get Data from:  ELMD
# Get Data from:  ELOX
# Get Data from:  ELS
# Get Data from:  ELSE
# Get Data from:  ELVT
# Get Data from:  ELY
# Get Data from:  EMAN
# Get Data from:  EMCF
# Get Data from:  EME
# Get Data from:  EMKR
# Get Data from:  EML
# Get Data from:  EMMS
# Get Data from:  EMN
# Get Data from:  EMR
# Get Data from:  ENDP
# Get Data from:  ENG
# Get Data from:  ENOB
# Get Data from:  ENPH
# Get Data from:  ENR
# Get Data from:  ENS
# Get Data from:  ENSG
# Get Data from:  ENSV
# Get Data from:  ENT
# Couldn't get data for : ENT
# Get Data from:  ENTA
# Get Data from:  ENTG
# Get Data from:  ENV
# Get Data from:  ENVA
# Get Data from:  ENZ
# Get Data from:  EOG
# Get Data from:  EOLS
# Get Data from:  EPAM
# Get Data from:  EPAY
# Get Data from:  EPC
# Get Data from:  EPM
# Get Data from:  EPR
# Get Data from:  EPRT
# Get Data from:  EPZM
# Get Data from:  EQBK
# Get Data from:  EQC
# Get Data from:  EQH
# Get Data from:  EQIX
# Get Data from:  EQR
# Get Data from:  EQT
# Get Data from:  ERI
# Couldn't get data for : ERI
# Get Data from:  ERIE
# Get Data from:  ERII
# Get Data from:  ES
# Get Data from:  ESBK
# Get Data from:  ESCA
# Get Data from:  ESE
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI']

# %%
for x in range (1000,1500):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  ESGR
# Get Data from:  ESNT
# Get Data from:  ESP
# Get Data from:  ESPR
# Get Data from:  ESRT
# Get Data from:  ESS
# Get Data from:  ESSA
# Get Data from:  ESTC
# Get Data from:  ESTE
# Get Data from:  ESXB
# Couldn't get data for : ESXB
# Get Data from:  ETFC
# Couldn't get data for : ETFC
# Get Data from:  ETH
# Couldn't get data for : ETH
# Get Data from:  ETM
# Couldn't get data for : ETM
# Get Data from:  ETN
# Get Data from:  ETR
# Get Data from:  ETRN
# Get Data from:  ETSY
# Get Data from:  EV
# Couldn't get data for : EV
# Get Data from:  EVBG
# Get Data from:  EVBN
# Get Data from:  EVC
# Get Data from:  EVER
# Get Data from:  EVFM
# Get Data from:  EVH
# Get Data from:  EVI
# Get Data from:  EVOK
# Get Data from:  EVOL
# Get Data from:  EVOP
# Get Data from:  EVR
# Get Data from:  EVRG
# Get Data from:  EVRI
# Get Data from:  EVTC
# Get Data from:  EW
# Get Data from:  EWBC
# Get Data from:  EXAS
# Get Data from:  EXC
# Get Data from:  EXEL
# Get Data from:  EXLS
# Get Data from:  EXP
# Get Data from:  EXPD
# Get Data from:  EXPE
# Get Data from:  EXPI
# Get Data from:  EXPO
# Get Data from:  EXPR
# Get Data from:  EXR
# Get Data from:  EXTN
# Get Data from:  EXTR
# Get Data from:  EYE
# Get Data from:  EYEG
# Couldn't get data for : EYEG
# Get Data from:  EYES
# Get Data from:  EYPT
# Get Data from:  EZPW
# Get Data from:  F
# Get Data from:  FAF
# Get Data from:  FANG
# Get Data from:  FARM
# Get Data from:  FARO
# Get Data from:  FAST
# Get Data from:  FATE
# Get Data from:  FB
# Get Data from:  FBC
# Get Data from:  FBHS
# Get Data from:  FBIO
# Get Data from:  FBIZ
# Get Data from:  FBK
# Get Data from:  FBM
# Couldn't get data for : FBM
# Get Data from:  FBMS
# Get Data from:  FBNC
# Get Data from:  FBP
# Get Data from:  FBSS
# Couldn't get data for : FBSS
# Get Data from:  FC
# Get Data from:  FCAP
# Get Data from:  FCBC
# Get Data from:  FCBP
# Couldn't get data for : FCBP
# Get Data from:  FCCO
# Get Data from:  FCCY
# Couldn't get data for : FCCY
# Get Data from:  FCEL
# Get Data from:  FCF
# Get Data from:  FCFS
# Get Data from:  FCN
# Get Data from:  FCNCA
# Get Data from:  FCPT
# Get Data from:  FCX
# Get Data from:  FDBC
# Get Data from:  FDEF
# Couldn't get data for : FDEF
# Get Data from:  FDP
# Get Data from:  FDS
# Get Data from:  FDX
# Get Data from:  FE
# Get Data from:  FEIM
# Get Data from:  FELE
# Get Data from:  FET
# Get Data from:  FEYE
# Couldn't get data for : FEYE
# Get Data from:  FF
# Get Data from:  FFBC
# Get Data from:  FFG
# Couldn't get data for : FFG
# Get Data from:  FFIC
# Get Data from:  FFIN
# Get Data from:  FFIV
# Get Data from:  FFNW
# Get Data from:  FFWM
# Get Data from:  FGBI
# Get Data from:  FGEN
# Get Data from:  FHB
# Get Data from:  FHN
# Get Data from:  FI
# Couldn't get data for : FI
# Get Data from:  FIBK
# Get Data from:  FICO
# Get Data from:  FIS
# Get Data from:  FISI
# Get Data from:  FISV
# Get Data from:  FIT
# Couldn't get data for : FIT
# Get Data from:  FITB
# Get Data from:  FIVE
# Get Data from:  FIVN
# Get Data from:  FIX
# Get Data from:  FIXX
# Get Data from:  FIZZ
# Get Data from:  FL
# Get Data from:  FLDM
# Get Data from:  FLIC
# Get Data from:  FLIR
# Couldn't get data for : FLIR
# Get Data from:  FLL
# Get Data from:  FLMN
# Get Data from:  FLNT
# Get Data from:  FLO
# Get Data from:  FLOW
# Get Data from:  FLR
# Get Data from:  FLS
# Get Data from:  FLT
# Get Data from:  FLWS
# Get Data from:  FLXN
# Couldn't get data for : FLXN
# Get Data from:  FLXS
# Get Data from:  FMAO
# Get Data from:  FMBH
# Get Data from:  FMBI
# Couldn't get data for : FMBI
# Get Data from:  FMC
# Get Data from:  FMNB
# Get Data from:  FN
# Get Data from:  FNB
# Get Data from:  FNCB
# Get Data from:  FND
# Get Data from:  FNF
# Get Data from:  FNHC
# Get Data from:  FNJN
# Couldn't get data for : FNJN
# Get Data from:  FNKO
# Get Data from:  FNLC
# Get Data from:  FNWB
# Get Data from:  FOCS
# Get Data from:  FOE
# Get Data from:  FOLD
# Get Data from:  FONR
# Get Data from:  FOR
# Get Data from:  FORD
# Get Data from:  FORM
# Get Data from:  FORR
# Get Data from:  FOSL
# Get Data from:  FOX
# Get Data from:  FOXA
# Get Data from:  FOXF
# Get Data from:  FPI
# Get Data from:  FPRX
# Couldn't get data for : FPRX
# Get Data from:  FR
# Get Data from:  FRAN
# Couldn't get data for : FRAN
# Get Data from:  FRBA
# Get Data from:  FRBK
# Get Data from:  FRC
# Get Data from:  FRD
# Get Data from:  FRGI
# Get Data from:  FRME
# Get Data from:  FRPH
# Get Data from:  FRPT
# Get Data from:  FRT
# Get Data from:  FRTA
# Couldn't get data for : FRTA
# Get Data from:  FSB
# Couldn't get data for : FSB
# Get Data from:  FSBW
# Get Data from:  FSCT
# Couldn't get data for : FSCT
# Get Data from:  FSFG
# Get Data from:  FSLR
# Get Data from:  FSLY
# Get Data from:  FSP
# Get Data from:  FSS
# Get Data from:  FSTR
# Get Data from:  FTDR
# Get Data from:  FTEK
# Get Data from:  FTI
# Get Data from:  FTK
# Get Data from:  FTNT
# Get Data from:  FTSI
# Couldn't get data for : FTSI
# Get Data from:  FTV
# Get Data from:  FUL
# Get Data from:  FULT
# Get Data from:  FUNC
# Get Data from:  FUSB
# Get Data from:  FVE
# Couldn't get data for : FVE
# Get Data from:  FWONA
# Get Data from:  FWONK
# Get Data from:  FWRD
# Get Data from:  G
# Get Data from:  GABC
# Get Data from:  GAIA
# Get Data from:  GALT
# Get Data from:  GATX
# Get Data from:  GBCI
# Get Data from:  GBL
# Get Data from:  GBLI
# Get Data from:  GBT
# Get Data from:  GBX
# Get Data from:  GCAP
# Couldn't get data for : GCAP
# Get Data from:  GCBC
# Get Data from:  GCI
# Get Data from:  GCO
# Get Data from:  GCP
# Get Data from:  GD
# Get Data from:  GDDY
# Get Data from:  GDEN
# Get Data from:  GDOT
# Get Data from:  GDP
# Couldn't get data for : GDP
# Get Data from:  GE
# Get Data from:  GEC
# Couldn't get data for : GEC
# Get Data from:  GEF
# Get Data from:  GEN
# Couldn't get data for : GEN
# Get Data from:  GENC
# Get Data from:  GEO
# Get Data from:  GEOS
# Get Data from:  GERN
# Get Data from:  GES
# Get Data from:  GEVO
# Get Data from:  GFED
# Get Data from:  GFF
# Get Data from:  GFN
# Couldn't get data for : GFN
# Get Data from:  GGG
# Get Data from:  GH
# Get Data from:  GHC
# Get Data from:  GHL
# Get Data from:  GHM
# Get Data from:  GIFI
# Get Data from:  GIII
# Get Data from:  GILD
# Get Data from:  GIS
# Get Data from:  GKOS
# Get Data from:  GLBZ
# Get Data from:  GLDD
# Get Data from:  GLIBA
# Couldn't get data for : GLIBA
# Get Data from:  GLPI
# Get Data from:  GLRE
# Get Data from:  GLT
# Get Data from:  GLUU
# Couldn't get data for : GLUU
# Get Data from:  GLW
# Get Data from:  GLYC
# Get Data from:  GM
# Get Data from:  GME
# Get Data from:  GMED
# Get Data from:  GMO
# Couldn't get data for : GMO
# Get Data from:  GMRE
# Get Data from:  GMS
# Get Data from:  GNC
# Couldn't get data for : GNC
# Get Data from:  GNCA
# Get Data from:  GNE
# Get Data from:  GNK
# Get Data from:  GNL
# Get Data from:  GNMK
# Couldn't get data for : GNMK
# Get Data from:  GNRC
# Get Data from:  GNTX
# Get Data from:  GNTY
# Get Data from:  GNW
# Get Data from:  GOGO
# Get Data from:  GOLF
# Get Data from:  GOOD
# Get Data from:  GOOG
# Get Data from:  GOOGL
# Get Data from:  GORO
# Get Data from:  GOSS
# Get Data from:  GPC
# Get Data from:  GPI
# Get Data from:  GPK
# Get Data from:  GPMT
# Get Data from:  GPN
# Get Data from:  GPOR
# Get Data from:  GPRE
# Get Data from:  GPRO
# Get Data from:  GPS
# Get Data from:  GPX
# Couldn't get data for : GPX
# Get Data from:  GRA
# Couldn't get data for : GRA
# Get Data from:  GRBK
# Get Data from:  GRC
# Get Data from:  GRIF
# Couldn't get data for : GRIF
# Get Data from:  GRMN
# Couldn't get data for : GRMN
# Get Data from:  GROW
# Get Data from:  GRPN
# Get Data from:  GRTS
# Get Data from:  GRUB
# Couldn't get data for : GRUB
# Get Data from:  GS
# Get Data from:  GSAT
# Get Data from:  GSB
# Couldn't get data for : GSB
# Get Data from:  GSBC
# Get Data from:  GSHD
# Get Data from:  GSIT
# Get Data from:  GSKY
# Get Data from:  GT
# Get Data from:  GTES
# Get Data from:  GTHX
# Get Data from:  GTIM
# Get Data from:  GTLS
# Get Data from:  GTN
# Get Data from:  GTS
# Couldn't get data for : GTS
# Get Data from:  GTT
# Couldn't get data for : GTT
# Get Data from:  GTX
# Get Data from:  GTY
# Get Data from:  GTYH
# Get Data from:  GV
# Couldn't get data for : GV
# Get Data from:  GVA
# Get Data from:  GVP
# Get Data from:  GWB
# Couldn't get data for : GWB
# Get Data from:  GWGH
# Get Data from:  GWRE
# Get Data from:  GWRS
# Get Data from:  GWW
# Get Data from:  H
# Get Data from:  HA
# Get Data from:  HAE
# Get Data from:  HAFC
# Get Data from:  HAIN
# Get Data from:  HAL
# Get Data from:  HALL
# Get Data from:  HALO
# Get Data from:  HAS
# Get Data from:  HASI
# Get Data from:  HAYN
# Get Data from:  HBAN
# Get Data from:  HBB
# Get Data from:  HBCP
# Get Data from:  HBI
# Get Data from:  HBIO
# Get Data from:  HBMD
# Get Data from:  HBNC
# Get Data from:  HBP
# Get Data from:  HCA
# Get Data from:  HCC
# Get Data from:  HCCI
# Get Data from:  HCFT
# Couldn't get data for : HCFT
# Get Data from:  HCHC
# Couldn't get data for : HCHC
# Get Data from:  HCI
# Get Data from:  HCKT
# Get Data from:  HCSG
# Get Data from:  HD
# Get Data from:  HDS
# Couldn't get data for : HDS
# Get Data from:  HDSN
# Get Data from:  HE
# Get Data from:  HEAR
# Get Data from:  HEES
# Get Data from:  HEI
# Get Data from:  HELE
# Get Data from:  HES
# Get Data from:  HFBL
# Get Data from:  HFC
# Couldn't get data for : HFC
# Get Data from:  HFWA
# Get Data from:  HGV
# Get Data from:  HHC
# Get Data from:  HHS
# Get Data from:  HI
# Get Data from:  HIBB
# Get Data from:  HIFS
# Get Data from:  HIG
# Get Data from:  HII
# Get Data from:  HIL
# Get Data from:  HIW
# Get Data from:  HL
# Get Data from:  HLF
# Get Data from:  HLI
# Get Data from:  HLIT
# Get Data from:  HLNE
# Get Data from:  HLT
# Get Data from:  HLX
# Get Data from:  HMHC
# Get Data from:  HMN
# Get Data from:  HMNF
# Get Data from:  HMST
# Get Data from:  HMSY
# Couldn't get data for : HMSY
# Get Data from:  HMTV
# Get Data from:  HNI
# Couldn't get data for : HNI
# Get Data from:  HNRG
# Get Data from:  HOFT
# Get Data from:  HOG
# Get Data from:  HOLX
# Get Data from:  HOMB
# Get Data from:  HOME
# Couldn't get data for : HOME
# Get Data from:  HON
# Get Data from:  HONE
# Get Data from:  HOPE
# Get Data from:  HOV
# Get Data from:  HP
# Get Data from:  HPE
# Get Data from:  HPP
# Get Data from:  HPQ
# Get Data from:  HPR
# Couldn't get data for : HPR
# Get Data from:  HQY
# Get Data from:  HR
# Get Data from:  HRB
# Get Data from:  HRC
# Couldn't get data for : HRC
# Get Data from:  HRI
# Get Data from:  HRL
# Get Data from:  HROW
# Get Data from:  HRTG
# Get Data from:  HRTX
# Get Data from:  HSC
# Get Data from:  HSIC
# Get Data from:  HSII
# Get Data from:  HSKA
# Couldn't get data for : HSKA
# Get Data from:  HSON
# Get Data from:  HST
# Get Data from:  HSTM
# Get Data from:  HSY
# Get Data from:  HT
# Couldn't get data for : HT
# Get Data from:  HTA
# Get Data from:  HTBI
# Get Data from:  HTBK
# Get Data from:  HTBX
# Get Data from:  HTGM
# Get Data from:  HTH
# Couldn't get data for : HTH
# Get Data from:  HTLD
# Get Data from:  HTLF
# Get Data from:  HUBB
# Get Data from:  HUBG
# Get Data from:  HUBS
# Get Data from:  HUM
# Get Data from:  HUN
# Get Data from:  HURC
# Get Data from:  HURN
# Get Data from:  HUSA
# Get Data from:  HVT
# Get Data from:  HWBK
# Get Data from:  HWC
# Get Data from:  HWCC
# Couldn't get data for : HWCC
# Get Data from:  HWKN
# Get Data from:  HXL
# Get Data from:  HY
# Get Data from:  HZN
# Get Data from:  HZNP
# Get Data from:  HZO
# Get Data from:  IAC
# Get Data from:  IART
# Get Data from:  IBCP
# Get Data from:  IBIO
# Get Data from:  IBKC
# Couldn't get data for : IBKC
# Get Data from:  IBKR
# Get Data from:  IBM
# Get Data from:  IBOC
# Get Data from:  IBP
# Get Data from:  IBTX
# Get Data from:  ICAD
# Get Data from:  ICBK
# Couldn't get data for : ICBK
# Get Data from:  ICCC
# Get Data from:  ICD
# Get Data from:  ICE
# Get Data from:  ICFI
# Get Data from:  ICHR
# Get Data from:  ICON
# Couldn't get data for : ICON
# Get Data from:  ICPT
# Get Data from:  ICUI
# Get Data from:  IDA
# Get Data from:  IDCC
# Get Data from:  IDN
# Get Data from:  IDRA
# Get Data from:  IDT
# Get Data from:  IDXG
# Get Data from:  IDXX
# Get Data from:  IEC
# Couldn't get data for : IEC
# Get Data from:  IESC
# Get Data from:  IEX
# Get Data from:  IFF
# Get Data from:  IHC
# Couldn't get data for : IHC
# Get Data from:  III
# Get Data from:  IIIN
# Get Data from:  IIIV
# Get Data from:  IIN
# Get Data from:  IIPR
# Get Data from:  IIVI
# Get Data from:  IKNX
# Couldn't get data for : IKNX
# Get Data from:  ILMN
# Get Data from:  ILPT
# Get Data from:  IMGN
# Get Data from:  IMH
# Get Data from:  IMKTA
# Get Data from:  IMMR
# Get Data from:  IMMU
# Couldn't get data for : IMMU
# Get Data from:  IMXI
# Get Data from:  INBK
# Get Data from:  INCY
# Get Data from:  INDB
# Get Data from:  INFI
# Get Data from:  INFN
# Get Data from:  INFO
# Couldn't get data for : INFO
# Get Data from:  INFU
# Get Data from:  INGN
# Get Data from:  INGR
# Get Data from:  INN
# Get Data from:  INO
# Get Data from:  INOD
# Get Data from:  INOV
# Couldn't get data for : INOV
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV']

# %%
for x in range (1500,2000):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  INPX
# Get Data from:  INS
# Couldn't get data for : INS
# Get Data from:  INSE
# Get Data from:  INSG
# Get Data from:  INSM
# Get Data from:  INSP
# Get Data from:  INSW
# Get Data from:  INT
# Get Data from:  INTC
# Get Data from:  INTG
# Get Data from:  INTL
# Couldn't get data for : INTL
# Get Data from:  INTT
# Get Data from:  INTU
# Get Data from:  INUV
# Get Data from:  INVA
# Get Data from:  INVE
# Get Data from:  INVH
# Get Data from:  INWK
# Couldn't get data for : INWK
# Get Data from:  IO
# Get Data from:  IONS
# Get Data from:  IOR
# Get Data from:  IOSP
# Get Data from:  IOTS
# Couldn't get data for : IOTS
# Get Data from:  IOVA
# Get Data from:  IP
# Get Data from:  IPAR
# Get Data from:  IPG
# Get Data from:  IPGP
# Get Data from:  IPHI
# Couldn't get data for : IPHI
# Get Data from:  IPI
# Get Data from:  IPWR
# Get Data from:  IQV
# Get Data from:  IR
# Get Data from:  IRBT
# Get Data from:  IRDM
# Get Data from:  IRET
# Couldn't get data for : IRET
# Get Data from:  IRIX
# Get Data from:  IRM
# Get Data from:  IRMD
# Get Data from:  IROQ
# Get Data from:  IRT
# Get Data from:  IRTC
# Get Data from:  IRWD
# Get Data from:  ISBC
# Get Data from:  ISDR
# Get Data from:  ISIG
# Get Data from:  ISNS
# Couldn't get data for : ISNS
# Get Data from:  ISR
# Get Data from:  ISRG
# Get Data from:  ISSC
# Get Data from:  ISTR
# Get Data from:  IT
# Get Data from:  ITCI
# Get Data from:  ITGR
# Get Data from:  ITI
# Get Data from:  ITIC
# Get Data from:  ITRI
# Get Data from:  ITT
# Get Data from:  ITW
# Get Data from:  IVAC
# Get Data from:  IVC
# Get Data from:  IVR
# Get Data from:  IVZ
# Get Data from:  IZEA
# Get Data from:  JACK
# Get Data from:  JAGX
# Get Data from:  JAKK
# Couldn't get data for : JAKK
# Get Data from:  JASN
# Couldn't get data for : JASN
# Get Data from:  JAX
# Couldn't get data for : JAX
# Get Data from:  JAZZ
# Get Data from:  JBGS
# Get Data from:  JBHT
# Get Data from:  JBL
# Get Data from:  JBLU
# Get Data from:  JBSS
# Get Data from:  JBT
# Get Data from:  JCAP
# Couldn't get data for : JCAP
# Get Data from:  JCI
# Get Data from:  JCOM
# Couldn't get data for : JCOM
# Get Data from:  JCS
# Get Data from:  JCTCF
# Get Data from:  JEF
# Get Data from:  JELD
# Get Data from:  JHG
# Get Data from:  JILL
# Get Data from:  JJSF
# Get Data from:  JKHY
# Get Data from:  JLL
# Get Data from:  JNCE
# Get Data from:  JNJ
# Get Data from:  JNPR
# Get Data from:  JOB
# Get Data from:  JOE
# Get Data from:  JOUT
# Get Data from:  JPM
# Get Data from:  JRVR
# Get Data from:  JVA
# Get Data from:  JWN
# Get Data from:  JYNT
# Get Data from:  K
# Get Data from:  KAI
# Get Data from:  KALA
# Get Data from:  KALU
# Get Data from:  KALV
# Get Data from:  KAMN
# Get Data from:  KAR
# Get Data from:  KBAL
# Get Data from:  KBH
# Get Data from:  KBR
# Get Data from:  KDMN
# Couldn't get data for : KDMN
# Get Data from:  KDP
# Get Data from:  KE
# Get Data from:  KELYA
# Get Data from:  KEQU
# Get Data from:  KEX
# Get Data from:  KEY
# Get Data from:  KEYS
# Get Data from:  KFFB
# Get Data from:  KFRC
# Get Data from:  KFY
# Get Data from:  KHC
# Get Data from:  KIDS
# Get Data from:  KIM
# Get Data from:  KIN
# Couldn't get data for : KIN
# Get Data from:  KINS
# Get Data from:  KIRK
# Get Data from:  KKR
# Get Data from:  KLAC
# Get Data from:  KLIC
# Get Data from:  KLXE
# Get Data from:  KMB
# Get Data from:  KMI
# Get Data from:  KMPH
# Get Data from:  KMPR
# Get Data from:  KMT
# Get Data from:  KMX
# Get Data from:  KN
# Get Data from:  KNL
# Couldn't get data for : KNL
# Get Data from:  KNSA
# Get Data from:  KNSL
# Get Data from:  KNX
# Get Data from:  KO
# Get Data from:  KOD
# Get Data from:  KODK
# Get Data from:  KOP
# Get Data from:  KOPN
# Get Data from:  KOS
# Get Data from:  KPTI
# Get Data from:  KR
# Get Data from:  KRA
# Couldn't get data for : KRA
# Get Data from:  KRC
# Get Data from:  KREF
# Get Data from:  KRG
# Get Data from:  KRNY
# Get Data from:  KRO
# Get Data from:  KRYS
# Get Data from:  KSS
# Get Data from:  KSU
# Couldn't get data for : KSU
# Get Data from:  KTCC
# Get Data from:  KTOS
# Get Data from:  KURA
# Get Data from:  KVHI
# Get Data from:  KW
# Get Data from:  KWR
# Get Data from:  KZR
# Get Data from:  L
# Get Data from:  LAD
# Get Data from:  LADR
# Get Data from:  LAKE
# Get Data from:  LAMR
# Get Data from:  LANC
# Get Data from:  LAND
# Get Data from:  LARK
# Get Data from:  LASR
# Get Data from:  LAUR
# Get Data from:  LAWS
# Get Data from:  LAZ
# Get Data from:  LB
# Couldn't get data for : LB
# Get Data from:  LBAI
# Get Data from:  LBC
# Get Data from:  LBRDA
# Get Data from:  LBRDK
# Get Data from:  LBRT
# Get Data from:  LBTYA
# Get Data from:  LBTYK
# Get Data from:  LC
# Get Data from:  LCI
# Get Data from:  LCII
# Get Data from:  LCNB
# Get Data from:  LCUT
# Get Data from:  LDL
# Couldn't get data for : LDL
# Get Data from:  LDOS
# Get Data from:  LE
# Get Data from:  LEA
# Get Data from:  LEAF
# Couldn't get data for : LEAF
# Get Data from:  LECO
# Get Data from:  LEE
# Get Data from:  LEG
# Get Data from:  LEGH
# Get Data from:  LEN
# Get Data from:  LEU
# Get Data from:  LEVI
# Get Data from:  LFUS
# Get Data from:  LFVN
# Get Data from:  LGIH
# Get Data from:  LGL
# Get Data from:  LGND
# Get Data from:  LH
# Get Data from:  LHCG
# Get Data from:  LIFE
# Get Data from:  LII
# Get Data from:  LILA
# Get Data from:  LILAK
# Get Data from:  LIN
# Get Data from:  LINC
# Get Data from:  LIND
# Get Data from:  LIQT
# Get Data from:  LITE
# Get Data from:  LIVE
# Get Data from:  LIVN
# Get Data from:  LIVX
# Couldn't get data for : LIVX
# Get Data from:  LJPC
# Get Data from:  LKFN
# Get Data from:  LKQ
# Get Data from:  LL
# Get Data from:  LLNW
# Get Data from:  LLY
# Get Data from:  LM
# Couldn't get data for : LM
# Get Data from:  LMAT
# Get Data from:  LMFA
# Get Data from:  LMNR
# Get Data from:  LMNX
# Couldn't get data for : LMNX
# Get Data from:  LMT
# Get Data from:  LNC
# Get Data from:  LNDC
# Get Data from:  LNG
# Get Data from:  LNN
# Get Data from:  LNT
# Get Data from:  LNTH
# Get Data from:  LOAN
# Get Data from:  LOB
# Get Data from:  LOCO
# Get Data from:  LODE
# Get Data from:  LOGM
# Couldn't get data for : LOGM
# Get Data from:  LONE
# Couldn't get data for : LONE
# Get Data from:  LOOP
# Get Data from:  LOPE
# Get Data from:  LORL
# Couldn't get data for : LORL
# Get Data from:  LOVE
# Get Data from:  LOW
# Get Data from:  LPCN
# Get Data from:  LPG
# Get Data from:  LPI
# Get Data from:  LPLA
# Get Data from:  LPSN
# Get Data from:  LPTH
# Get Data from:  LPX
# Get Data from:  LQDA
# Get Data from:  LQDT
# Get Data from:  LRCX
# Get Data from:  LRN
# Get Data from:  LSBK
# Get Data from:  LSCC
# Get Data from:  LSI
# Get Data from:  LSTR
# Get Data from:  LSXMA
# Get Data from:  LSXMK
# Get Data from:  LTBR
# Get Data from:  LTC
# Get Data from:  LTHM
# Get Data from:  LTRPA
# Get Data from:  LTRX
# Get Data from:  LUB
# Get Data from:  LULU
# Get Data from:  LUNA
# Get Data from:  LUV
# Get Data from:  LVS
# Get Data from:  LW
# Get Data from:  LWAY
# Get Data from:  LXP
# Get Data from:  LXRX
# Get Data from:  LXU
# Get Data from:  LYB
# Get Data from:  LYFT
# Get Data from:  LYTS
# Get Data from:  LYV
# Get Data from:  LZB
# Get Data from:  M
# Get Data from:  MA
# Get Data from:  MAA
# Get Data from:  MAC
# Get Data from:  MACK
# Get Data from:  MAN
# Get Data from:  MANH
# Get Data from:  MANT
# Get Data from:  MAR
# Get Data from:  MARA
# Get Data from:  MARK
# Get Data from:  MAS
# Get Data from:  MASI
# Get Data from:  MAT
# Get Data from:  MATW
# Get Data from:  MATX
# Get Data from:  MAYS
# Get Data from:  MBCN
# Get Data from:  MBI
# Get Data from:  MBII
# Get Data from:  MBIN
# Get Data from:  MBIO
# Get Data from:  MBOT
# Get Data from:  MBUU
# Get Data from:  MBWM
# Get Data from:  MC
# Get Data from:  MCB
# Get Data from:  MCBC
# Get Data from:  MCD
# Get Data from:  MCF
# Couldn't get data for : MCF
# Get Data from:  MCFT
# Get Data from:  MCHP
# Get Data from:  MCHX
# Get Data from:  MCK
# Get Data from:  MCO
# Get Data from:  MCRB
# Get Data from:  MCRI
# Get Data from:  MCS
# Get Data from:  MCY
# Get Data from:  MD
# Get Data from:  MDB
# Get Data from:  MDC
# Get Data from:  MDGL
# Get Data from:  MDLY
# Couldn't get data for : MDLY
# Get Data from:  MDLZ
# Get Data from:  MDP
# Couldn't get data for : MDP
# Get Data from:  MDRX
# Get Data from:  MDT
# Get Data from:  MDU
# Get Data from:  MED
# Get Data from:  MEDP
# Get Data from:  MEET
# Couldn't get data for : MEET
# Get Data from:  MEI
# Get Data from:  MEIP
# Get Data from:  MERC
# Get Data from:  MESA
# Get Data from:  MET
# Get Data from:  MFA
# Get Data from:  MFNC
# Couldn't get data for : MFNC
# Get Data from:  MG
# Get Data from:  MGEE
# Get Data from:  MGEN
# Couldn't get data for : MGEN
# Get Data from:  MGI
# Get Data from:  MGLN
# Couldn't get data for : MGLN
# Get Data from:  MGM
# Get Data from:  MGNX
# Get Data from:  MGPI
# Get Data from:  MGRC
# Get Data from:  MGTA
# Get Data from:  MGY
# Get Data from:  MGYR
# Get Data from:  MHH
# Get Data from:  MHK
# Get Data from:  MHLD
# Get Data from:  MHO
# Get Data from:  MIC
# Get Data from:  MICR
# Get Data from:  MICT
# Get Data from:  MIDD
# Get Data from:  MIK
# Couldn't get data for : MIK
# Get Data from:  MIND
# Get Data from:  MINI
# Couldn't get data for : MINI
# Get Data from:  MITK
# Get Data from:  MITT
# Get Data from:  MJCO
# Couldn't get data for : MJCO
# Get Data from:  MKC
# Get Data from:  MKL
# Get Data from:  MKSI
# Get Data from:  MKTX
# Get Data from:  MLAB
# Get Data from:  MLHR
# Couldn't get data for : MLHR
# Get Data from:  MLI
# Get Data from:  MLM
# Get Data from:  MLND
# Couldn't get data for : MLND
# Get Data from:  MLP
# Get Data from:  MLR
# Get Data from:  MLSS
# Get Data from:  MLVF
# Get Data from:  MMAC
# Couldn't get data for : MMAC
# Get Data from:  MMC
# Get Data from:  MMI
# Get Data from:  MMM
# Get Data from:  MMS
# Get Data from:  MMSI
# Get Data from:  MN
# Get Data from:  MNK
# Couldn't get data for : MNK
# Get Data from:  MNKD
# Get Data from:  MNOV
# Get Data from:  MNR
# Couldn't get data for : MNR
# Get Data from:  MNRL
# Get Data from:  MNRO
# Get Data from:  MNST
# Get Data from:  MNTA
# Couldn't get data for : MNTA
# Get Data from:  MNTX
# Get Data from:  MO
# Get Data from:  MOBL
# Get Data from:  MOD
# Get Data from:  MODN
# Get Data from:  MOFG
# Get Data from:  MOH
# Get Data from:  MORN
# Get Data from:  MOS
# Get Data from:  MOSY
# Couldn't get data for : MOSY
# Get Data from:  MOTS
# Get Data from:  MOV
# Get Data from:  MPAA
# Get Data from:  MPB
# Get Data from:  MPC
# Get Data from:  MPW
# Get Data from:  MPWR
# Get Data from:  MPX
# Get Data from:  MRAM
# Get Data from:  MRC
# Get Data from:  MRCY
# Get Data from:  MRIN
# Get Data from:  MRK
# Get Data from:  MRKR
# Get Data from:  MRLN
# Couldn't get data for : MRLN
# Get Data from:  MRNS
# Get Data from:  MRO
# Get Data from:  MRSN
# Get Data from:  MRTN
# Get Data from:  MRTX
# Get Data from:  MRVL
# Get Data from:  MS
# Get Data from:  MSA
# Get Data from:  MSBF
# Couldn't get data for : MSBF
# Get Data from:  MSBI
# Get Data from:  MSCI
# Get Data from:  MSEX
# Get Data from:  MSFT
# Get Data from:  MSGN
# Couldn't get data for : MSGN
# Get Data from:  MSI
# Get Data from:  MSM
# Get Data from:  MSN
# Get Data from:  MSON
# Couldn't get data for : MSON
# Get Data from:  MSTR
# Get Data from:  MTB
# Get Data from:  MTCH
# Get Data from:  MTD
# Get Data from:  MTDR
# Get Data from:  MTEM
# Get Data from:  MTEX
# Get Data from:  MTG
# Get Data from:  MTH
# Get Data from:  MTN
# Get Data from:  MTNB
# Get Data from:  MTOR
# Get Data from:  MTRN
# Get Data from:  MTRX
# Get Data from:  MTSC
# Couldn't get data for : MTSC
# Get Data from:  MTSI
# Get Data from:  MTW
# Get Data from:  MTX
# Get Data from:  MTZ
# Get Data from:  MU
# Get Data from:  MUR
# Get Data from:  MUSA
# Get Data from:  MUX
# Get Data from:  MVBF
# Get Data from:  MVIS
# Get Data from:  MWA
# Get Data from:  MXIM
# Couldn't get data for : MXIM
# Get Data from:  MXL
# Get Data from:  MYE
# Get Data from:  MYGN
# Get Data from:  MYL
# Couldn't get data for : MYL
# Get Data from:  MYOK
# Couldn't get data for : MYOK
# Get Data from:  MYOS
# Couldn't get data for : MYOS
# Get Data from:  MYRG
# Get Data from:  NAII
# Get Data from:  NATH
# Get Data from:  NATI
# Get Data from:  NATR
# Get Data from:  NAV
# Couldn't get data for : NAV
# Get Data from:  NAVB
# Get Data from:  NAVI
# Get Data from:  NBEV
# Get Data from:  NBHC
# Get Data from:  NBIX
# Get Data from:  NBL
# Couldn't get data for : NBL
# Get Data from:  NBN
# Get Data from:  NBR
# Get Data from:  NBTB
# Get Data from:  NBY
# Get Data from:  NC
# Get Data from:  NCBS
# Get Data from:  NCLH
# Get Data from:  NCMI
# Get Data from:  NCR
# Get Data from:  NCSM
# Get Data from:  NDAQ
# Get Data from:  NDLS
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL']

# %%
for x in range (2000,2500):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  NDSN
# Get Data from:  NE
# Get Data from:  NEE
# Get Data from:  NEM
# Get Data from:  NEO
# Get Data from:  NEOG
# Get Data from:  NEON
# Get Data from:  NEOS
# Couldn't get data for : NEOS
# Get Data from:  NERV
# Get Data from:  NETE
# Couldn't get data for : NETE
# Get Data from:  NEU
# Get Data from:  NEWR
# Get Data from:  NFBK
# Get Data from:  NFG
# Get Data from:  NFLX
# Get Data from:  NGHC
# Couldn't get data for : NGHC
# Get Data from:  NGS
# Get Data from:  NGVC
# Get Data from:  NGVT
# Get Data from:  NHC
# Get Data from:  NHI
# Get Data from:  NHTC
# Get Data from:  NI
# Get Data from:  NICK
# Get Data from:  NINE
# Get Data from:  NJR
# Get Data from:  NK
# Couldn't get data for : NK
# Get Data from:  NKE
# Get Data from:  NKSH
# Get Data from:  NKTR
# Get Data from:  NL
# Get Data from:  NLS
# Get Data from:  NLSN
# Get Data from:  NLY
# Get Data from:  NMIH
# Get Data from:  NMRK
# Get Data from:  NNBR
# Get Data from:  NNI
# Get Data from:  NNN
# Get Data from:  NNVC
# Get Data from:  NOC
# Get Data from:  NODK
# Get Data from:  NOG
# Get Data from:  NOV
# Get Data from:  NOVT
# Get Data from:  NOW
# Get Data from:  NP
# Get Data from:  NPK
# Get Data from:  NPO
# Get Data from:  NPTN
# Get Data from:  NR
# Get Data from:  NRC
# Get Data from:  NRG
# Get Data from:  NRIM
# Get Data from:  NRZ
# Get Data from:  NSA
# Get Data from:  NSC
# Get Data from:  NSEC
# Get Data from:  NSIT
# Get Data from:  NSP
# Get Data from:  NSSC
# Get Data from:  NSTG
# Get Data from:  NTAP
# Get Data from:  NTCT
# Get Data from:  NTGR
# Get Data from:  NTIC
# Get Data from:  NTIP
# Get Data from:  NTLA
# Get Data from:  NTN
# Couldn't get data for : NTN
# Get Data from:  NTNX
# Get Data from:  NTRA
# Get Data from:  NTRS
# Get Data from:  NTWK
# Get Data from:  NUAN
# Get Data from:  NUE
# Get Data from:  NURO
# Get Data from:  NUS
# Get Data from:  NUVA
# Get Data from:  NVAX
# Get Data from:  NVDA
# Get Data from:  NVEC
# Get Data from:  NVEE
# Get Data from:  NVFY
# Get Data from:  NVIV
# Get Data from:  NVR
# Get Data from:  NVRO
# Get Data from:  NVT
# Get Data from:  NVTA
# Get Data from:  NVUS
# Couldn't get data for : NVUS
# Get Data from:  NWBI
# Get Data from:  NWE
# Get Data from:  NWFL
# Get Data from:  NWHM
# Couldn't get data for : NWHM
# Get Data from:  NWL
# Get Data from:  NWLI
# Get Data from:  NWN
# Get Data from:  NWPX
# Get Data from:  NWS
# Get Data from:  NWSA
# Get Data from:  NX
# Get Data from:  NXGN
# Get Data from:  NXRT
# Get Data from:  NXST
# Get Data from:  NXTD
# Couldn't get data for : NXTD
# Get Data from:  NYCB
# Get Data from:  NYMT
# Get Data from:  NYT
# Get Data from:  O
# Get Data from:  OAS
# Get Data from:  OBCI
# Get Data from:  OBNK
# Get Data from:  OC
# Get Data from:  OCC
# Get Data from:  OCFC
# Get Data from:  OCN
# Get Data from:  OCUL
# Get Data from:  OCX
# Get Data from:  ODC
# Get Data from:  ODFL
# Get Data from:  ODP
# Get Data from:  ODT
# Couldn't get data for : ODT
# Get Data from:  OESX
# Get Data from:  OFC
# Get Data from:  OFED
# Get Data from:  OFG
# Get Data from:  OFIX
# Get Data from:  OFLX
# Get Data from:  OGE
# Get Data from:  OGEN
# Get Data from:  OGS
# Get Data from:  OHI
# Get Data from:  OI
# Get Data from:  OII
# Get Data from:  OIS
# Get Data from:  OKE
# Get Data from:  OKTA
# Get Data from:  OLED
# Get Data from:  OLLI
# Get Data from:  OLN
# Get Data from:  OLP
# Get Data from:  OMC
# Get Data from:  OMCL
# Get Data from:  OMER
# Get Data from:  OMEX
# Get Data from:  OMF
# Get Data from:  OMI
# Get Data from:  ON
# Get Data from:  ONB
# Get Data from:  ONCS
# Get Data from:  ONDK
# Couldn't get data for : ONDK
# Get Data from:  ONTX
# Get Data from:  ONVO
# Get Data from:  OOMA
# Get Data from:  OPGN
# Get Data from:  OPI
# Get Data from:  OPK
# Get Data from:  OPOF
# Get Data from:  OPRX
# Get Data from:  OPTN
# Get Data from:  OPTT
# Get Data from:  OPY
# Get Data from:  ORA
# Get Data from:  ORBC
# Couldn't get data for : ORBC
# Get Data from:  ORC
# Get Data from:  ORCL
# Get Data from:  ORGO
# Get Data from:  ORI
# Get Data from:  ORLY
# Get Data from:  ORN
# Get Data from:  ORRF
# Get Data from:  OSBC
# Get Data from:  OSG
# Get Data from:  OSIS
# Get Data from:  OSK
# Get Data from:  OSPN
# Get Data from:  OSTK
# Get Data from:  OSUR
# Get Data from:  OTEL
# Couldn't get data for : OTEL
# Get Data from:  OTIC
# Get Data from:  OTTR
# Get Data from:  OUT
# Get Data from:  OVBC
# Get Data from:  OVLY
# Get Data from:  OXM
# Get Data from:  OXY
# Get Data from:  OZK
# Get Data from:  PACB
# Get Data from:  PACW
# Get Data from:  PAG
# Get Data from:  PAHC
# Get Data from:  PANL
# Get Data from:  PANW
# Get Data from:  PAR
# Get Data from:  PARR
# Get Data from:  PATI
# Get Data from:  PATK
# Get Data from:  PAYC
# Get Data from:  PAYX
# Get Data from:  PB
# Get Data from:  PBCT
# Get Data from:  PBF
# Get Data from:  PBH
# Get Data from:  PBHC
# Get Data from:  PBI
# Get Data from:  PBIP
# Get Data from:  PBPB
# Get Data from:  PBYI
# Get Data from:  PCAR
# Get Data from:  PCH
# Get Data from:  PCRX
# Get Data from:  PCSB
# Get Data from:  PCTI
# Get Data from:  PCTY
# Get Data from:  PCYG
# Get Data from:  PCYO
# Get Data from:  PD
# Get Data from:  PDCE
# Get Data from:  PDCO
# Get Data from:  PDEX
# Get Data from:  PDFS
# Get Data from:  PDLB
# Get Data from:  PDLI
# Couldn't get data for : PDLI
# Get Data from:  PDM
# Get Data from:  PE
# Couldn't get data for : PE
# Get Data from:  PEB
# Get Data from:  PEBK
# Get Data from:  PEBO
# Get Data from:  PED
# Get Data from:  PEG
# Get Data from:  PEGA
# Get Data from:  PEI
# Get Data from:  PEIX
# Couldn't get data for : PEIX
# Get Data from:  PEN
# Get Data from:  PENN
# Get Data from:  PEP
# Get Data from:  PESI
# Get Data from:  PETQ
# Get Data from:  PETS
# Get Data from:  PFBC
# Get Data from:  PFBI
# Couldn't get data for : PFBI
# Get Data from:  PFE
# Get Data from:  PFG
# Get Data from:  PFGC
# Get Data from:  PFIE
# Get Data from:  PFIN
# Get Data from:  PFIS
# Get Data from:  PFMT
# Get Data from:  PFNX
# Couldn't get data for : PFNX
# Get Data from:  PFPT
# Couldn't get data for : PFPT
# Get Data from:  PFS
# Get Data from:  PFSW
# Get Data from:  PG
# Get Data from:  PGC
# Get Data from:  PGNX
# Couldn't get data for : PGNX
# Get Data from:  PGR
# Get Data from:  PGRE
# Get Data from:  PGTI
# Get Data from:  PH
# Get Data from:  PHAS
# Get Data from:  PHIO
# Get Data from:  PHM
# Get Data from:  PHX
# Get Data from:  PI
# Get Data from:  PICO
# Couldn't get data for : PICO
# Get Data from:  PIH
# Couldn't get data for : PIH
# Get Data from:  PII
# Get Data from:  PINC
# Get Data from:  PINS
# Get Data from:  PJT
# Get Data from:  PK
# Get Data from:  PKBK
# Get Data from:  PKE
# Get Data from:  PKG
# Get Data from:  PKI
# Get Data from:  PKOH
# Get Data from:  PLAB
# Get Data from:  PLAN
# Get Data from:  PLAY
# Get Data from:  PLBC
# Get Data from:  PLCE
# Get Data from:  PLD
# Get Data from:  PLNT
# Get Data from:  PLOW
# Get Data from:  PLPC
# Get Data from:  PLSE
# Get Data from:  PLT
# Couldn't get data for : PLT
# Get Data from:  PLUG
# Get Data from:  PLUS
# Get Data from:  PLXP
# Get Data from:  PLXS
# Get Data from:  PLYA
# Get Data from:  PLYM
# Get Data from:  PM
# Get Data from:  PMBC
# Couldn't get data for : PMBC
# Get Data from:  PMD
# Get Data from:  PMT
# Get Data from:  PMTS
# Get Data from:  PNBK
# Get Data from:  PNC
# Get Data from:  PNFP
# Get Data from:  PNM
# Get Data from:  PNR
# Get Data from:  PNRG
# Get Data from:  PNW
# Get Data from:  PODD
# Get Data from:  POL
# Couldn't get data for : POL
# Get Data from:  POOL
# Get Data from:  POR
# Get Data from:  POST
# Get Data from:  POWI
# Get Data from:  POWL
# Get Data from:  PPBI
# Get Data from:  PPC
# Get Data from:  PPG
# Get Data from:  PPIH
# Get Data from:  PPL
# Get Data from:  PPSI
# Get Data from:  PQG
# Couldn't get data for : PQG
# Get Data from:  PRA
# Get Data from:  PRAA
# Get Data from:  PRAH
# Couldn't get data for : PRAH
# Get Data from:  PRCP
# Couldn't get data for : PRCP
# Get Data from:  PRFT
# Get Data from:  PRGO
# Get Data from:  PRGS
# Get Data from:  PRGX
# Couldn't get data for : PRGX
# Get Data from:  PRI
# Get Data from:  PRIM
# Get Data from:  PRK
# Get Data from:  PRLB
# Get Data from:  PRMW
# Get Data from:  PRNB
# Couldn't get data for : PRNB
# Get Data from:  PRO
# Get Data from:  PROV
# Get Data from:  PRPH
# Get Data from:  PRSC
# Couldn't get data for : PRSC
# Get Data from:  PRSP
# Couldn't get data for : PRSP
# Get Data from:  PRTA
# Get Data from:  PRTK
# Get Data from:  PRTS
# Get Data from:  PRTY
# Get Data from:  PRU
# Get Data from:  PRVB
# Get Data from:  PS
# Couldn't get data for : PS
# Get Data from:  PSA
# Get Data from:  PSB
# Get Data from:  PSMT
# Get Data from:  PSN
# Get Data from:  PSTG
# Get Data from:  PSX
# Get Data from:  PTC
# Get Data from:  PTCT
# Get Data from:  PTE
# Get Data from:  PTEN
# Get Data from:  PTGX
# Get Data from:  PTI
# Couldn't get data for : PTI
# Get Data from:  PTLA
# Couldn't get data for : PTLA
# Get Data from:  PTN
# Get Data from:  PTSI
# Get Data from:  PTVCA
# Couldn't get data for : PTVCA
# Get Data from:  PTVCB
# Couldn't get data for : PTVCB
# Get Data from:  PUB
# Couldn't get data for : PUB
# Get Data from:  PULM
# Get Data from:  PUMP
# Get Data from:  PVAC
# Couldn't get data for : PVAC
# Get Data from:  PVBC
# Get Data from:  PVH
# Get Data from:  PW
# Get Data from:  PWOD
# Get Data from:  PWR
# Get Data from:  PXD
# Get Data from:  PXLW
# Get Data from:  PYPL
# Get Data from:  PZG
# Get Data from:  PZN
# Get Data from:  PZZA
# Get Data from:  QADA
# Couldn't get data for : QADA
# Get Data from:  QADB
# Couldn't get data for : QADB
# Get Data from:  QCOM
# Get Data from:  QCRH
# Get Data from:  QDEL
# Get Data from:  QEP
# Couldn't get data for : QEP
# Get Data from:  QLYS
# Get Data from:  QNST
# Get Data from:  QRHC
# Get Data from:  QRTEA
# Get Data from:  QRVO
# Get Data from:  QTRX
# Get Data from:  QTS
# Couldn't get data for : QTS
# Get Data from:  QTWO
# Get Data from:  QUAD
# Get Data from:  QUIK
# Get Data from:  QUMU
# Get Data from:  QUOT
# Get Data from:  R
# Get Data from:  RAD
# Get Data from:  RAIL
# Get Data from:  RAMP
# Get Data from:  RARE
# Get Data from:  RAVE
# Get Data from:  RAVN
# Couldn't get data for : RAVN
# Get Data from:  RBB
# Get Data from:  RBBN
# Get Data from:  RBC
# Couldn't get data for : RBC
# Get Data from:  RBCAA
# Get Data from:  RBCN
# Get Data from:  RBNC
# Couldn't get data for : RBNC
# Get Data from:  RC
# Get Data from:  RCII
# Get Data from:  RCKT
# Get Data from:  RCKY
# Get Data from:  RCL
# Get Data from:  RCM
# Get Data from:  RCMT
# Get Data from:  RCUS
# Get Data from:  RDFN
# Get Data from:  RDI
# Get Data from:  RDN
# Get Data from:  RDNT
# Get Data from:  RDUS
# Get Data from:  RDVT
# Get Data from:  RE
# Get Data from:  REED
# Get Data from:  REFR
# Get Data from:  REG
# Get Data from:  REGI
# Get Data from:  REGN
# Get Data from:  REI
# Get Data from:  RELL
# Get Data from:  RELV
# Get Data from:  REPH
# Couldn't get data for : REPH
# Get Data from:  REPL
# Get Data from:  RES
# Get Data from:  RESI
# Get Data from:  RESN
# Get Data from:  RETA
# Get Data from:  REV
# Get Data from:  REVG
# Get Data from:  REX
# Get Data from:  REXR
# Get Data from:  REZI
# Get Data from:  RF
# Get Data from:  RFIL
# Get Data from:  RFL
# Get Data from:  RFP
# Get Data from:  RGA
# Get Data from:  RGCO
# Get Data from:  RGEN
# Get Data from:  RGLD
# Get Data from:  RGLS
# Get Data from:  RGNX
# Get Data from:  RGR
# Get Data from:  RGS
# Get Data from:  RH
# Get Data from:  RHE
# Get Data from:  RHI
# Get Data from:  RHP
# Get Data from:  RIBT
# Get Data from:  RICK
# Get Data from:  RIG
# Get Data from:  RIGL
# Get Data from:  RILY
# Get Data from:  RIOT
# Get Data from:  RJF
# Get Data from:  RKDA
# Get Data from:  RL
# Get Data from:  RLGT
# Get Data from:  RLGY
# Get Data from:  RLH
# Couldn't get data for : RLH
# Get Data from:  RLI
# Get Data from:  RLJ
# Get Data from:  RM
# Get Data from:  RMAX
# Get Data from:  RMBS
# Get Data from:  RMCF
# Get Data from:  RMD
# Get Data from:  RMR
# Get Data from:  RMTI
# Get Data from:  RNDB
# Get Data from:  RNET
# Couldn't get data for : RNET
# Get Data from:  RNG
# Get Data from:  RNR
# Get Data from:  RNST
# Get Data from:  RNWK
# Get Data from:  ROCK
# Get Data from:  ROG
# Get Data from:  ROIC
# Get Data from:  ROK
# Get Data from:  ROKU
# Get Data from:  ROL
# Get Data from:  ROLL
# Get Data from:  ROP
# Get Data from:  ROST
# Get Data from:  RP
# Couldn't get data for : RP
# Get Data from:  RPAI
# Couldn't get data for : RPAI
# Get Data from:  RPD
# Get Data from:  RPM
# Get Data from:  RPT
# Get Data from:  RRC
# Get Data from:  RRD
# Couldn't get data for : RRD
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL',
#  'NEOS',
#  'NETE',
#  'NGHC',
#  'NK',
#  'NTN',
#  'NVUS',
#  'NWHM',
#  'NXTD',
#  'ODT',
#  'ONDK',
#  'ORBC',
#  'OTEL',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'REPH',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RRD']

# %%
for x in range (2500,3000):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  RRGB
# Get Data from:  RRR
# Get Data from:  RRTS
# Get Data from:  RS
# Get Data from:  RSG
# Get Data from:  RST
# Couldn't get data for : RST
# Get Data from:  RTIX
# Couldn't get data for : RTIX
# Get Data from:  RTRX
# Couldn't get data for : RTRX
# Get Data from:  RTW
# Couldn't get data for : RTW
# Get Data from:  RUBI
# Couldn't get data for : RUBI
# Get Data from:  RUBY
# Get Data from:  RUN
# Get Data from:  RUSHA
# Get Data from:  RUSHB
# Get Data from:  RUTH
# Get Data from:  RVI
# Get Data from:  RVLT
# Couldn't get data for : RVLT
# Get Data from:  RVNC
# Get Data from:  RVP
# Get Data from:  RVSB
# Get Data from:  RWT
# Get Data from:  RXN
# Couldn't get data for : RXN
# Get Data from:  RYAM
# Get Data from:  RYI
# Get Data from:  RYN
# Get Data from:  RYTM
# Get Data from:  SABR
# Get Data from:  SACH
# Get Data from:  SAFE
# Get Data from:  SAFM
# Get Data from:  SAFT
# Get Data from:  SAGE
# Get Data from:  SAH
# Get Data from:  SAIA
# Get Data from:  SAIC
# Get Data from:  SAIL
# Get Data from:  SAL
# Get Data from:  SALM
# Get Data from:  SAM
# Get Data from:  SAMG
# Get Data from:  SANM
# Get Data from:  SANW
# Get Data from:  SASR
# Get Data from:  SATS
# Get Data from:  SAVE
# Get Data from:  SBAC
# Get Data from:  SBBX
# Couldn't get data for : SBBX
# Get Data from:  SBCF
# Get Data from:  SBFG
# Get Data from:  SBGI
# Get Data from:  SBH
# Get Data from:  SBNY
# Get Data from:  SBOW
# Get Data from:  SBPH
# Couldn't get data for : SBPH
# Get Data from:  SBRA
# Get Data from:  SBSI
# Get Data from:  SBT
# Get Data from:  SBUX
# Get Data from:  SC
# Couldn't get data for : SC
# Get Data from:  SCHL
# Get Data from:  SCHN
# Get Data from:  SCHW
# Get Data from:  SCI
# Get Data from:  SCL
# Get Data from:  SCON
# Couldn't get data for : SCON
# Get Data from:  SCOR
# Get Data from:  SCPL
# Get Data from:  SCS
# Get Data from:  SCSC
# Get Data from:  SCVL
# Get Data from:  SCWX
# Get Data from:  SCX
# Get Data from:  SCYX
# Get Data from:  SD
# Get Data from:  SDPI
# Get Data from:  SEAC
# Get Data from:  SEAS
# Get Data from:  SEB
# Get Data from:  SEDG
# Get Data from:  SEE
# Get Data from:  SEIC
# Get Data from:  SELB
# Get Data from:  SELF
# Get Data from:  SEM
# Get Data from:  SENEA
# Get Data from:  SENEB
# Get Data from:  SENS
# Get Data from:  SERV
# Couldn't get data for : SERV
# Get Data from:  SESN
# Get Data from:  SF
# Get Data from:  SFBC
# Get Data from:  SFBS
# Get Data from:  SFE
# Get Data from:  SFIX
# Get Data from:  SFM
# Get Data from:  SFNC
# Get Data from:  SFST
# Get Data from:  SGA
# Get Data from:  SGC
# Get Data from:  SGEN
# Get Data from:  SGH
# Get Data from:  SGMA
# Get Data from:  SGMO
# Get Data from:  SGMS
# Get Data from:  SGRP
# Get Data from:  SGRY
# Get Data from:  SHAK
# Get Data from:  SHBI
# Get Data from:  SHEN
# Get Data from:  SHLO
# Couldn't get data for : SHLO
# Get Data from:  SHO
# Get Data from:  SHOO
# Get Data from:  SHSP
# Couldn't get data for : SHSP
# Get Data from:  SHW
# Get Data from:  SIBN
# Get Data from:  SIEB
# Get Data from:  SIEN
# Get Data from:  SIF
# Get Data from:  SIG
# Get Data from:  SIGA
# Get Data from:  SIGI
# Get Data from:  SILK
# Get Data from:  SINT
# Get Data from:  SIRI
# Get Data from:  SITC
# Get Data from:  SITE
# Get Data from:  SITO
# Couldn't get data for : SITO
# Get Data from:  SIVB
# Get Data from:  SIX
# Get Data from:  SJI
# Get Data from:  SJM
# Get Data from:  SJW
# Get Data from:  SKT
# Get Data from:  SKX
# Get Data from:  SKY
# Get Data from:  SKYW
# Get Data from:  SLAB
# Get Data from:  SLB
# Get Data from:  SLCA
# Get Data from:  SLCT
# Couldn't get data for : SLCT
# Get Data from:  SLDB
# Get Data from:  SLG
# Get Data from:  SLGN
# Get Data from:  SLM
# Get Data from:  SLNO
# Get Data from:  SLP
# Get Data from:  SLS
# Get Data from:  SM
# Get Data from:  SMAR
# Get Data from:  SMBC
# Get Data from:  SMBK
# Get Data from:  SMED
# Get Data from:  SMG
# Get Data from:  SMIT
# Get Data from:  SMMF
# Get Data from:  SMP
# Get Data from:  SMPL
# Get Data from:  SMRT
# Get Data from:  SMSI
# Get Data from:  SMTC
# Get Data from:  SNA
# Get Data from:  SNAP
# Get Data from:  SNBR
# Get Data from:  SNCR
# Get Data from:  SND
# Get Data from:  SNDR
# Get Data from:  SNDX
# Get Data from:  SNFCA
# Get Data from:  SNOA
# Get Data from:  SNPS
# Get Data from:  SNR
# Couldn't get data for : SNR
# Get Data from:  SNSS
# Couldn't get data for : SNSS
# Get Data from:  SNV
# Get Data from:  SNX
# Get Data from:  SO
# Get Data from:  SOHO
# Get Data from:  SOI
# Get Data from:  SOLY
# Couldn't get data for : SOLY
# Get Data from:  SON
# Get Data from:  SONA
# Couldn't get data for : SONA
# Get Data from:  SONO
# Get Data from:  SP
# Get Data from:  SPB
# Get Data from:  SPG
# Get Data from:  SPGI
# Get Data from:  SPKE
# Couldn't get data for : SPKE
# Get Data from:  SPLK
# Get Data from:  SPN
# Couldn't get data for : SPN
# Get Data from:  SPNE
# Get Data from:  SPOK
# Get Data from:  SPPI
# Get Data from:  SPR
# Get Data from:  SPRO
# Get Data from:  SPRT
# Couldn't get data for : SPRT
# Get Data from:  SPSC
# Get Data from:  SPTN
# Get Data from:  SPWH
# Get Data from:  SPWR
# Get Data from:  SPXC
# Get Data from:  SQ
# Get Data from:  SQBG
# Couldn't get data for : SQBG
# Get Data from:  SR
# Get Data from:  SRC
# Get Data from:  SRCE
# Get Data from:  SRCL
# Get Data from:  SRDX
# Get Data from:  SRE
# Get Data from:  SREV
# Get Data from:  SRG
# Get Data from:  SRI
# Get Data from:  SRNE
# Get Data from:  SRPT
# Get Data from:  SRRK
# Get Data from:  SRT
# Get Data from:  SRTS
# Get Data from:  SSB
# Get Data from:  SSBI
# Get Data from:  SSD
# Get Data from:  SSKN
# Get Data from:  SSNC
# Get Data from:  SSP
# Get Data from:  SSTI
# Get Data from:  SSTK
# Get Data from:  ST
# Get Data from:  STAA
# Get Data from:  STAG
# Get Data from:  STAR
# Get Data from:  STAY
# Couldn't get data for : STAY
# Get Data from:  STBA
# Get Data from:  STC
# Get Data from:  STCN
# Get Data from:  STE
# Get Data from:  STFC
# Couldn't get data for : STFC
# Get Data from:  STIM
# Get Data from:  STKS
# Get Data from:  STL
# Couldn't get data for : STL
# Get Data from:  STLD
# Get Data from:  STMP
# Couldn't get data for : STMP
# Get Data from:  STND
# Couldn't get data for : STND
# Get Data from:  STOR
# Get Data from:  STRA
# Get Data from:  STRL
# Get Data from:  STRM
# Get Data from:  STRS
# Get Data from:  STRT
# Get Data from:  STT
# Get Data from:  STWD
# Get Data from:  STX
# Get Data from:  STXB
# Get Data from:  STZ
# Get Data from:  SUI
# Get Data from:  SUM
# Get Data from:  SUMR
# Get Data from:  SUNW
# Get Data from:  SUP
# Get Data from:  SUPN
# Get Data from:  SVBI
# Couldn't get data for : SVBI
# Get Data from:  SVMK
# Couldn't get data for : SVMK
# Get Data from:  SVRA
# Get Data from:  SVT
# Get Data from:  SWAV
# Get Data from:  SWCH
# Get Data from:  SWK
# Get Data from:  SWKS
# Get Data from:  SWM
# Get Data from:  SWN
# Get Data from:  SWX
# Get Data from:  SXC
# Get Data from:  SXI
# Get Data from:  SXT
# Get Data from:  SYBT
# Get Data from:  SYBX
# Get Data from:  SYF
# Get Data from:  SYK
# Get Data from:  SYKE
# Couldn't get data for : SYKE
# Get Data from:  SYN
# Get Data from:  SYNA
# Get Data from:  SYNC
# Couldn't get data for : SYNC
# Get Data from:  SYNH
# Get Data from:  SYNL
# Get Data from:  SYPR
# Get Data from:  SYRS
# Get Data from:  SYX
# Couldn't get data for : SYX
# Get Data from:  SYY
# Get Data from:  T
# Get Data from:  TACO
# Get Data from:  TACT
# Get Data from:  TAIT
# Get Data from:  TALO
# Get Data from:  TAP
# Get Data from:  TAST
# Get Data from:  TAT
# Couldn't get data for : TAT
# Get Data from:  TAYD
# Get Data from:  TBBK
# Get Data from:  TBI
# Get Data from:  TBIO
# Couldn't get data for : TBIO
# Get Data from:  TBK
# Get Data from:  TBNK
# Get Data from:  TBPH
# Get Data from:  TCBI
# Get Data from:  TCBK
# Get Data from:  TCDA
# Get Data from:  TCF
# Couldn't get data for : TCF
# Get Data from:  TCFC
# Get Data from:  TCI
# Get Data from:  TCMD
# Get Data from:  TCO
# Couldn't get data for : TCO
# Get Data from:  TCON
# Get Data from:  TCS
# Get Data from:  TDC
# Get Data from:  TDG
# Get Data from:  TDOC
# Get Data from:  TDS
# Get Data from:  TDW
# Get Data from:  TDY
# Get Data from:  TECD
# Couldn't get data for : TECD
# Get Data from:  TECH
# Get Data from:  TEL
# Get Data from:  TELL
# Get Data from:  TEN
# Get Data from:  TENB
# Get Data from:  TENX
# Get Data from:  TER
# Get Data from:  TERP
# Couldn't get data for : TERP
# Get Data from:  TESS
# Get Data from:  TEUM
# Get Data from:  TEX
# Get Data from:  TFSL
# Get Data from:  TFX
# Get Data from:  TG
# Get Data from:  TGEN
# Get Data from:  TGI
# Get Data from:  TGLS
# Get Data from:  TGNA
# Get Data from:  TGT
# Get Data from:  TGTX
# Get Data from:  THC
# Get Data from:  THFF
# Get Data from:  THG
# Get Data from:  THO
# Get Data from:  THR
# Get Data from:  THRM
# Get Data from:  THS
# Get Data from:  TIF
# Couldn't get data for : TIF
# Get Data from:  TILE
# Get Data from:  TIPT
# Get Data from:  TISI
# Get Data from:  TITN
# Get Data from:  TJX
# Get Data from:  TKR
# Get Data from:  TLF
# Couldn't get data for : TLF
# Get Data from:  TLGT
# Couldn't get data for : TLGT
# Get Data from:  TLRD
# Couldn't get data for : TLRD
# Get Data from:  TLYS
# Get Data from:  TMDX
# Get Data from:  TMHC
# Get Data from:  TMO
# Get Data from:  TMP
# Get Data from:  TMST
# Get Data from:  TMUS
# Get Data from:  TNAV
# Couldn't get data for : TNAV
# Get Data from:  TNC
# Get Data from:  TNDM
# Get Data from:  TNET
# Get Data from:  TNXP
# Get Data from:  TOL
# Get Data from:  TORC
# Couldn't get data for : TORC
# Get Data from:  TOWN
# Get Data from:  TPB
# Get Data from:  TPC
# Get Data from:  TPH
# Get Data from:  TPHS
# Get Data from:  TPIC
# Get Data from:  TPR
# Get Data from:  TPRE
# Couldn't get data for : TPRE
# Get Data from:  TPTX
# Get Data from:  TPX
# Get Data from:  TR
# Get Data from:  TRC
# Get Data from:  TRCH
# Couldn't get data for : TRCH
# Get Data from:  TREC
# Get Data from:  TREE
# Get Data from:  TREX
# Get Data from:  TRGP
# Get Data from:  TRHC
# Get Data from:  TRIP
# Get Data from:  TRMB
# Get Data from:  TRMK
# Get Data from:  TRN
# Get Data from:  TRNO
# Get Data from:  TRNS
# Get Data from:  TROW
# Get Data from:  TROX
# Get Data from:  TRS
# Get Data from:  TRST
# Get Data from:  TRT
# Get Data from:  TRTN
# Get Data from:  TRTX
# Get Data from:  TRU
# Get Data from:  TRUE
# Couldn't get data for : TRUE
# Get Data from:  TRUP
# Get Data from:  TRV
# Get Data from:  TRVN
# Get Data from:  TRWH
# Couldn't get data for : TRWH
# Get Data from:  TRXC
# Couldn't get data for : TRXC
# Get Data from:  TSBK
# Get Data from:  TSC
# Get Data from:  TSCO
# Get Data from:  TSE
# Get Data from:  TSLA
# Get Data from:  TSN
# Get Data from:  TSQ
# Get Data from:  TTC
# Get Data from:  TTD
# Get Data from:  TTEC
# Get Data from:  TTEK
# Get Data from:  TTGT
# Get Data from:  TTI
# Get Data from:  TTMI
# Get Data from:  TTNP
# Get Data from:  TTOO
# Get Data from:  TTPH
# Couldn't get data for : TTPH
# Get Data from:  TTWO
# Get Data from:  TUP
# Get Data from:  TUSK
# Get Data from:  TVTY
# Get Data from:  TW
# Get Data from:  TWI
# Get Data from:  TWIN
# Get Data from:  TWLO
# Get Data from:  TWMC
# Couldn't get data for : TWMC
# Get Data from:  TWNK
# Get Data from:  TWO
# Get Data from:  TWOU
# Get Data from:  TWST
# Get Data from:  TWTR
# Get Data from:  TXMD
# Get Data from:  TXN
# Get Data from:  TXRH
# Get Data from:  TXT
# Get Data from:  TYL
# Get Data from:  TYME
# Get Data from:  TZOO
# Get Data from:  UA
# Get Data from:  UAA
# Get Data from:  UAL
# Get Data from:  UAMY
# Get Data from:  UBA
# Get Data from:  UBCP
# Get Data from:  UBER
# Get Data from:  UBFO
# Get Data from:  UBOH
# Get Data from:  UBSI
# Get Data from:  UCBI
# Get Data from:  UCTT
# Get Data from:  UDR
# Get Data from:  UE
# Get Data from:  UEC
# Get Data from:  UEIC
# Get Data from:  UFAB
# Get Data from:  UFCS
# Get Data from:  UFI
# Get Data from:  UFPI
# Get Data from:  UFPT
# Get Data from:  UFS
# Couldn't get data for : UFS
# Get Data from:  UG
# Get Data from:  UGI
# Get Data from:  UHAL
# Get Data from:  UHS
# Get Data from:  UHT
# Get Data from:  UIHC
# Get Data from:  UIS
# Get Data from:  ULBI
# Get Data from:  ULH
# Get Data from:  ULTA
# Get Data from:  UMBF
# Get Data from:  UMH
# Get Data from:  UMPQ
# Get Data from:  UNAM
# Get Data from:  UNB
# Get Data from:  UNF
# Get Data from:  UNFI
# Get Data from:  UNH
# Get Data from:  UNIT
# Get Data from:  UNM
# Get Data from:  UNP
# Get Data from:  UNTY
# Get Data from:  UNVR
# Get Data from:  UONE
# Get Data from:  UONEK
# Get Data from:  UPLD
# Get Data from:  UPS
# Get Data from:  UPWK
# Get Data from:  URBN
# Get Data from:  URI
# Get Data from:  UROV
# Couldn't get data for : UROV
# Get Data from:  USAK
# Get Data from:  USAP
# Get Data from:  USAT
# Couldn't get data for : USAT
# Get Data from:  USB
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL',
#  'NEOS',
#  'NETE',
#  'NGHC',
#  'NK',
#  'NTN',
#  'NVUS',
#  'NWHM',
#  'NXTD',
#  'ODT',
#  'ONDK',
#  'ORBC',
#  'OTEL',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'REPH',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RRD',
#  'RST',
#  'RTIX',
#  'RTRX',
#  'RTW',
#  'RUBI',
#  'RVLT',
#  'RXN',
#  'SBBX',
#  'SBPH',
#  'SC',
#  'SCON',
#  'SERV',
#  'SHLO',
#  'SHSP',
#  'SITO',
#  'SLCT',
#  'SNR',
#  'SNSS',
#  'SOLY',
#  'SONA',
#  'SPKE',
#  'SPN',
#  'SPRT',
#  'SQBG',
#  'STAY',
#  'STFC',
#  'STL',
#  'STMP',
#  'STND',
#  'SVBI',
#  'SVMK',
#  'SYKE',
#  'SYNC',
#  'SYX',
#  'TAT',
#  'TBIO',
#  'TCF',
#  'TCO',
#  'TECD',
#  'TERP',
#  'TIF',
#  'TLF',
#  'TLGT',
#  'TLRD',
#  'TNAV',
#  'TORC',
#  'TPRE',
#  'TRCH',
#  'TRUE ',
#  'TRWH',
#  'TRXC',
#  'TTPH',
#  'TWMC',
#  'UFS',
#  'UROV',
#  'USAT']

# %%
for x in range (3475,3481):
    save_to_csv_from_yahoo(folder, tickers[x], syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data from:  ZS
# Get Data from:  ZUMZ
# Get Data from:  ZUO
# Get Data from:  ZYNE
# Get Data from:  ZYXI
# Get Data from:  ZNGA
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL',
#  'NEOS',
#  'NETE',
#  'NGHC',
#  'NK',
#  'NTN',
#  'NVUS',
#  'NWHM',
#  'NXTD',
#  'ODT',
#  'ONDK',
#  'ORBC',
#  'OTEL',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'REPH',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RRD',
#  'RST',
#  'RTIX',
#  'RTRX',
#  'RTW',
#  'RUBI',
#  'RVLT',
#  'RXN',
#  'SBBX',
#  'SBPH',
#  'SC',
#  'SCON',
#  'SERV',
#  'SHLO',
#  'SHSP',
#  'SITO',
#  'SLCT',
#  'SNR',
#  'SNSS',
#  'SOLY',
#  'SONA',
#  'SPKE',
#  'SPN',
#  'SPRT',
#  'SQBG',
#  'STAY',
#  'STFC',
#  'STL',
#  'STMP',
#  'STND',
#  'SVBI',
#  'SVMK',
#  'SYKE',
#  'SYNC',
#  'SYX',
#  'TAT',
#  'TBIO',
#  'TCF',
#  'TCO',
#  'TECD',
#  'TERP',
#  'TIF',
#  'TLF',
#  'TLGT',
#  'TLRD',
#  'TNAV',
#  'TORC',
#  'TPRE',
#  'TRCH',
#  'TRUE ',
#  'TRWH',
#  'TRXC',
#  'TTPH',
#  'TWMC',
#  'UFS',
#  'UROV',
#  'USAT',
#  'USCR',
#  'VAR',
#  'VCRA',
#  'VER',
#  'VRTU',
#  'VSLR',
#  'VVUS',
#  'WDR',
#  'WIFI',
#  'WLTW',
#  'WMGI',
#  'WPG',
#  'WPX',
#  'WRI',
#  'WRTC',
#  'WYND',
#  'XAN',
#  'XEC',
#  'XLNX',
#  'XLRN',
#  'XOG',
#  'XONE',
#  'YRCW',
#  'ZAGG',
#  'ZGNX',
#  'ZIOP',
#  'ZIXI',
#  'ZN',
#  'UROV',
#  'USAT',
#  'VAR',
#  'VER',
#  'VRML',
#  'CBS',
#  'VICL',
#  'VRTU',
#  'VSI',
#  'VSLR',
#  'VVUS',
#  'VCRA',
#  'VISI',
#  'VOXX',
#  'GRA',
#  'WBC',
#  'WDR',
#  'WD',
#  'WPG',
#  'WRI',
#  'WCG',
#  'WEBK',
#  'WAIR',
#  'WLH',
#  'WLTW',
#  'WPX',
#  'WRTC',
#  'WMGI',
#  'WYND',
#  'XLNX',
#  'YRCW',
#  'YUMA',
#  'ZFGN',
#  'ZAGG',
#  'ZAYO',
#  'ZN',
#  'ZIOP',
#  'ZIXI',
#  'ZGNX']

# %%
for x in missing_stocks:
    save_to_csv_from_yahoo(folder, x, syear, smonth, sday, eyear, emonth, eday)
print("Finished")
stocks_not_downloaded
# Out:
# Finished
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL',
#  'NEOS',
#  'NETE',
#  'NGHC',
#  'NK',
#  'NTN',
#  'NVUS',
#  'NWHM',
#  'NXTD',
#  'ODT',
#  'ONDK',
#  'ORBC',
#  'OTEL',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'REPH',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RRD',
#  'RST',
#  'RTIX',
#  'RTRX',
#  'RTW',
#  'RUBI',
#  'RVLT',
#  'RXN',
#  'SBBX',
#  'SBPH',
#  'SC',
#  'SCON',
#  'SERV',
#  'SHLO',
#  'SHSP',
#  'SITO',
#  'SLCT',
#  'SNR',
#  'SNSS',
#  'SOLY',
#  'SONA',
#  'SPKE',
#  'SPN',
#  'SPRT',
#  'SQBG',
#  'STAY',
#  'STFC',
#  'STL',
#  'STMP',
#  'STND',
#  'SVBI',
#  'SVMK',
#  'SYKE',
#  'SYNC',
#  'SYX',
#  'TAT',
#  'TBIO',
#  'TCF',
#  'TCO',
#  'TECD',
#  'TERP',
#  'TIF',
#  'TLF',
#  'TLGT',
#  'TLRD',
#  'TNAV',
#  'TORC',
#  'TPRE',
#  'TRCH',
#  'TRUE ',
#  'TRWH',
#  'TRXC',
#  'TTPH',
#  'TWMC',
#  'UFS',
#  'UROV',
#  'USAT',
#  'USCR',
#  'VAR',
#  'VCRA',
#  'VER',
#  'VRTU',
#  'VSLR',
#  'VVUS',
#  'WDR',
#  'WIFI',
#  'WLTW',
#  'WMGI',
#  'WPG',
#  'WPX',
#  'WRI',
#  'WRTC',
#  'WYND',
#  'XAN',
#  'XEC',
#  'XLNX',
#  'XLRN',
#  'XOG',
#  'XONE',
#  'YRCW',
#  'ZAGG',
#  'ZGNX',
#  'ZIOP',
#  'ZIXI',
#  'ZN',
#  'UROV',
#  'USAT',
#  'VAR',
#  'VER',
#  'VRML',
#  'CBS',
#  'VICL',
#  'VRTU',
#  'VSI',
#  'VSLR',
#  'VVUS',
#  'VCRA',
#  'VISI',
#  'VOXX',
#  'GRA',
#  'WBC',
#  'WDR',
#  'WD',
#  'WPG',
#  'WRI',
#  'WCG',
#  'WEBK',
#  'WAIR',
#  'WLH',
#  'WLTW',
#  'WPX',
#  'WRTC',
#  'WMGI',
#  'WYND',
#  'XLNX',
#  'YRCW',
#  'YUMA',
#  'ZFGN',
#  'ZAGG',
#  'ZAYO',
#  'ZN',
#  'ZIOP',
#  'ZIXI',
#  'ZGNX']

# %%
stocks_not_downloaded
# Out:
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC',
#  'AIMT',
#  'AKCA',
#  'AKER',
#  'ALSK',
#  'ALTM',
#  'ALXN',
#  'AMAG',
#  'AMRB',
#  'ANH',
#  'ARA',
#  'ARPO',
#  'ASFI',
#  'ASNA',
#  'ATH',
#  'AWSM',
#  'AXE',
#  'BASI',
#  'BCEI',
#  'BDGE',
#  'BMCH',
#  'BMTC',
#  'BOCH',
#  'BOMN',
#  'BPFH',
#  'BREW',
#  'BRKS',
#  'BSTC',
#  'BXS',
#  'CAI',
#  'CATB',
#  'CATM',
#  'CATS',
#  'CBB',
#  'CBLI',
#  'CBMG',
#  'CERC',
#  'CETV',
#  'CGIX',
#  'CHAP',
#  'CIT',
#  'CKH',
#  'CLCT',
#  'CLDR',
#  'CLGX',
#  'CLI',
#  'CLNC',
#  'CLNY',
#  'CLUB',
#  'CMD',
#  'CMO',
#  'CNBKA',
#  'COG',
#  'CONE',
#  'COR',
#  'CORE',
#  'CPLG',
#  'CPST',
#  'CREE',
#  'CRY',
#  'CSLT',
#  'CSOD',
#  'CSU',
#  'CTB',
#  'CTL',
#  'CUB',
#  'CVA',
#  'CVIA',
#  'CVTI',
#  'CXO',
#  'CXP',
#  'DLPH',
#  'DNKN',
#  'DNR',
#  'DRAD',
#  'DRNA',
#  'DSPG',
#  'DVD',
#  'EBSB',
#  'ECHO',
#  'EE',
#  'EGOV',
#  'EIDX',
#  'EIGI',
#  'ELGX',
#  'ENT',
#  'ERI',
#  'ESXB',
#  'ETFC',
#  'ETH',
#  'ETM',
#  'EV',
#  'EYEG',
#  'FBM',
#  'FBSS',
#  'FCBP',
#  'FCCY',
#  'FDEF',
#  'FEYE',
#  'FFG',
#  'FI',
#  'FIT',
#  'FLIR',
#  'FLXN',
#  'FMBI',
#  'FNJN',
#  'FPRX',
#  'FRAN',
#  'FRTA',
#  'FSB',
#  'FSCT',
#  'FTSI',
#  'FVE',
#  'GCAP',
#  'GDP',
#  'GEC',
#  'GEN',
#  'GFN',
#  'GLIBA',
#  'GLUU',
#  'GMO',
#  'GNC',
#  'GNMK',
#  'GPX',
#  'GRA',
#  'GRIF',
#  'GRMN',
#  'GRUB',
#  'GSB',
#  'GTS',
#  'GTT',
#  'GV',
#  'GWB',
#  'HCFT',
#  'HCHC',
#  'HDS',
#  'HFC',
#  'HMSY',
#  'HNI',
#  'HOME',
#  'HPR',
#  'HRC',
#  'HSKA',
#  'HT',
#  'HTH',
#  'HWCC',
#  'IBKC',
#  'ICBK',
#  'ICON',
#  'IEC',
#  'IHC',
#  'IKNX',
#  'IMMU',
#  'INFO',
#  'INOV',
#  'INS',
#  'INTL',
#  'INWK',
#  'IOTS',
#  'IPHI',
#  'IRET',
#  'ISNS',
#  'JAKK',
#  'JASN',
#  'JAX',
#  'JCAP',
#  'JCOM',
#  'KDMN',
#  'KIN',
#  'KNL',
#  'KRA',
#  'KSU',
#  'LB',
#  'LDL',
#  'LEAF',
#  'LIVX',
#  'LM',
#  'LMNX',
#  'LOGM',
#  'LONE',
#  'LORL',
#  'MCF',
#  'MDLY',
#  'MDP',
#  'MEET',
#  'MFNC',
#  'MGEN',
#  'MGLN',
#  'MIK',
#  'MINI',
#  'MJCO',
#  'MLHR',
#  'MLND',
#  'MMAC',
#  'MNK',
#  'MNR',
#  'MNTA',
#  'MOSY',
#  'MRLN',
#  'MSBF',
#  'MSGN',
#  'MSON',
#  'MTSC',
#  'MXIM',
#  'MYL',
#  'MYOK',
#  'MYOS',
#  'NAV',
#  'NBL',
#  'NEOS',
#  'NETE',
#  'NGHC',
#  'NK',
#  'NTN',
#  'NVUS',
#  'NWHM',
#  'NXTD',
#  'ODT',
#  'ONDK',
#  'ORBC',
#  'OTEL',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'REPH',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RRD',
#  'RST',
#  'RTIX',
#  'RTRX',
#  'RTW',
#  'RUBI',
#  'RVLT',
#  'RXN',
#  'SBBX',
#  'SBPH',
#  'SC',
#  'SCON',
#  'SERV',
#  'SHLO',
#  'SHSP',
#  'SITO',
#  'SLCT',
#  'SNR',
#  'SNSS',
#  'SOLY',
#  'SONA',
#  'SPKE',
#  'SPN',
#  'SPRT',
#  'SQBG',
#  'STAY',
#  'STFC',
#  'STL',
#  'STMP',
#  'STND',
#  'SVBI',
#  'SVMK',
#  'SYKE',
#  'SYNC',
#  'SYX',
#  'TAT',
#  'TBIO',
#  'TCF',
#  'TCO',
#  'TECD',
#  'TERP',
#  'TIF',
#  'TLF',
#  'TLGT',
#  'TLRD',
#  'TNAV',
#  'TORC',
#  'TPRE',
#  'TRCH',
#  'TRUE ',
#  'TRWH',
#  'TRXC',
#  'TTPH',
#  'TWMC',
#  'UFS',
#  'UROV',
#  'USAT',
#  'USCR',
#  'VAR',
#  'VCRA',
#  'VER',
#  'VRTU',
#  'VSLR',
#  'VVUS',
#  'WDR',
#  'WIFI',
#  'WLTW',
#  'WMGI',
#  'WPG',
#  'WPX',
#  'WRI',
#  'WRTC',
#  'WYND',
#  'XAN',
#  'XEC',
#  'XLNX',
#  'XLRN',
#  'XOG',
#  'XONE',
#  'YRCW',
#  'ZAGG',
#  'ZGNX',
#  'ZIOP',
#  'ZIXI',
#  'ZN',
#  'UROV',
#  'USAT',
#  'VAR',
#  'VER',
#  'VRML',
#  'CBS',
#  'VICL',
#  'VRTU',
#  'VSI',
#  'VSLR',
#  'VVUS',
#  'VCRA',
#  'VISI',
#  'VOXX',
#  'GRA',
#  'WBC',
#  'WDR',
#  'WD',
#  'WPG',
#  'WRI',
#  'WCG',
#  'WEBK',
#  'WAIR',
#  'WLH',
#  'WLTW',
#  'WPX',
#  'WRTC',
#  'WMGI',
#  'WYND',
#  'XLNX',
#  'YRCW',
#  'YUMA',
#  'ZFGN',
#  'ZAGG',
#  'ZAYO',
#  'ZN',
#  'ZIOP',
#  'ZIXI',
#  'ZGNX']
